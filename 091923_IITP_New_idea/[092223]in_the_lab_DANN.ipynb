# %%
from tqdm.notebook import tqdm
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.utils.data as data_util
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from torchsummary import summary
from sklearn.metrics import r2_score

# %%
CUDA = torch.cuda.is_available()
print(CUDA)

device = torch.device('cuda:0' if CUDA else 'cpu')
# Out:
# True

# %%
nelec = pd.read_csv('nelec_082323.csv')
dhw = pd.read_csv('dhw_merge.csv')

# %% [markdown]
# ### Domain Classification

# %%
nelec = nelec.drop(['YEAR'], axis=1)
dhw = dhw.drop(['YEAR'], axis=1)

# %%
input_nelec = nelec.iloc[:-1,].reset_index(drop=True)
output_nelec = nelec[['n_elec']].iloc[1:].reset_index(drop=True)
output_nelec.columns = ['nelec']

input_dhw = dhw.iloc[:-1,].reset_index(drop=True)
output_dhw = dhw[['DHW']].iloc[1:].reset_index(drop=True)
output_dhw.columns = ['dhw']

nelec = pd.concat([input_nelec, output_nelec], axis=1)
dhw = pd.concat([input_dhw, output_dhw], axis=1)

# %%
scaler_nelec = MinMaxScaler()
scaler_dhw = MinMaxScaler()

scaler_nelec.fit(nelec)
scaler_dhw.fit(dhw)

scaled_nelec = scaler_nelec.transform(nelec)
scaled_dhw = scaler_dhw.transform(dhw)

nelec = pd.DataFrame(scaled_nelec, index=nelec.index, columns=nelec.columns)
dhw = pd.DataFrame(scaled_dhw, index=dhw.index, columns=dhw.columns)

# %%
standard_nelec = int(len(nelec) * 0.7)
standard_dhw = int(len(dhw) * 0.7)

nelec_train = nelec.iloc[:standard_nelec]
nelec_test = nelec.iloc[standard_nelec:].reset_index(drop=True)

dhw_train = dhw.iloc[:standard_dhw]
dhw_test = dhw.iloc[standard_dhw:].reset_index(drop=True)

# %%
nelec_trainx = nelec_train.drop(['nelec'], axis=1)
nelec_trainy = nelec_train[['nelec']]

nelec_testx = nelec_test.drop(['nelec'], axis=1)
nelec_testy = nelec_test[['nelec']]

dhw_trainx = dhw_train.drop(['dhw'], axis=1)
dhw_trainy = dhw_train[['dhw']]

dhw_testx = dhw_test.drop(['dhw'], axis=1)
dhw_testy = dhw_test[['dhw']]

# %%
seqLength = 24
def buildDataSet(input, target, seqLength):
    xdata = []
    ydata = []
    for i in range(len(input) - seqLength):
        tx = input.iloc[i:i+seqLength]
        ty = target.iloc[i+seqLength-1]
        xdata.append(tx)
        ydata.append(ty)
    return np.array(xdata), np.array(ydata)

nelec_trainx, nelec_trainy = buildDataSet(nelec_trainx, nelec_trainy, seqLength)
nelec_testx, nelec_testy = buildDataSet(nelec_testx, nelec_testy, seqLength)

dhw_trainx, dhw_trainy = buildDataSet(dhw_trainx, dhw_trainy, seqLength)
dhw_testx, dhw_testy = buildDataSet(dhw_testx, dhw_testy, seqLength)

# %%
print(nelec_trainx.shape)
print(nelec_trainy.shape)
print(nelec_testx.shape)
print(nelec_testy.shape)
print(dhw_trainx.shape)
print(dhw_trainy.shape)
print(dhw_testx.shape)
print(dhw_testy.shape)
# Out:
# (20392, 24, 12)
# (20392, 1)
# (8727, 24, 12)
# (8727, 1)
# (20392, 24, 12)
# (20392, 1)
# (8727, 24, 12)
# (8727, 1)

# %%
# 텐서로 변환
nelec_trainx_tensor = torch.FloatTensor(nelec_trainx)
nelec_trainy_tensor = torch.FloatTensor(nelec_trainy)

nelec_testx_tensor = torch.FloatTensor(nelec_testx)
nelec_testy_tensor = torch.FloatTensor(nelec_testy)

dhw_trainx_tensor = torch.FloatTensor(dhw_trainx)
dhw_trainy_tensor = torch.FloatTensor(dhw_trainy)

dhw_testx_tensor = torch.FloatTensor(dhw_testx)
dhw_testy_tensor = torch.FloatTensor(dhw_testy)

# %%
# 텐서 형태로 데이터 정의
nelec_train = TensorDataset(nelec_trainx_tensor, nelec_trainy_tensor)
nelec_test = TensorDataset(nelec_testx_tensor, nelec_testy_tensor)

dhw_train = TensorDataset(dhw_trainx_tensor, dhw_trainy_tensor)
dhw_test = TensorDataset(dhw_testx_tensor, dhw_testy_tensor)

# %%
batch_for_nelec_train = 512
batch_for_nelec_test = 512
batch_for_dhw_train = 512
batch_for_dhw_test = 512

NELEC_train = DataLoader(nelec_train,
                        batch_size=batch_for_nelec_train,
                        shuffle=False,  
                        drop_last=True)

NELEC_test = DataLoader(nelec_test,
                        batch_size=batch_for_nelec_test,
                        shuffle=False,  
                        drop_last=True)

DHW_train = DataLoader(dhw_train,
                        batch_size=batch_for_dhw_train,
                        shuffle=False,  
                        drop_last=True)

DHW_test = DataLoader(dhw_test,
                        batch_size=batch_for_dhw_test,
                        shuffle=False,  
                        drop_last=True)

# %% [markdown]
# # 모델 구조 선언

# %%
import torch.nn as nn
import torch.nn.functional as F

# %% [markdown]
# ### GradientReversalLayer

# %%
class GradientReversalFunction(torch.autograd.Function):
    @staticmethod
    def forward(ctx, x):
        return x.view_as(x)

    @staticmethod
    def backward(ctx, grad_output):
        return (grad_output * -1), None

class GradientReversalLayer(torch.nn.Module):
    def __init__(self):
        super(GradientReversalLayer, self).__init__()

    def forward(self, x):
        return GradientReversalFunction.apply(x)

# %% [markdown]
# ### LSTM for Feature Extraction

# %%
class Swish(nn.Module):
    def __init__(self):
        super().__init__()
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        return x * self.sigmoid(x)

# %%
class Seq2SeqModel(nn.Module):
    def __init__(self):
        super(Seq2SeqModel, self).__init__()
        
        # for feature extracting
        self.conv1 = nn.Conv1d(12, 64, kernel_size=1)
        self.pool1 = nn.MaxPool1d(kernel_size=2, stride=1, padding=0)
        self.conv2 = nn.Conv1d(64, 32, kernel_size=1)
        self.pool2 = nn.MaxPool1d(kernel_size=2, stride=1, padding=0)
        self.conv3 = nn.Conv1d(32, 128, kernel_size=1)
        self.pool3 = nn.MaxPool1d(kernel_size=2, stride=1, padding=0)
        
        # Encoder
        self.encoder1 = nn.LSTM(128, 64, batch_first=True, bias=False)
        self.encoder2 = nn.LSTM(64, 32, batch_first=True, bias=False)
        self.encoder3 = nn.LSTM(32, 128, batch_first=True, bias=False)
        
        # Decoder
        self.decoder1 = nn.LSTM(128, 128, batch_first=True, bias=False)
        self.decoder2 = nn.LSTM(128, 32, batch_first=True, bias=False)
        self.decoder3 = nn.LSTM(32, 64, batch_first=True, bias=False)
        
        self.flatten = nn.Flatten()
        self.dense = nn.Linear(24 * 64, 1)
        self.tanh = nn.Tanh()
        self.swish = Swish()
        
    def forward(self, x):
        x = x.transpose(1,2)
        x = self.conv1(x)
        x = self.swish(x)
        x = x.transpose(2,1)
        x = self.pool1(x)
        x = F.pad(x, (0, 1), 'replicate', 0)
        
        x = x.transpose(1,2)
        x = self.conv2(x)
        x = self.swish(x)
        x = x.transpose(2,1)
        x = self.pool2(x)
        x = F.pad(x, (0, 1), 'replicate', 0)
        
        x = x.transpose(1,2)
        x = self.conv3(x)
        x = self.swish(x)
        x = x.transpose(2,1)
        x = self.pool3(x)
        x = F.pad(x, (0, 1), 'replicate', 0)
        
        #x = x.transpose(2,1)
        x, _ = self.encoder1(x)
        x = self.tanh(x)
        x, _ = self.encoder2(x)
        x = self.tanh(x)
        #x, (h, c) = self.encoder3(x)
        #x = self.tanh(x)
        #x, _ = self.decoder1(x, (h, c))
        #x = self.tanh(x)
        #x, _ = self.decoder2(x)
        #x = self.tanh(x)
        #x, _ = self.decoder3(x)
        #x = self.tanh(x)
        x = x[:,-1]
        return x

# %%
# class lstm(nn.Module):
#     def __init__(self):
#         super(lstm, self).__init__()
#         self.lstm1 = nn.LSTM(12, 64, batch_first=True)
#         self.bn1 = nn.BatchNorm1d(24)
#         self.lstm2 = nn.LSTM(64, 64, batch_first=True)
        
#         self.fc = nn.Linear(64, 64)
#         self.dropout = nn.Dropout(0.6)
#         self.relu = nn.ReLU()

        
#     def forward(self, x):
#         x, (h0, c0) = self.lstm1(x)
#         x = self.bn1(x)
#         x = self.relu(x)
#         x = self.dropout(x)
        
#         x, _ = self.lstm2(x, (h0, c0))
#         x = self.bn1(x)
#         x = self.relu(x)
#         x = self.dropout(x)
        
#         x = x[:,-1]

#         return x

# %% [markdown]
# ### Domain Regression

# %%
class domain_regression(nn.Module):
    def __init__(self):
        super(domain_regression, self).__init__()
        self.regression_layer1 = nn.Linear(32, 100)
        self.regression_layer4 = nn.Linear(100, 1)
        self.bn1 = nn.BatchNorm1d(100)
        self.dropout = nn.Dropout(0.6)
        self.relu = nn.ReLU()
    def forward(self, x):
        x = self.bn1(self.regression_layer1(x))
        x = self.relu(x)
        x = self.dropout(x)
        x = self.regression_layer4(x)
        
        return x

# %% [markdown]
# ### Domain Classification

# %%
class domain_classfication(nn.Module):
    def __init__(self):
        super(domain_classfication, self).__init__()
        self.classification_layer0 = GradientReversalLayer()
        self.classification_layer1 = nn.Linear(32, 100)
        self.classification_layer4 = nn.Linear(100, 1)
        self.relu = nn.ReLU()
        self.bn1 = nn.BatchNorm1d(100)
        self.dropout = nn.Dropout(0.6)
    def forward(self, x):
        x = self.classification_layer0(x)
        x = self.bn1(self.classification_layer1(x))
        x = self.relu(x)
        x = self.dropout(x)
        x = self.classification_layer4(x)
        
        return x

# %% [markdown]
# ### Set the DANN

# %%
class dann(nn.Module):
    def __init__(self, lstm):
        super(dann, self).__init__()
        self.lstm = lstm
        self.regression = domain_regression()
        self.classification = domain_classfication()
        
    def forward(self, x):
        feature = self.lstm(x)
        reg_output = self.regression(feature)
        cla_output = self.classification(feature)
        
        return reg_output, cla_output

# %% [markdown]
# ### Loss 선언

# %%
class dann_loss(nn.Module):
    def __init__(self):
        super(dann_loss, self).__init__()
        self.reg = nn.L1Loss()
        self.cla = nn.BCEWithLogitsLoss()
        
    def forward(self, result, reg_real, domain_num, alpha=1):
        reg_output, cla_output = result
        batch_size = reg_output.shape[0]
        cla_target = torch.FloatTensor([domain_num] * batch_size).unsqueeze(1).to(device)
        
        reg_loss = self.reg(reg_output, reg_real)
        cla_loss = self.cla(cla_output, cla_target)
        cla_loss2 = cla_loss * alpha
        
        loss = reg_loss + cla_loss2
        
        return loss, reg_loss, cla_loss2

# %%
my_lstm = Seq2SeqModel().to(device)
model = dann(my_lstm).to(device)
loss_fn = dann_loss().to(device)

# %% [markdown]
# # 훈련

# %%
from torch.optim.lr_scheduler import LinearLR

alpha = 1.0
epochs = 200
model.train() # 훈련 모드 설정

optimizer= torch.optim.Adamax(model.parameters(), lr=0.001)#, weight_decay=0.01)
scheduler = LinearLR(optimizer, start_factor=1.0, end_factor=0.0, total_iters = epochs * len(NELEC_train))

patience = 100  # Early stopping을 위한 기다리는 최대 epoch 수
best_loss = float('inf')
best_source_loss = float('inf')
best_model_state_dict = None
counter = 10  # Early stopping 카운터

for i in range(1, epochs + 1):
    total_loss = 0
    source_total_loss = 0
    target_total_loss = 0
    src_reg_total = 0
    src_cla_total = 0
    tar_reg_total = 0
    tar_cal_total = 0
    reg_loss_total = 0
    cla_loss_total = 0
    for step, (source_data, target_data) in enumerate(zip(NELEC_train, DHW_train)):
        source_x = source_data[0].to(device)
        source_y = source_data[1].to(device)
        target_x = target_data[0].to(device)
        target_y = target_data[1].to(device)
        # 순전파
        source_result = model(source_x)
        target_result = model(target_x)
        # 순전파 loss
        source_loss, source_reg_loss, source_cla_loss = loss_fn(source_result, source_y, 0, alpha=alpha) # 소스 도메인 레이블 0
        target_loss, target_reg_loss, target_cla_loss = loss_fn(target_result, target_y, 1, alpha=alpha) # 타겟 도메인 레이블 1
        
        loss = source_loss + target_loss
        reg_loss = source_reg_loss + target_reg_loss
        cla_loss = source_cla_loss + target_cla_loss

        reg_loss_total += reg_loss.item()
        cla_loss_total += cla_loss.item()
        
        total_loss += loss.item()
        
        # 그래디언트 계산 및 업데이트
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        scheduler.step()
        
        # Early stopping 확인
    if total_loss / len(NELEC_train) < best_loss:
        best_loss = total_loss / len(NELEC_train)
        best_model_state_dict = model.state_dict()
        counter = 0  # Counter 초기화
    else:
        counter += 1
        if counter >= patience:
            print(f'Early stopping at epoch {i}')
            break

    print('Epoch : %d, Total Avg Loss : %.4f' % (i, total_loss / len(NELEC_train)))     
    print('Avg Regression Loss : %.4f' % (reg_loss_total / len(NELEC_train)))
    print('Avg Classification Loss : %.4f' % (cla_loss_total / len(NELEC_train)))
    print('')


# 최상의 모델을 파일로 저장
if best_model_state_dict is not None:
    torch.save(best_model_state_dict, '091423_in_the_lab3.pth')
    #torch.save(model, "model.pth")
# Out:
# Epoch : 1, Total Avg Loss : 1.9777
# Avg Regression Loss : 0.5911
# Avg Classification Loss : 1.3866
#
# Epoch : 2, Total Avg Loss : 1.8594
# Avg Regression Loss : 0.4719
# Avg Classification Loss : 1.3874
#
# Epoch : 3, Total Avg Loss : 1.7956
# Avg Regression Loss : 0.4117
# Avg Classification Loss : 1.3839
#
# Epoch : 4, Total Avg Loss : 1.7525
# Avg Regression Loss : 0.3745
# Avg Classification Loss : 1.3780
#
# Epoch : 5, Total Avg Loss : 1.7330
# Avg Regression Loss : 0.3581
# Avg Classification Loss : 1.3749
#
# Epoch : 6, Total Avg Loss : 1.7185
# Avg Regression Loss : 0.3465
# Avg Classification Loss : 1.3720
#
# Epoch : 7, Total Avg Loss : 1.7142
# Avg Regression Loss : 0.3418
# Avg Classification Loss : 1.3724
#
# Epoch : 8, Total Avg Loss : 1.7123
# Avg Regression Loss : 0.3405
# Avg Classification Loss : 1.3718
#
# Epoch : 9, Total Avg Loss : 1.7161
# Avg Regression Loss : 0.3421
# Avg Classification Loss : 1.3739
#
# Epoch : 10, Total Avg Loss : 1.7031
# Avg Regression Loss : 0.3313
# Avg Classification Loss : 1.3718
#
# Epoch : 11, Total Avg Loss : 1.6860
# Avg Regression Loss : 0.3172
# Avg Classification Loss : 1.3688
#
# Epoch : 12, Total Avg Loss : 1.6740
# Avg Regression Loss : 0.3073
# Avg Classification Loss : 1.3667
#
# Epoch : 13, Total Avg Loss : 1.6647
# Avg Regression Loss : 0.2989
# Avg Classification Loss : 1.3659
#
# Epoch : 14, Total Avg Loss : 1.6693
# Avg Regression Loss : 0.3020
# Avg Classification Loss : 1.3673
#
# Epoch : 15, Total Avg Loss : 1.6674
# Avg Regression Loss : 0.3039
# Avg Classification Loss : 1.3636
#
# Epoch : 16, Total Avg Loss : 1.6525
# Avg Regression Loss : 0.2928
# Avg Classification Loss : 1.3597
#
# Epoch : 17, Total Avg Loss : 1.6567
# Avg Regression Loss : 0.2914
# Avg Classification Loss : 1.3653
#
# Epoch : 18, Total Avg Loss : 1.6326
# Avg Regression Loss : 0.2728
# Avg Classification Loss : 1.3597
#
# Epoch : 19, Total Avg Loss : 1.6511
# Avg Regression Loss : 0.2862
# Avg Classification Loss : 1.3649
#
# Epoch : 20, Total Avg Loss : 1.6631
# Avg Regression Loss : 0.2946
# Avg Classification Loss : 1.3685
#
# Epoch : 21, Total Avg Loss : 1.6641
# Avg Regression Loss : 0.2886
# Avg Classification Loss : 1.3755
#
# Epoch : 22, Total Avg Loss : 1.6489
# Avg Regression Loss : 0.2733
# Avg Classification Loss : 1.3756
#
# Epoch : 23, Total Avg Loss : 1.6375
# Avg Regression Loss : 0.2663
# Avg Classification Loss : 1.3713
#
# Epoch : 24, Total Avg Loss : 1.6482
# Avg Regression Loss : 0.2730
# Avg Classification Loss : 1.3752
#
# Epoch : 25, Total Avg Loss : 1.6709
# Avg Regression Loss : 0.2868
# Avg Classification Loss : 1.3841
#
# Epoch : 26, Total Avg Loss : 1.6531
# Avg Regression Loss : 0.2702
# Avg Classification Loss : 1.3829
#
# Epoch : 27, Total Avg Loss : 1.6107
# Avg Regression Loss : 0.2432
# Avg Classification Loss : 1.3675
#
# Epoch : 28, Total Avg Loss : 1.6039
# Avg Regression Loss : 0.2390
# Avg Classification Loss : 1.3649
#
# Epoch : 29, Total Avg Loss : 1.6017
# Avg Regression Loss : 0.2378
# Avg Classification Loss : 1.3639
#
# Epoch : 30, Total Avg Loss : 1.5947
# Avg Regression Loss : 0.2332
# Avg Classification Loss : 1.3615
#
# Epoch : 31, Total Avg Loss : 1.6163
# Avg Regression Loss : 0.2498
# Avg Classification Loss : 1.3664
#
# Epoch : 32, Total Avg Loss : 1.5976
# Avg Regression Loss : 0.2364
# Avg Classification Loss : 1.3612
#
# Epoch : 33, Total Avg Loss : 1.6020
# Avg Regression Loss : 0.2410
# Avg Classification Loss : 1.3610
#
# Epoch : 34, Total Avg Loss : 1.5853
# Avg Regression Loss : 0.2278
# Avg Classification Loss : 1.3575
#
# Epoch : 35, Total Avg Loss : 1.5765
# Avg Regression Loss : 0.2226
# Avg Classification Loss : 1.3538
#
# Epoch : 36, Total Avg Loss : 1.5736
# Avg Regression Loss : 0.2199
# Avg Classification Loss : 1.3537
#
# Epoch : 37, Total Avg Loss : 1.5860
# Avg Regression Loss : 0.2334
# Avg Classification Loss : 1.3525
#
# Epoch : 38, Total Avg Loss : 1.6122
# Avg Regression Loss : 0.2474
# Avg Classification Loss : 1.3648
#
# Epoch : 39, Total Avg Loss : 1.5935
# Avg Regression Loss : 0.2362
# Avg Classification Loss : 1.3573
#
# Epoch : 40, Total Avg Loss : 1.6012
# Avg Regression Loss : 0.2441
# Avg Classification Loss : 1.3571
#
# Epoch : 41, Total Avg Loss : 1.5729
# Avg Regression Loss : 0.2240
# Avg Classification Loss : 1.3489
#
# Epoch : 42, Total Avg Loss : 1.5929
# Avg Regression Loss : 0.2363
# Avg Classification Loss : 1.3565
#
# Epoch : 43, Total Avg Loss : 1.5827
# Avg Regression Loss : 0.2307
# Avg Classification Loss : 1.3519
#
# Epoch : 44, Total Avg Loss : 1.6041
# Avg Regression Loss : 0.2429
# Avg Classification Loss : 1.3612
#
# Epoch : 45, Total Avg Loss : 1.5811
# Avg Regression Loss : 0.2251
# Avg Classification Loss : 1.3560
#
# Epoch : 46, Total Avg Loss : 1.5889
# Avg Regression Loss : 0.2304
# Avg Classification Loss : 1.3584
#
# Epoch : 47, Total Avg Loss : 1.5775
# Avg Regression Loss : 0.2225
# Avg Classification Loss : 1.3550
#
# Epoch : 48, Total Avg Loss : 1.5715
# Avg Regression Loss : 0.2174
# Avg Classification Loss : 1.3541
#
# Epoch : 49, Total Avg Loss : 1.5825
# Avg Regression Loss : 0.2235
# Avg Classification Loss : 1.3590
#
# Epoch : 50, Total Avg Loss : 1.5806
# Avg Regression Loss : 0.2241
# Avg Classification Loss : 1.3565
#
# Epoch : 51, Total Avg Loss : 1.5826
# Avg Regression Loss : 0.2241
# Avg Classification Loss : 1.3585
#
# Epoch : 52, Total Avg Loss : 1.5783
# Avg Regression Loss : 0.2234
# Avg Classification Loss : 1.3549
#
# Epoch : 53, Total Avg Loss : 1.5849
# Avg Regression Loss : 0.2279
# Avg Classification Loss : 1.3570
#
# Epoch : 54, Total Avg Loss : 1.5721
# Avg Regression Loss : 0.2192
# Avg Classification Loss : 1.3529
#
# Epoch : 55, Total Avg Loss : 1.5672
# Avg Regression Loss : 0.2133
# Avg Classification Loss : 1.3539
#
# Epoch : 56, Total Avg Loss : 1.5617
# Avg Regression Loss : 0.2086
# Avg Classification Loss : 1.3532
#
# Epoch : 57, Total Avg Loss : 1.5644
# Avg Regression Loss : 0.2102
# Avg Classification Loss : 1.3543
#
# Epoch : 58, Total Avg Loss : 1.5728
# Avg Regression Loss : 0.2165
# Avg Classification Loss : 1.3564
#
# Epoch : 59, Total Avg Loss : 1.5801
# Avg Regression Loss : 0.2231
# Avg Classification Loss : 1.3570
#
# Epoch : 60, Total Avg Loss : 1.5765
# Avg Regression Loss : 0.2228
# Avg Classification Loss : 1.3537
#
# Epoch : 61, Total Avg Loss : 1.5591
# Avg Regression Loss : 0.2104
# Avg Classification Loss : 1.3487
#
# Epoch : 62, Total Avg Loss : 1.5527
# Avg Regression Loss : 0.2054
# Avg Classification Loss : 1.3473
#
# Epoch : 63, Total Avg Loss : 1.5553
# Avg Regression Loss : 0.2045
# Avg Classification Loss : 1.3509
#
# Epoch : 64, Total Avg Loss : 1.5547
# Avg Regression Loss : 0.2044
# Avg Classification Loss : 1.3502
#
# Epoch : 65, Total Avg Loss : 1.5576
# Avg Regression Loss : 0.2038
# Avg Classification Loss : 1.3538
#
# Epoch : 66, Total Avg Loss : 1.5727
# Avg Regression Loss : 0.2123
# Avg Classification Loss : 1.3604
#
# Epoch : 67, Total Avg Loss : 1.5806
# Avg Regression Loss : 0.2125
# Avg Classification Loss : 1.3680
#
# Epoch : 68, Total Avg Loss : 1.5761
# Avg Regression Loss : 0.2096
# Avg Classification Loss : 1.3665
#
# Epoch : 69, Total Avg Loss : 1.5922
# Avg Regression Loss : 0.2122
# Avg Classification Loss : 1.3800
#
# Epoch : 70, Total Avg Loss : 1.6057
# Avg Regression Loss : 0.2131
# Avg Classification Loss : 1.3926
#
# Epoch : 71, Total Avg Loss : 1.6043
# Avg Regression Loss : 0.2099
# Avg Classification Loss : 1.3944
#
# Epoch : 72, Total Avg Loss : 1.6026
# Avg Regression Loss : 0.2120
# Avg Classification Loss : 1.3907
#
# Epoch : 73, Total Avg Loss : 1.5837
# Avg Regression Loss : 0.1995
# Avg Classification Loss : 1.3842
#
# Epoch : 74, Total Avg Loss : 1.5804
# Avg Regression Loss : 0.1982
# Avg Classification Loss : 1.3822
#
# Epoch : 75, Total Avg Loss : 1.5814
# Avg Regression Loss : 0.1973
# Avg Classification Loss : 1.3842
#
# Epoch : 76, Total Avg Loss : 1.5910
# Avg Regression Loss : 0.2066
# Avg Classification Loss : 1.3844
#
# Epoch : 77, Total Avg Loss : 1.5995
# Avg Regression Loss : 0.2109
# Avg Classification Loss : 1.3887
#
# Epoch : 78, Total Avg Loss : 1.5872
# Avg Regression Loss : 0.2107
# Avg Classification Loss : 1.3765
#
# Epoch : 79, Total Avg Loss : 1.5642
# Avg Regression Loss : 0.2002
# Avg Classification Loss : 1.3640
#
# Epoch : 80, Total Avg Loss : 1.5580
# Avg Regression Loss : 0.2009
# Avg Classification Loss : 1.3571
#
# Epoch : 81, Total Avg Loss : 1.5519
# Avg Regression Loss : 0.1918
# Avg Classification Loss : 1.3600
#
# Epoch : 82, Total Avg Loss : 1.5474
# Avg Regression Loss : 0.1866
# Avg Classification Loss : 1.3608
#
# Epoch : 83, Total Avg Loss : 1.5497
# Avg Regression Loss : 0.1852
# Avg Classification Loss : 1.3645
#
# Epoch : 84, Total Avg Loss : 1.5601
# Avg Regression Loss : 0.1921
# Avg Classification Loss : 1.3680
#
# Epoch : 85, Total Avg Loss : 1.5524
# Avg Regression Loss : 0.1895
# Avg Classification Loss : 1.3628
#
# Epoch : 86, Total Avg Loss : 1.5608
# Avg Regression Loss : 0.1971
# Avg Classification Loss : 1.3637
#
# Epoch : 87, Total Avg Loss : 1.5654
# Avg Regression Loss : 0.2000
# Avg Classification Loss : 1.3654
#
# Epoch : 88, Total Avg Loss : 1.5796
# Avg Regression Loss : 0.2071
# Avg Classification Loss : 1.3724
#
# Epoch : 89, Total Avg Loss : 1.5795
# Avg Regression Loss : 0.2067
# Avg Classification Loss : 1.3728
#
# Epoch : 90, Total Avg Loss : 1.5679
# Avg Regression Loss : 0.1972
# Avg Classification Loss : 1.3707
#
# Epoch : 91, Total Avg Loss : 1.5748
# Avg Regression Loss : 0.1994
# Avg Classification Loss : 1.3754
#
# Epoch : 92, Total Avg Loss : 1.5900
# Avg Regression Loss : 0.2040
# Avg Classification Loss : 1.3860
#
# Epoch : 93, Total Avg Loss : 1.6117
# Avg Regression Loss : 0.2149
# Avg Classification Loss : 1.3968
#
# Epoch : 94, Total Avg Loss : 1.5745
# Avg Regression Loss : 0.2035
# Avg Classification Loss : 1.3710
#
# Epoch : 95, Total Avg Loss : 1.5739
# Avg Regression Loss : 0.1986
# Avg Classification Loss : 1.3753
#
# Epoch : 96, Total Avg Loss : 1.6475
# Avg Regression Loss : 0.2187
# Avg Classification Loss : 1.4289
#
# Epoch : 97, Total Avg Loss : 1.6708
# Avg Regression Loss : 0.2424
# Avg Classification Loss : 1.4283
#
# Epoch : 98, Total Avg Loss : 1.7910
# Avg Regression Loss : 0.2797
# Avg Classification Loss : 1.5113
#
# Epoch : 99, Total Avg Loss : 1.6933
# Avg Regression Loss : 0.2420
# Avg Classification Loss : 1.4513
#
# Epoch : 100, Total Avg Loss : 1.6602
# Avg Regression Loss : 0.2238
# Avg Classification Loss : 1.4364
#
# Epoch : 101, Total Avg Loss : 1.6778
# Avg Regression Loss : 0.2364
# Avg Classification Loss : 1.4414
#
# Epoch : 102, Total Avg Loss : 1.6360
# Avg Regression Loss : 0.2298
# Avg Classification Loss : 1.4062
#
# Epoch : 103, Total Avg Loss : 1.6089
# Avg Regression Loss : 0.2140
# Avg Classification Loss : 1.3949
#
# Epoch : 104, Total Avg Loss : 1.5971
# Avg Regression Loss : 0.2046
# Avg Classification Loss : 1.3925
#
# Epoch : 105, Total Avg Loss : 1.6001
# Avg Regression Loss : 0.2137
# Avg Classification Loss : 1.3864
#
# Epoch : 106, Total Avg Loss : 1.5815
# Avg Regression Loss : 0.2034
# Avg Classification Loss : 1.3781
#
# Epoch : 107, Total Avg Loss : 1.5677
# Avg Regression Loss : 0.1977
# Avg Classification Loss : 1.3700
#
# Epoch : 108, Total Avg Loss : 1.5623
# Avg Regression Loss : 0.1928
# Avg Classification Loss : 1.3695
#
# Epoch : 109, Total Avg Loss : 1.5706
# Avg Regression Loss : 0.2007
# Avg Classification Loss : 1.3699
#
# Epoch : 110, Total Avg Loss : 1.5709
# Avg Regression Loss : 0.2015
# Avg Classification Loss : 1.3694
#
# Epoch : 111, Total Avg Loss : 1.5626
# Avg Regression Loss : 0.1944
# Avg Classification Loss : 1.3682
#
# Epoch : 112, Total Avg Loss : 1.5612
# Avg Regression Loss : 0.1928
# Avg Classification Loss : 1.3684
#
# Epoch : 113, Total Avg Loss : 1.5657
# Avg Regression Loss : 0.2028
# Avg Classification Loss : 1.3629
#
# Epoch : 114, Total Avg Loss : 1.5594
# Avg Regression Loss : 0.2007
# Avg Classification Loss : 1.3587
#
# Epoch : 115, Total Avg Loss : 1.5609
# Avg Regression Loss : 0.2000
# Avg Classification Loss : 1.3609
#
# Epoch : 116, Total Avg Loss : 1.5477
# Avg Regression Loss : 0.1955
# Avg Classification Loss : 1.3522
#
# Epoch : 117, Total Avg Loss : 1.5417
# Avg Regression Loss : 0.1864
# Avg Classification Loss : 1.3553
#
# Epoch : 118, Total Avg Loss : 1.5499
# Avg Regression Loss : 0.1962
# Avg Classification Loss : 1.3537
#
# Epoch : 119, Total Avg Loss : 1.5687
# Avg Regression Loss : 0.2189
# Avg Classification Loss : 1.3499
#
# Epoch : 120, Total Avg Loss : 1.5729
# Avg Regression Loss : 0.2067
# Avg Classification Loss : 1.3662
#
# Epoch : 121, Total Avg Loss : 1.5555
# Avg Regression Loss : 0.1959
# Avg Classification Loss : 1.3596
#
# Epoch : 122, Total Avg Loss : 1.5559
# Avg Regression Loss : 0.1962
# Avg Classification Loss : 1.3597
#
# Epoch : 123, Total Avg Loss : 1.5533
# Avg Regression Loss : 0.1939
# Avg Classification Loss : 1.3593
#
# Epoch : 124, Total Avg Loss : 1.5655
# Avg Regression Loss : 0.2002
# Avg Classification Loss : 1.3654
#
# Epoch : 125, Total Avg Loss : 1.5739
# Avg Regression Loss : 0.2013
# Avg Classification Loss : 1.3726
#
# Epoch : 126, Total Avg Loss : 1.5693
# Avg Regression Loss : 0.2008
# Avg Classification Loss : 1.3685
#
# Epoch : 127, Total Avg Loss : 1.5652
# Avg Regression Loss : 0.1932
# Avg Classification Loss : 1.3720
#
# Epoch : 128, Total Avg Loss : 1.5414
# Avg Regression Loss : 0.1871
# Avg Classification Loss : 1.3543
#
# Epoch : 129, Total Avg Loss : 1.5458
# Avg Regression Loss : 0.1906
# Avg Classification Loss : 1.3553
#
# Epoch : 130, Total Avg Loss : 1.5491
# Avg Regression Loss : 0.1911
# Avg Classification Loss : 1.3580
#
# Epoch : 131, Total Avg Loss : 1.5476
# Avg Regression Loss : 0.1929
# Avg Classification Loss : 1.3547
#
# Epoch : 132, Total Avg Loss : 1.5375
# Avg Regression Loss : 0.1889
# Avg Classification Loss : 1.3486
#
# Epoch : 133, Total Avg Loss : 1.5333
# Avg Regression Loss : 0.1863
# Avg Classification Loss : 1.3470
#
# Epoch : 134, Total Avg Loss : 1.5308
# Avg Regression Loss : 0.1844
# Avg Classification Loss : 1.3463
#
# Epoch : 135, Total Avg Loss : 1.5339
# Avg Regression Loss : 0.1851
# Avg Classification Loss : 1.3488
#
# Epoch : 136, Total Avg Loss : 1.5385
# Avg Regression Loss : 0.1874
# Avg Classification Loss : 1.3511
#
# Epoch : 137, Total Avg Loss : 1.5522
# Avg Regression Loss : 0.1907
# Avg Classification Loss : 1.3615
#
# Epoch : 138, Total Avg Loss : 1.5674
# Avg Regression Loss : 0.1930
# Avg Classification Loss : 1.3743
#
# Epoch : 139, Total Avg Loss : 1.5550
# Avg Regression Loss : 0.1890
# Avg Classification Loss : 1.3659
#
# Epoch : 140, Total Avg Loss : 1.5496
# Avg Regression Loss : 0.1870
# Avg Classification Loss : 1.3626
#
# Epoch : 141, Total Avg Loss : 1.5585
# Avg Regression Loss : 0.1878
# Avg Classification Loss : 1.3707
#
# Epoch : 142, Total Avg Loss : 1.5543
# Avg Regression Loss : 0.1850
# Avg Classification Loss : 1.3693
#
# Epoch : 143, Total Avg Loss : 1.5519
# Avg Regression Loss : 0.1864
# Avg Classification Loss : 1.3655
#
# Epoch : 144, Total Avg Loss : 1.5510
# Avg Regression Loss : 0.1887
# Avg Classification Loss : 1.3624
#
# Epoch : 145, Total Avg Loss : 1.5394
# Avg Regression Loss : 0.1821
# Avg Classification Loss : 1.3573
#
# Epoch : 146, Total Avg Loss : 1.5388
# Avg Regression Loss : 0.1788
# Avg Classification Loss : 1.3600
#
# Epoch : 147, Total Avg Loss : 1.5461
# Avg Regression Loss : 0.1807
# Avg Classification Loss : 1.3654
#
# Epoch : 148, Total Avg Loss : 1.5465
# Avg Regression Loss : 0.1812
# Avg Classification Loss : 1.3653
#
# Epoch : 149, Total Avg Loss : 1.5517
# Avg Regression Loss : 0.1845
# Avg Classification Loss : 1.3672
#
# Epoch : 150, Total Avg Loss : 1.5510
# Avg Regression Loss : 0.1861
# Avg Classification Loss : 1.3649
#
# Epoch : 151, Total Avg Loss : 1.5503
# Avg Regression Loss : 0.1864
# Avg Classification Loss : 1.3639
#
# Epoch : 152, Total Avg Loss : 1.5505
# Avg Regression Loss : 0.1857
# Avg Classification Loss : 1.3648
#
# Epoch : 153, Total Avg Loss : 1.5467
# Avg Regression Loss : 0.1850
# Avg Classification Loss : 1.3617
#
# Epoch : 154, Total Avg Loss : 1.5480
# Avg Regression Loss : 0.1830
# Avg Classification Loss : 1.3650
#
# Epoch : 155, Total Avg Loss : 1.5578
# Avg Regression Loss : 0.1835
# Avg Classification Loss : 1.3743
#
# Epoch : 156, Total Avg Loss : 1.5705
# Avg Regression Loss : 0.1842
# Avg Classification Loss : 1.3863
#
# Epoch : 157, Total Avg Loss : 1.5517
# Avg Regression Loss : 0.1795
# Avg Classification Loss : 1.3722
#
# Epoch : 158, Total Avg Loss : 1.5450
# Avg Regression Loss : 0.1797
# Avg Classification Loss : 1.3653
#
# Epoch : 159, Total Avg Loss : 1.5593
# Avg Regression Loss : 0.1833
# Avg Classification Loss : 1.3761
#
# Epoch : 160, Total Avg Loss : 1.5717
# Avg Regression Loss : 0.1877
# Avg Classification Loss : 1.3841
#
# Epoch : 161, Total Avg Loss : 1.5818
# Avg Regression Loss : 0.1888
# Avg Classification Loss : 1.3931
#
# Epoch : 162, Total Avg Loss : 1.5878
# Avg Regression Loss : 0.1910
# Avg Classification Loss : 1.3968
#
# Epoch : 163, Total Avg Loss : 1.5602
# Avg Regression Loss : 0.1811
# Avg Classification Loss : 1.3791
#
# Epoch : 164, Total Avg Loss : 1.5647
# Avg Regression Loss : 0.1846
# Avg Classification Loss : 1.3801
#
# Epoch : 165, Total Avg Loss : 1.5556
# Avg Regression Loss : 0.1835
# Avg Classification Loss : 1.3721
#
# Epoch : 166, Total Avg Loss : 1.5619
# Avg Regression Loss : 0.1857
# Avg Classification Loss : 1.3762
#
# Epoch : 167, Total Avg Loss : 1.5604
# Avg Regression Loss : 0.1869
# Avg Classification Loss : 1.3736
#
# Epoch : 168, Total Avg Loss : 1.5643
# Avg Regression Loss : 0.1916
# Avg Classification Loss : 1.3727
#
# Epoch : 169, Total Avg Loss : 1.5568
# Avg Regression Loss : 0.1836
# Avg Classification Loss : 1.3732
#
# Epoch : 170, Total Avg Loss : 1.5542
# Avg Regression Loss : 0.1831
# Avg Classification Loss : 1.3711
#
# Epoch : 171, Total Avg Loss : 1.5794
# Avg Regression Loss : 0.1859
# Avg Classification Loss : 1.3935
#
# Epoch : 172, Total Avg Loss : 1.6141
# Avg Regression Loss : 0.1926
# Avg Classification Loss : 1.4215
#
# Epoch : 173, Total Avg Loss : 1.6052
# Avg Regression Loss : 0.1942
# Avg Classification Loss : 1.4110
#
# Epoch : 174, Total Avg Loss : 1.5989
# Avg Regression Loss : 0.1919
# Avg Classification Loss : 1.4071
#
# Epoch : 175, Total Avg Loss : 1.6029
# Avg Regression Loss : 0.1900
# Avg Classification Loss : 1.4129
#
# Epoch : 176, Total Avg Loss : 1.5967
# Avg Regression Loss : 0.1872
# Avg Classification Loss : 1.4095
#
# Epoch : 177, Total Avg Loss : 1.5834
# Avg Regression Loss : 0.1864
# Avg Classification Loss : 1.3969
#
# Epoch : 178, Total Avg Loss : 1.5874
# Avg Regression Loss : 0.1893
# Avg Classification Loss : 1.3981
#
# Epoch : 179, Total Avg Loss : 1.5899
# Avg Regression Loss : 0.1890
# Avg Classification Loss : 1.4009
#
# Epoch : 180, Total Avg Loss : 1.5884
# Avg Regression Loss : 0.1877
# Avg Classification Loss : 1.4006
#
# Epoch : 181, Total Avg Loss : 1.5844
# Avg Regression Loss : 0.1859
# Avg Classification Loss : 1.3986
#
# Epoch : 182, Total Avg Loss : 1.5900
# Avg Regression Loss : 0.1841
# Avg Classification Loss : 1.4060
#
# Epoch : 183, Total Avg Loss : 1.5972
# Avg Regression Loss : 0.1850
# Avg Classification Loss : 1.4122
#
# Epoch : 184, Total Avg Loss : 1.6045
# Avg Regression Loss : 0.1866
# Avg Classification Loss : 1.4179
#
# Epoch : 185, Total Avg Loss : 1.6104
# Avg Regression Loss : 0.1882
# Avg Classification Loss : 1.4221
#
# Epoch : 186, Total Avg Loss : 1.6092
# Avg Regression Loss : 0.1873
# Avg Classification Loss : 1.4219
#
# Epoch : 187, Total Avg Loss : 1.6041
# Avg Regression Loss : 0.1866
# Avg Classification Loss : 1.4175
#
# Epoch : 188, Total Avg Loss : 1.6004
# Avg Regression Loss : 0.1881
# Avg Classification Loss : 1.4123
#
# Epoch : 189, Total Avg Loss : 1.5939
# Avg Regression Loss : 0.1860
# Avg Classification Loss : 1.4079
#
# Epoch : 190, Total Avg Loss : 1.5881
# Avg Regression Loss : 0.1836
# Avg Classification Loss : 1.4045
#
# Epoch : 191, Total Avg Loss : 1.5833
# Avg Regression Loss : 0.1832
# Avg Classification Loss : 1.4002
#
# Epoch : 192, Total Avg Loss : 1.5825
# Avg Regression Loss : 0.1823
# Avg Classification Loss : 1.4002
#
# Epoch : 193, Total Avg Loss : 1.5764
# Avg Regression Loss : 0.1808
# Avg Classification Loss : 1.3956
#
# Epoch : 194, Total Avg Loss : 1.5750
# Avg Regression Loss : 0.1798
# Avg Classification Loss : 1.3952
#
# Epoch : 195, Total Avg Loss : 1.5742
# Avg Regression Loss : 0.1800
# Avg Classification Loss : 1.3942
#
# Epoch : 196, Total Avg Loss : 1.5753
# Avg Regression Loss : 0.1798
# Avg Classification Loss : 1.3955
#
# Epoch : 197, Total Avg Loss : 1.5697
# Avg Regression Loss : 0.1793
# Avg Classification Loss : 1.3904
#
# Epoch : 198, Total Avg Loss : 1.5714
# Avg Regression Loss : 0.1791
# Avg Classification Loss : 1.3923
#
# Epoch : 199, Total Avg Loss : 1.5709
# Avg Regression Loss : 0.1790
# Avg Classification Loss : 1.3919
#
# Epoch : 200, Total Avg Loss : 1.5709
# Avg Regression Loss : 0.1790
# Avg Classification Loss : 1.3919

# %%
# # 저장된 가중치 불러오기
# model.load_state_dict(torch.load('091423_in_the_lab3.pth'))

# # 가중치 확인
# for name, param in model.named_parameters():
#     if param.requires_grad:
#         #print(f"Layer name: {name}")
#         print(name)
#         print(param.data.shape)

# %%
# # 모델의 가중치를 추출
# weights = []
# for name, param in model.named_parameters():
#     if param.requires_grad:
#         weights.append(param.data)

# # 모든 가중치를 하나의 데이터프레임으로 결합
# all_weights = torch.cat([w.view(-1) for w in weights], dim=0)
# df = pd.DataFrame({'Weight': all_weights.cpu().numpy()})  # .cpu()를 사용하여 GPU 텐서를 CPU로 이동

# # CSV 파일로 저장
# df.to_csv('all_weights.csv', index=False)

# %% [markdown]
# # train 데이터로 테스트

# %%
# 저장된 최상의 소스 모델 불러오기
best_source_model2 = dann(my_lstm).to(device)
best_source_model2.load_state_dict(torch.load('091423_in_the_lab3.pth'))
best_source_model2.eval()  # 평가 모드로 설정

s_pred = []  # MNIST 데이터셋의 예측값을 저장할 리스트
t_pred = []  # SVHN 데이터셋의 예측값을 저장할 리스트
s_real = []
t_real = []
s_d_pred = []
t_d_pred = []

for step, (source_data, target_data) in enumerate(zip(NELEC_train, DHW_train)):
    sourcex = source_data[0].to(device)
    sourcey = source_data[1].to(device)
    targetx = target_data[0].to(device)
    targety = target_data[1].to(device)

    # 저장된 최상의 모델로 예측
    source_domain_label_pred, source_pred = best_source_model2(sourcex)
    target_domain_label_pred, target_pred = best_source_model2(targetx)

    ## 예측값을 리스트에 저장
    s_pred.extend(source_pred.detach().cpu().numpy())
    t_pred.extend(target_pred.detach().cpu().numpy())
    s_real.extend(sourcey.detach().cpu().numpy())
    t_real.extend(targety.detach().cpu().numpy())
    s_d_pred.extend(source_domain_label_pred.detach().cpu().numpy())
    t_d_pred.extend(target_domain_label_pred.detach().cpu().numpy())

# R2 스코어 계산
s_r2 = r2_score(s_real, s_pred)
t_r2 = r2_score(t_real, t_pred)

print('SOURCE R2 Score:', s_r2)
print('TARGET R2 Score:', t_r2)
# Out:
# SOURCE R2 Score: -13.132827461671093
# TARGET R2 Score: -2.876591250581887

# %%
plt.figure(figsize=(40,10))
plt.plot(s_real, color='red', label='source real')
plt.plot(s_pred, color='blue', label='source pred')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(40,10))
plt.plot(t_real, color='red', label='target real')
plt.plot(t_pred, color='blue', label='target pred')
plt.legend()
plt.show()

# %% [markdown]
# # test 데이터로 테스트

# %%
# 저장된 최상의 소스 모델 불러오기
best_source_model2 = dann(my_lstm).to(device)
best_source_model2.load_state_dict(torch.load('091423_in_the_lab3.pth'))
best_source_model2.eval()  # 평가 모드로 설정

s_pred = []  # MNIST 데이터셋의 예측값을 저장할 리스트
t_pred = []  # SVHN 데이터셋의 예측값을 저장할 리스트
s_real = []
t_real = []


for step, (source_data, target_data) in enumerate(zip(NELEC_test, DHW_test)):
    sourcex = source_data[0].to(device)
    sourcey = source_data[1].to(device)
    targetx = target_data[0].to(device)
    targety = target_data[1].to(device)

    # 저장된 최상의 모델로 예측
    _, source_pred = best_source_model2(sourcex)
    _, target_pred = best_source_model2(targetx)

    ## 예측값을 리스트에 저장
    s_pred.extend(source_pred.detach().cpu().numpy())
    t_pred.extend(target_pred.detach().cpu().numpy())
    s_real.extend(sourcey.detach().cpu().numpy())
    t_real.extend(targety.detach().cpu().numpy())

# R2 스코어 계산
s_r2 = r2_score(s_real, s_pred)
t_r2 = r2_score(t_real, t_pred)

print('SOURCE R2 Score:', s_r2)
print('TARGET R2 Score:', t_r2)
# Out:
# SOURCE R2 Score: -11.59407594298095
# TARGET R2 Score: -2.4537544763913806

# %%
plt.figure(figsize=(40,10))
plt.plot(s_real, color='red', label='source real')
plt.plot(s_pred, color='blue', label='source pred')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(40,10))
plt.plot(t_real, color='red', label='target real')
plt.plot(t_pred, color='blue', label='target pred')
plt.legend()
plt.show()

# %%
import winsound as sd
def beepsound():
    fr = 2000    # range : 37 ~ 32767
    du = 800     # 1000 ms ==1second
    sd.Beep(fr, du) # winsound.Beep(frequency, duration)
beepsound()

# %% [markdown]
# ### Domain Embedding Space 시각화

# %%
# 가장 앞 batch의 250개씩의 데이터만 샘플링
source_tsne = DataLoader(nelec_train,
                        batch_size=1000,
                        shuffle=False,  
                        drop_last=True)

target_tsne = DataLoader(dhw_train,
                        batch_size=1000,
                        shuffle=False,  
                        drop_last=True)

source_tsne2 = next(iter(source_tsne))
target_tsne2 = next(iter(target_tsne))

source_x_TNSE = source_tsne2[0].to(device)
source_y_TNSE = source_tsne2[1].to(device)

target_x_TNSE = target_tsne2[0].to(device)
target_y_TNSE = target_tsne2[1].to(device)

# 학습된 모델의 LSTM 부분만 활용 (100차원 임베딩 벡터를 받아오는 과정)
source_vector = model.lstm(source_x_TNSE)
target_vector = model.lstm(target_x_TNSE)

# %%
from sklearn.manifold import TSNE

df = pd.DataFrame(np.concatenate([source_vector.cpu().detach().numpy(), target_vector.cpu().detach().numpy()]))

tsne_np = TSNE(n_components=2).fit_transform(df)
tsne_df = pd.DataFrame(tsne_np, columns=['component 0', 'component 1'])

# %%
tsne_df_0 = tsne_df.loc[:1000]
tsne_df_1 = tsne_df.loc[1000:]

plt.scatter(tsne_df_0['component 0'], tsne_df_0['component 1'], color='green', label='NELEC', alpha=0.5)
plt.scatter(tsne_df_1['component 0'], tsne_df_1['component 1'], color='black', label='DHW', alpha=0.5)

plt.title('alpha = '+ str(alpha))
plt.xlabel('component 0')
plt.ylabel('component 1')
plt.legend()
plt.show()
