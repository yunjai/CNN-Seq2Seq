# %%
from tqdm.notebook import tqdm
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tqdm
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import time
import tensorflow as tf
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import Sequential, load_model

# %%
dhw_merge = pd.read_csv('dhw_merge.csv')
elec_merge  = pd.read_csv('elec_merge.csv')
n_elec_merge = pd.read_csv('nelec_082323.csv')

dhw_merge = dhw_merge.drop(['YEAR'], axis=1)
elec_merge = elec_merge.drop(['YEAR'], axis=1)
n_elec_merge = n_elec_merge.drop(['YEAR'], axis=1)

# %%
# n_elec_merge['date'] = pd.to_datetime(n_elec_merge.iloc[:,:4])
# ne_date = n_elec_merge[['date']]

# %%
# plt.figure(figsize=(8,5))
# plt.ylabel('National Elec consumption')
# plt.plot(ne_date, n_elec_merge['n_elec'], color='red')
# plt.legend()
# plt.show()

# %%
# plt.figure(figsize=(8,5))
# plt.ylabel('Suwon Elec consumption]')
# plt.plot(e_date, elec_merge['ELEC'], color='red')
# plt.legend()
# plt.show()

# %% [markdown]
# ##  For Scaling

# %%
dhw_X = dhw_merge.drop(['DHW'], axis=1)
dhw_Y = dhw_merge[['DHW']]

scaler_dhw = MinMaxScaler()
scaler_dhw.fit(dhw_X)
scaled_dhw_X = scaler_dhw.transform(dhw_X)

new_dhw_X = pd.DataFrame(scaled_dhw_X, index=dhw_X.index, columns=dhw_X.columns)
new_dhw = pd.concat([new_dhw_X, dhw_Y], axis=1)

# %%
elec_X = elec_merge.drop(['ELEC'], axis=1)
elec_Y = elec_merge[['ELEC']]

scaler_elec = MinMaxScaler()
scaler_elec.fit(elec_X)
scaled_elec_X = scaler_elec.transform(elec_X)

new_elec_X = pd.DataFrame(scaled_elec_X, index=elec_X.index, columns=elec_X.columns)
new_elec = pd.concat([new_elec_X, elec_Y], axis=1)

# %%
n_elec_X = n_elec_merge.drop(['n_elec'], axis=1)
n_elec_Y = n_elec_merge[['n_elec']]

scaler_n_elec = MinMaxScaler()
scaler_n_elec.fit(n_elec_X)
scaled_n_elec_X = scaler_n_elec.transform(n_elec_X)

new_n_elec_X = pd.DataFrame(scaled_n_elec_X, index=n_elec_X.index, columns=n_elec_X.columns)
new_n_elec = pd.concat([new_n_elec_X, n_elec_Y], axis=1)

# %%
input_dhw = new_dhw.iloc[:-1,]
target_dhw = new_dhw[['DHW']].iloc[1:]

trainX_dhw, testX_dhw, trainY_dhw, testY_dhw = train_test_split(input_dhw,target_dhw,test_size=0.3,shuffle=False,random_state=0)

# %%
input_elec = new_elec.iloc[:-1,]
target_elec = new_elec[['ELEC']].iloc[1:]

trainX_elec, testX_elec, trainY_elec, testY_elec = train_test_split(input_elec,target_elec,test_size=0.3,shuffle=False,random_state=0)

# %%
input = new_n_elec.iloc[:-1,]
target = new_n_elec[['n_elec']].iloc[1:]

trainX_n_elec, testX_n_elec, trainY_n_elec, testY_n_elec = train_test_split(input,target,test_size=0.3,shuffle=False,random_state=0)

# %%
def buildDataSet(input, target, seqLength):
    xdata = []
    ydata = []
    for i in range(len(input) - seqLength):
        tx = input.iloc[i:i+seqLength]
        ty = target.iloc[i+seqLength-1]
        xdata.append(tx)
        ydata.append(ty)
    return np.array(xdata), np.array(ydata)

# %%
trainx_dhw, trainy_dhw = buildDataSet(trainX_dhw, trainY_dhw, 24)
testx_dhw, testy_dhw = buildDataSet(testX_dhw, testY_dhw, 24)
trainx_elec, trainy_elec = buildDataSet(trainX_elec, trainY_elec, 24)
testx_elec, testy_elec = buildDataSet(testX_elec, testY_elec, 24)
trainx_n_elec, trainy_n_elec = buildDataSet(trainX_n_elec, trainY_n_elec, 24)
testx_n_elec, testy_n_elec = buildDataSet(testX_n_elec, testY_n_elec, 24)

# %% [markdown]
# ## Reverse MinMaxScaler

# %%
def seq2seq_model(input_shape):
    model_input = tf.keras.layers.Input(shape=input_shape)

    # for feature extracting
    conv1 = tf.keras.layers.Conv1D(64, 1, activation='swish')(model_input)
    pool1 = tf.keras.layers.MaxPool1D(pool_size=2, strides=1, padding='same')(conv1)
    conv2 = tf.keras.layers.Conv1D(32, 1, activation='swish')(pool1)
    pool2 = tf.keras.layers.MaxPool1D(pool_size=2, strides=1, padding='same')(conv2)
    conv3 = tf.keras.layers.Conv1D(128, 1, activation='swish')(pool2)
    pool3 = tf.keras.layers.MaxPool1D(pool_size=2, strides=1, padding='same')(conv3)

    # 인코더 - 디코더 선언
    encoder_lstm1 = tf.keras.layers.LSTM(64, return_sequences=True, activation='tanh', use_bias=False)
    encoder_lstm2 = tf.keras.layers.LSTM(32, return_sequences=True, activation='tanh', use_bias=False)
    encoder_lstm3 = tf.keras.layers.LSTM(128, return_state=True, return_sequences=True, activation='tanh', use_bias=False)

    decoder_lstm1 = tf.keras.layers.LSTM(128, return_sequences=True, activation='tanh', use_bias=False)
    decoder_lstm2 = tf.keras.layers.LSTM(32, return_sequences=True, activation='tanh', use_bias=False)
    decoder_lstm3 = tf.keras.layers.LSTM(64, return_sequences=True, activation='tanh', use_bias=False)

    # 인코더
    encoder_output_lstm1 = encoder_lstm1(pool3)
    encoder_output_lstm2 = encoder_lstm2(encoder_output_lstm1)
    encoder_output_lstm3, state_h, state_c = encoder_lstm3(encoder_output_lstm2)

    #디코더
    decoder_lstm1_output = decoder_lstm1(encoder_output_lstm3, initial_state=[state_h, state_c])
    decoder_lstm2_output = decoder_lstm2(decoder_lstm1_output)
    decoder_lstm3_output = decoder_lstm3(decoder_lstm2_output)

    flatten = tf.keras.layers.Flatten()(decoder_lstm3_output)
    model_output = tf.keras.layers.Dense(1, activation='swish')(flatten)
    
    model = tf.keras.models.Model(model_input, model_output)
    
    return model

# %%
model = seq2seq_model(input_shape=(24, 12))
model.summary()
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 24, 12)]     0           []
#
#  conv1d (Conv1D)                (None, 24, 64)       832         ['input_1[0][0]']
#
#  max_pooling1d (MaxPooling1D)   (None, 24, 64)       0           ['conv1d[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 24, 32)       2080        ['max_pooling1d[0][0]']
#
#  max_pooling1d_1 (MaxPooling1D)  (None, 24, 32)      0           ['conv1d_1[0][0]']
#
#  conv1d_2 (Conv1D)              (None, 24, 128)      4224        ['max_pooling1d_1[0][0]']
#
#  max_pooling1d_2 (MaxPooling1D)  (None, 24, 128)     0           ['conv1d_2[0][0]']
#
#  lstm (LSTM)                    (None, 24, 64)       49152       ['max_pooling1d_2[0][0]']
#
#  lstm_1 (LSTM)                  (None, 24, 32)       12288       ['lstm[0][0]']
#
#  lstm_2 (LSTM)                  [(None, 24, 128),    81920       ['lstm_1[0][0]']
#                                  (None, 128),
#                                  (None, 128)]
#
#  lstm_3 (LSTM)                  (None, 24, 128)      131072      ['lstm_2[0][0]',
#                                                                   'lstm_2[0][1]',
#                                                                   'lstm_2[0][2]']
#
#  lstm_4 (LSTM)                  (None, 24, 32)       20480       ['lstm_3[0][0]']
#
#  lstm_5 (LSTM)                  (None, 24, 64)       24576       ['lstm_4[0][0]']
#
#  flatten (Flatten)              (None, 1536)         0           ['lstm_5[0][0]']
#
#  dense (Dense)                  (None, 1)            1537        ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 328,161
# Trainable params: 328,161
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# 모델 컴파일
earlystopping = EarlyStopping(monitor='loss', patience=15)
checkpoint = ModelCheckpoint(moniter='loss',filepath='0920_seq2seq_tensorflow_TEST.h5')
model.compile(loss='mae', optimizer=tf.keras.optimizers.Adamax(learning_rate=3e-4,clipnorm=1.0), metrics=['mae'])
# 모델 요약 정보 출력
hist = model.fit(trainx_elec, trainy_elec, epochs=1000, batch_size=1024, callbacks=[earlystopping,checkpoint])
# Out:
# Epoch 1/1000
# 3/3 [==============================] - 7s 155ms/step - loss: 0.6121 - mae: 0.6121
# Epoch 2/1000
# 3/3 [==============================] - 0s 123ms/step - loss: 0.6115 - mae: 0.6115
# Epoch 3/1000
# 3/3 [==============================] - 0s 124ms/step - loss: 0.6108 - mae: 0.6108
# Epoch 4/1000
# 3/3 [==============================] - 0s 125ms/step - loss: 0.6100 - mae: 0.6100
# Epoch 5/1000
# 3/3 [==============================] - 0s 124ms/step - loss: 0.6091 - mae: 0.6091
# Epoch 6/1000
# 3/3 [==============================] - 0s 142ms/step - loss: 0.6079 - mae: 0.6079
# Epoch 7/1000
# 3/3 [==============================] - 0s 136ms/step - loss: 0.6065 - mae: 0.6065
# Epoch 8/1000
# 3/3 [==============================] - 0s 147ms/step - loss: 0.6046 - mae: 0.6046
# Epoch 9/1000
# 3/3 [==============================] - 0s 125ms/step - loss: 0.6021 - mae: 0.6021
# Epoch 10/1000
# 3/3 [==============================] - 0s 138ms/step - loss: 0.5987 - mae: 0.5987
# Epoch 11/1000
# 3/3 [==============================] - 0s 128ms/step - loss: 0.5941 - mae: 0.5941
# Epoch 12/1000
# 3/3 [==============================] - 0s 129ms/step - loss: 0.5877 - mae: 0.5877
# Epoch 13/1000
# 3/3 [==============================] - 0s 135ms/step - loss: 0.5788 - mae: 0.5788
# Epoch 14/1000
# 3/3 [==============================] - 0s 131ms/step - loss: 0.5661 - mae: 0.5661
# Epoch 15/1000
# 3/3 [==============================] - 0s 135ms/step - loss: 0.5480 - mae: 0.5480
# Epoch 16/1000
# 3/3 [==============================] - 0s 131ms/step - loss: 0.5218 - mae: 0.5218
# Epoch 17/1000
# 3/3 [==============================] - 0s 118ms/step - loss: 0.4833 - mae: 0.4833
# Epoch 18/1000
# 3/3 [==============================] - 0s 131ms/step - loss: 0.4279 - mae: 0.4279
# Epoch 19/1000
# 3/3 [==============================] - 0s 156ms/step - loss: 0.3571 - mae: 0.3571
# Epoch 20/1000
# 3/3 [==============================] - 0s 118ms/step - loss: 0.3011 - mae: 0.3011
# Epoch 21/1000
# 3/3 [==============================] - 0s 132ms/step - loss: 0.3355 - mae: 0.3355
# Epoch 22/1000
# 3/3 [==============================] - 0s 131ms/step - loss: 0.3222 - mae: 0.3222
# Epoch 23/1000
# 3/3 [==============================] - 0s 124ms/step - loss: 0.2972 - mae: 0.2972
# Epoch 24/1000
# 3/3 [==============================] - 0s 131ms/step - loss: 0.2991 - mae: 0.2991
# Epoch 25/1000
# 3/3 [==============================] - 0s 130ms/step - loss: 0.3053 - mae: 0.3053
# Epoch 26/1000
# 3/3 [==============================] - 0s 130ms/step - loss: 0.3017 - mae: 0.3017
# Epoch 27/1000
# 3/3 [==============================] - 0s 134ms/step - loss: 0.2923 - mae: 0.2923
# Epoch 28/1000
# 3/3 [==============================] - 0s 124ms/step - loss: 0.2891 - mae: 0.2891
# Epoch 29/1000
# 3/3 [==============================] - 0s 132ms/step - loss: 0.2910 - mae: 0.2910
# Epoch 30/1000
# 3/3 [==============================] - 0s 136ms/step - loss: 0.2904 - mae: 0.2904
# Epoch 31/1000
# 3/3 [==============================] - 0s 120ms/step - loss: 0.2871 - mae: 0.2871
# Epoch 32/1000
# 3/3 [==============================] - 0s 133ms/step - loss: 0.2851 - mae: 0.2851
# Epoch 33/1000
# 3/3 [==============================] - 0s 131ms/step - loss: 0.2851 - mae: 0.2851
# Epoch 34/1000
# 3/3 [==============================] - 0s 144ms/step - loss: 0.2844 - mae: 0.2844
# Epoch 35/1000
# 3/3 [==============================] - 0s 131ms/step - loss: 0.2828 - mae: 0.2828
# Epoch 36/1000
# 3/3 [==============================] - 0s 133ms/step - loss: 0.2815 - mae: 0.2815
# Epoch 37/1000
# 3/3 [==============================] - 0s 125ms/step - loss: 0.2810 - mae: 0.2810
# Epoch 38/1000
# 3/3 [==============================] - 0s 130ms/step - loss: 0.2799 - mae: 0.2799
# Epoch 39/1000
# 3/3 [==============================] - 0s 134ms/step - loss: 0.2788 - mae: 0.2788
# Epoch 40/1000
# 3/3 [==============================] - 0s 129ms/step - loss: 0.2777 - mae: 0.2777
# Epoch 41/1000
# 3/3 [==============================] - 0s 144ms/step - loss: 0.2768 - mae: 0.2768
# Epoch 42/1000
# 3/3 [==============================] - 0s 125ms/step - loss: 0.2757 - mae: 0.2757
# Epoch 43/1000
# 3/3 [==============================] - 0s 128ms/step - loss: 0.2746 - mae: 0.2746
# Epoch 44/1000
# 3/3 [==============================] - 0s 124ms/step - loss: 0.2736 - mae: 0.2736
# Epoch 45/1000
# 3/3 [==============================] - 0s 126ms/step - loss: 0.2726 - mae: 0.2726
# Epoch 46/1000
# 3/3 [==============================] - 0s 118ms/step - loss: 0.2715 - mae: 0.2715
# Epoch 47/1000
# 3/3 [==============================] - 0s 130ms/step - loss: 0.2703 - mae: 0.2703
# Epoch 48/1000
# 3/3 [==============================] - 0s 118ms/step - loss: 0.2693 - mae: 0.2693
# Epoch 49/1000
# 3/3 [==============================] - 0s 118ms/step - loss: 0.2682 - mae: 0.2682
# Epoch 50/1000
# 3/3 [==============================] - 0s 126ms/step - loss: 0.2669 - mae: 0.2669
# Epoch 51/1000
# 3/3 [==============================] - 0s 128ms/step - loss: 0.2659 - mae: 0.2659
# Epoch 52/1000
# 3/3 [==============================] - 0s 120ms/step - loss: 0.2646 - mae: 0.2646
# Epoch 53/1000
# 3/3 [==============================] - 0s 120ms/step - loss: 0.2633 - mae: 0.2633
# Epoch 54/1000
# 3/3 [==============================] - 0s 119ms/step - loss: 0.2619 - mae: 0.2619
# Epoch 55/1000
# 3/3 [==============================] - 0s 122ms/step - loss: 0.2606 - mae: 0.2606
# Epoch 56/1000
# 3/3 [==============================] - 0s 132ms/step - loss: 0.2593 - mae: 0.2593
# Epoch 57/1000
# 3/3 [==============================] - 0s 121ms/step - loss: 0.2579 - mae: 0.2579
# Epoch 58/1000
# 3/3 [==============================] - 0s 123ms/step - loss: 0.2565 - mae: 0.2565
# Epoch 59/1000
# 3/3 [==============================] - 0s 127ms/step - loss: 0.2551 - mae: 0.2551
# Epoch 60/1000
# 3/3 [==============================] - 0s 125ms/step - loss: 0.2537 - mae: 0.2537
# Epoch 61/1000
# 3/3 [==============================] - 0s 124ms/step - loss: 0.2522 - mae: 0.2522
# Epoch 62/1000
# 3/3 [==============================] - 0s 131ms/step - loss: 0.2509 - mae: 0.2509
# Epoch 63/1000
# 3/3 [==============================] - 0s 122ms/step - loss: 0.2495 - mae: 0.2495
# Epoch 64/1000
# 3/3 [==============================] - 0s 125ms/step - loss: 0.2482 - mae: 0.2482
# Epoch 65/1000
# 3/3 [==============================] - 0s 122ms/step - loss: 0.2468 - mae: 0.2468
# Epoch 66/1000
# 3/3 [==============================] - 0s 129ms/step - loss: 0.2456 - mae: 0.2456
# Epoch 67/1000
# 3/3 [==============================] - 0s 121ms/step - loss: 0.2443 - mae: 0.2443
# Epoch 68/1000
# 3/3 [==============================] - 0s 137ms/step - loss: 0.2432 - mae: 0.2432
# Epoch 69/1000
# 3/3 [==============================] - 0s 130ms/step - loss: 0.2421 - mae: 0.2421
# Epoch 70/1000
# 3/3 [==============================] - 0s 125ms/step - loss: 0.2410 - mae: 0.2410
# Epoch 71/1000
# 3/3 [==============================] - 0s 124ms/step - loss: 0.2401 - mae: 0.2401
# Epoch 72/1000
# 3/3 [==============================] - 0s 118ms/step - loss: 0.2391 - mae: 0.2391
# Epoch 73/1000
# 3/3 [==============================] - 0s 122ms/step - loss: 0.2382 - mae: 0.2382
# Epoch 74/1000
# 3/3 [==============================] - 0s 126ms/step - loss: 0.2375 - mae: 0.2375
# Epoch 75/1000
# 3/3 [==============================] - 0s 129ms/step - loss: 0.2368 - mae: 0.2368
# Epoch 76/1000
# 3/3 [==============================] - 0s 127ms/step - loss: 0.2361 - mae: 0.2361
# Epoch 77/1000
# 3/3 [==============================] - 0s 132ms/step - loss: 0.2356 - mae: 0.2356
# Epoch 78/1000
# 3/3 [==============================] - 0s 123ms/step - loss: 0.2351 - mae: 0.2351
# Epoch 79/1000
# 3/3 [==============================] - 0s 120ms/step - loss: 0.2346 - mae: 0.2346
# Epoch 80/1000
# 3/3 [==============================] - 0s 116ms/step - loss: 0.2342 - mae: 0.2342
# Epoch 81/1000
# 3/3 [==============================] - 0s 117ms/step - loss: 0.2338 - mae: 0.2338
# Epoch 82/1000
# 3/3 [==============================] - 0s 121ms/step - loss: 0.2334 - mae: 0.2334
# Epoch 83/1000
# 3/3 [==============================] - 0s 124ms/step - loss: 0.2330 - mae: 0.2330
# Epoch 84/1000
# 3/3 [==============================] - 0s 118ms/step - loss: 0.2327 - mae: 0.2327
# Epoch 85/1000
# 3/3 [==============================] - 0s 125ms/step - loss: 0.2323 - mae: 0.2323
# Epoch 86/1000
# 3/3 [==============================] - 0s 124ms/step - loss: 0.2320 - mae: 0.2320
# Epoch 87/1000
# 3/3 [==============================] - 0s 122ms/step - loss: 0.2317 - mae: 0.2317
# Epoch 88/1000
# 3/3 [==============================] - 0s 124ms/step - loss: 0.2314 - mae: 0.2314
# Epoch 89/1000
# 3/3 [==============================] - 0s 122ms/step - loss: 0.2312 - mae: 0.2312
# Epoch 90/1000
# 3/3 [==============================] - 0s 123ms/step - loss: 0.2309 - mae: 0.2309
# Epoch 91/1000
# 3/3 [==============================] - 0s 125ms/step - loss: 0.2307 - mae: 0.2307
# Epoch 92/1000
# 3/3 [==============================] - 0s 136ms/step - loss: 0.2304 - mae: 0.2304
# Epoch 93/1000
# 3/3 [==============================] - 0s 118ms/step - loss: 0.2303 - mae: 0.2303
# Epoch 94/1000
# 3/3 [==============================] - 0s 127ms/step - loss: 0.2300 - mae: 0.2300
# Epoch 95/1000
# 3/3 [==============================] - 0s 126ms/step - loss: 0.2298 - mae: 0.2298
# Epoch 96/1000
# 3/3 [==============================] - 0s 154ms/step - loss: 0.2297 - mae: 0.2297
# Epoch 97/1000
# 3/3 [==============================] - 0s 129ms/step - loss: 0.2294 - mae: 0.2294
# Epoch 98/1000
# 3/3 [==============================] - 0s 134ms/step - loss: 0.2292 - mae: 0.2292
# Epoch 99/1000
# 3/3 [==============================] - 0s 124ms/step - loss: 0.2290 - mae: 0.2290
# Epoch 100/1000
# 3/3 [==============================] - 0s 126ms/step - loss: 0.2289 - mae: 0.2289
# Epoch 101/1000
# 3/3 [==============================] - 0s 125ms/step - loss: 0.2288 - mae: 0.2288
# Epoch 102/1000
# 3/3 [==============================] - 0s 132ms/step - loss: 0.2285 - mae: 0.2285
# Epoch 103/1000
# 3/3 [==============================] - 0s 117ms/step - loss: 0.2285 - mae: 0.2285
# Epoch 104/1000
# 3/3 [==============================] - 0s 124ms/step - loss: 0.2283 - mae: 0.2283
# Epoch 105/1000
# 3/3 [==============================] - 0s 124ms/step - loss: 0.2283 - mae: 0.2283
# Epoch 106/1000
# 3/3 [==============================] - 0s 131ms/step - loss: 0.2280 - mae: 0.2280
# Epoch 107/1000
# 3/3 [==============================] - 0s 182ms/step - loss: 0.2278 - mae: 0.2278
# Epoch 108/1000
# 3/3 [==============================] - 0s 132ms/step - loss: 0.2277 - mae: 0.2277
# Epoch 109/1000
# 3/3 [==============================] - 0s 140ms/step - loss: 0.2277 - mae: 0.2277
# Epoch 110/1000
# 3/3 [==============================] - 0s 128ms/step - loss: 0.2274 - mae: 0.2274
# Epoch 111/1000
# 3/3 [==============================] - 0s 133ms/step - loss: 0.2274 - mae: 0.2274
# Epoch 112/1000
# 3/3 [==============================] - 0s 137ms/step - loss: 0.2271 - mae: 0.2271
# Epoch 113/1000
# 3/3 [==============================] - 0s 125ms/step - loss: 0.2270 - mae: 0.2270
# Epoch 114/1000
# 3/3 [==============================] - 0s 125ms/step - loss: 0.2270 - mae: 0.2270
# Epoch 115/1000
# 3/3 [==============================] - 0s 130ms/step - loss: 0.2267 - mae: 0.2267
# Epoch 116/1000
# 3/3 [==============================] - 0s 133ms/step - loss: 0.2266 - mae: 0.2266
# Epoch 117/1000
# 3/3 [==============================] - 0s 129ms/step - loss: 0.2265 - mae: 0.2265
# Epoch 118/1000
# 3/3 [==============================] - 0s 130ms/step - loss: 0.2263 - mae: 0.2263
# Epoch 119/1000
# 3/3 [==============================] - 0s 133ms/step - loss: 0.2262 - mae: 0.2262
# Epoch 120/1000
# 3/3 [==============================] - 0s 129ms/step - loss: 0.2263 - mae: 0.2263
# Epoch 121/1000
# 3/3 [==============================] - 0s 123ms/step - loss: 0.2260 - mae: 0.2260
# Epoch 122/1000
# 3/3 [==============================] - 0s 125ms/step - loss: 0.2259 - mae: 0.2259
# Epoch 123/1000
# 3/3 [==============================] - 0s 131ms/step - loss: 0.2258 - mae: 0.2258
# Epoch 124/1000
# 3/3 [==============================] - 0s 132ms/step - loss: 0.2256 - mae: 0.2256
# Epoch 125/1000
# 3/3 [==============================] - 0s 124ms/step - loss: 0.2255 - mae: 0.2255
# Epoch 126/1000
# 3/3 [==============================] - 0s 132ms/step - loss: 0.2254 - mae: 0.2254
# Epoch 127/1000
# 3/3 [==============================] - 0s 131ms/step - loss: 0.2253 - mae: 0.2253
# Epoch 128/1000
# 3/3 [==============================] - 0s 132ms/step - loss: 0.2252 - mae: 0.2252
# Epoch 129/1000
# 3/3 [==============================] - 0s 128ms/step - loss: 0.2250 - mae: 0.2250
# Epoch 130/1000
# 3/3 [==============================] - 0s 138ms/step - loss: 0.2249 - mae: 0.2249
# Epoch 131/1000
# 3/3 [==============================] - 0s 134ms/step - loss: 0.2249 - mae: 0.2249
# Epoch 132/1000
# 3/3 [==============================] - 0s 132ms/step - loss: 0.2247 - mae: 0.2247
# Epoch 133/1000
# 3/3 [==============================] - 0s 136ms/step - loss: 0.2246 - mae: 0.2246
# Epoch 134/1000
# 3/3 [==============================] - 0s 140ms/step - loss: 0.2245 - mae: 0.2245
# Epoch 135/1000
# 3/3 [==============================] - 0s 132ms/step - loss: 0.2244 - mae: 0.2244
# Epoch 136/1000
# 3/3 [==============================] - 0s 135ms/step - loss: 0.2242 - mae: 0.2242
# Epoch 137/1000
# 3/3 [==============================] - 0s 131ms/step - loss: 0.2245 - mae: 0.2245
# Epoch 138/1000
# 3/3 [==============================] - 0s 135ms/step - loss: 0.2241 - mae: 0.2241
# Epoch 139/1000
# 3/3 [==============================] - 0s 133ms/step - loss: 0.2241 - mae: 0.2241
# Epoch 140/1000
# 3/3 [==============================] - 0s 134ms/step - loss: 0.2239 - mae: 0.2239
# Epoch 141/1000
# 3/3 [==============================] - 0s 140ms/step - loss: 0.2239 - mae: 0.2239
# Epoch 142/1000
# 3/3 [==============================] - 0s 143ms/step - loss: 0.2238 - mae: 0.2238
# Epoch 143/1000
# 3/3 [==============================] - 0s 140ms/step - loss: 0.2235 - mae: 0.2235
# Epoch 144/1000
# 3/3 [==============================] - 0s 131ms/step - loss: 0.2235 - mae: 0.2235
# Epoch 145/1000
# 3/3 [==============================] - 0s 137ms/step - loss: 0.2233 - mae: 0.2233
# Epoch 146/1000
# 3/3 [==============================] - 0s 135ms/step - loss: 0.2232 - mae: 0.2232
# Epoch 147/1000
# 3/3 [==============================] - 0s 138ms/step - loss: 0.2231 - mae: 0.2231
# Epoch 148/1000
# 3/3 [==============================] - 0s 134ms/step - loss: 0.2231 - mae: 0.2231
# Epoch 149/1000
# 3/3 [==============================] - 0s 134ms/step - loss: 0.2230 - mae: 0.2230
# Epoch 150/1000
# 3/3 [==============================] - 0s 139ms/step - loss: 0.2228 - mae: 0.2228
# Epoch 151/1000
# 3/3 [==============================] - 0s 137ms/step - loss: 0.2228 - mae: 0.2228
# Epoch 152/1000
# 3/3 [==============================] - 0s 137ms/step - loss: 0.2226 - mae: 0.2226
# Epoch 153/1000
# 3/3 [==============================] - 0s 130ms/step - loss: 0.2226 - mae: 0.2226
# Epoch 154/1000
# 3/3 [==============================] - 0s 138ms/step - loss: 0.2224 - mae: 0.2224
# Epoch 155/1000
# 3/3 [==============================] - 0s 147ms/step - loss: 0.2224 - mae: 0.2224
# Epoch 156/1000
# 3/3 [==============================] - 0s 135ms/step - loss: 0.2222 - mae: 0.2222
# Epoch 157/1000
# 3/3 [==============================] - 0s 136ms/step - loss: 0.2222 - mae: 0.2222
# Epoch 158/1000
# 3/3 [==============================] - 0s 141ms/step - loss: 0.2220 - mae: 0.2220
# Epoch 159/1000
# 3/3 [==============================] - 0s 134ms/step - loss: 0.2220 - mae: 0.2220
# Epoch 160/1000
# 3/3 [==============================] - 0s 130ms/step - loss: 0.2219 - mae: 0.2219
# Epoch 161/1000
# 3/3 [==============================] - 0s 136ms/step - loss: 0.2218 - mae: 0.2218
# Epoch 162/1000
# 3/3 [==============================] - 0s 135ms/step - loss: 0.2219 - mae: 0.2219
# Epoch 163/1000
# 3/3 [==============================] - 0s 132ms/step - loss: 0.2217 - mae: 0.2217
# Epoch 164/1000
# 3/3 [==============================] - 0s 136ms/step - loss: 0.2217 - mae: 0.2217
# Epoch 165/1000
# 3/3 [==============================] - 0s 137ms/step - loss: 0.2215 - mae: 0.2215
# Epoch 166/1000
# 3/3 [==============================] - 0s 136ms/step - loss: 0.2216 - mae: 0.2216
# Epoch 167/1000
# 3/3 [==============================] - 0s 152ms/step - loss: 0.2213 - mae: 0.2213
# Epoch 168/1000
# 3/3 [==============================] - 0s 154ms/step - loss: 0.2212 - mae: 0.2212
# Epoch 169/1000
# 3/3 [==============================] - 0s 144ms/step - loss: 0.2210 - mae: 0.2210
# Epoch 170/1000
# 3/3 [==============================] - 0s 130ms/step - loss: 0.2210 - mae: 0.2210
# Epoch 171/1000
# 3/3 [==============================] - 0s 145ms/step - loss: 0.2209 - mae: 0.2209
# Epoch 172/1000
# 3/3 [==============================] - 0s 139ms/step - loss: 0.2208 - mae: 0.2208
# Epoch 173/1000
# 3/3 [==============================] - 0s 136ms/step - loss: 0.2207 - mae: 0.2207
# Epoch 174/1000
# 3/3 [==============================] - 0s 142ms/step - loss: 0.2206 - mae: 0.2206
# Epoch 175/1000
# 3/3 [==============================] - 0s 139ms/step - loss: 0.2206 - mae: 0.2206
# Epoch 176/1000
# 3/3 [==============================] - 0s 150ms/step - loss: 0.2207 - mae: 0.2207
# Epoch 177/1000
# 3/3 [==============================] - 0s 135ms/step - loss: 0.2207 - mae: 0.2207
# Epoch 178/1000
# 3/3 [==============================] - 0s 157ms/step - loss: 0.2203 - mae: 0.2203
# Epoch 179/1000
# 3/3 [==============================] - 0s 146ms/step - loss: 0.2203 - mae: 0.2203
# Epoch 180/1000
# 3/3 [==============================] - 0s 139ms/step - loss: 0.2201 - mae: 0.2201
# Epoch 181/1000
# 3/3 [==============================] - 0s 146ms/step - loss: 0.2203 - mae: 0.2203
# Epoch 182/1000
# 3/3 [==============================] - 0s 135ms/step - loss: 0.2200 - mae: 0.2200
# Epoch 183/1000
# 3/3 [==============================] - 0s 136ms/step - loss: 0.2201 - mae: 0.2201
# Epoch 184/1000
# 3/3 [==============================] - 0s 146ms/step - loss: 0.2200 - mae: 0.2200
# Epoch 185/1000
# 3/3 [==============================] - 0s 138ms/step - loss: 0.2198 - mae: 0.2198
# Epoch 186/1000
# 3/3 [==============================] - 0s 130ms/step - loss: 0.2196 - mae: 0.2196
# Epoch 187/1000
# 3/3 [==============================] - 0s 143ms/step - loss: 0.2196 - mae: 0.2196
# Epoch 188/1000
# 3/3 [==============================] - 0s 148ms/step - loss: 0.2199 - mae: 0.2199
# Epoch 189/1000
# 3/3 [==============================] - 0s 148ms/step - loss: 0.2194 - mae: 0.2194
# Epoch 190/1000
# 3/3 [==============================] - 0s 136ms/step - loss: 0.2194 - mae: 0.2194
# Epoch 191/1000
# 3/3 [==============================] - 0s 140ms/step - loss: 0.2193 - mae: 0.2193
# Epoch 192/1000
# 3/3 [==============================] - 0s 132ms/step - loss: 0.2191 - mae: 0.2191
# Epoch 193/1000
# 3/3 [==============================] - 0s 142ms/step - loss: 0.2191 - mae: 0.2191
# Epoch 194/1000
# 3/3 [==============================] - 0s 140ms/step - loss: 0.2189 - mae: 0.2189
# Epoch 195/1000
# 3/3 [==============================] - 0s 135ms/step - loss: 0.2189 - mae: 0.2189
# Epoch 196/1000
# 3/3 [==============================] - 0s 136ms/step - loss: 0.2188 - mae: 0.2188
# Epoch 197/1000
# 3/3 [==============================] - 0s 133ms/step - loss: 0.2188 - mae: 0.2188
# Epoch 198/1000
# 3/3 [==============================] - 0s 141ms/step - loss: 0.2186 - mae: 0.2186
# Epoch 199/1000
# 3/3 [==============================] - 0s 147ms/step - loss: 0.2186 - mae: 0.2186
# Epoch 200/1000
# 3/3 [==============================] - 0s 136ms/step - loss: 0.2184 - mae: 0.2184
# Epoch 201/1000
# 3/3 [==============================] - 0s 140ms/step - loss: 0.2182 - mae: 0.2182
# Epoch 202/1000
# 3/3 [==============================] - 0s 136ms/step - loss: 0.2182 - mae: 0.2182
# Epoch 203/1000
# 3/3 [==============================] - 0s 141ms/step - loss: 0.2181 - mae: 0.2181
# Epoch 204/1000
# 3/3 [==============================] - 0s 130ms/step - loss: 0.2180 - mae: 0.2180
# Epoch 205/1000
# 3/3 [==============================] - 0s 135ms/step - loss: 0.2179 - mae: 0.2179
# Epoch 206/1000
# 3/3 [==============================] - 0s 128ms/step - loss: 0.2179 - mae: 0.2179
# Epoch 207/1000
# 3/3 [==============================] - 0s 135ms/step - loss: 0.2177 - mae: 0.2177
# Epoch 208/1000
# 3/3 [==============================] - 0s 141ms/step - loss: 0.2177 - mae: 0.2177
# Epoch 209/1000
# 3/3 [==============================] - 0s 131ms/step - loss: 0.2175 - mae: 0.2175
# Epoch 210/1000
# 3/3 [==============================] - 0s 138ms/step - loss: 0.2175 - mae: 0.2175
# Epoch 211/1000
# 3/3 [==============================] - 0s 137ms/step - loss: 0.2175 - mae: 0.2175
# Epoch 212/1000
# 3/3 [==============================] - 0s 144ms/step - loss: 0.2175 - mae: 0.2175
# Epoch 213/1000
# 3/3 [==============================] - 0s 143ms/step - loss: 0.2172 - mae: 0.2172
# Epoch 214/1000
# 3/3 [==============================] - 0s 140ms/step - loss: 0.2173 - mae: 0.2173
# Epoch 215/1000
# 3/3 [==============================] - 0s 137ms/step - loss: 0.2169 - mae: 0.2169
# Epoch 216/1000
# 3/3 [==============================] - 0s 138ms/step - loss: 0.2171 - mae: 0.2171
# Epoch 217/1000
# 3/3 [==============================] - 0s 142ms/step - loss: 0.2168 - mae: 0.2168
# Epoch 218/1000
# 3/3 [==============================] - 0s 140ms/step - loss: 0.2167 - mae: 0.2167
# Epoch 219/1000
# 3/3 [==============================] - 0s 144ms/step - loss: 0.2167 - mae: 0.2167
# Epoch 220/1000
# 3/3 [==============================] - 0s 129ms/step - loss: 0.2166 - mae: 0.2166
# Epoch 221/1000
# 3/3 [==============================] - 0s 129ms/step - loss: 0.2165 - mae: 0.2165
# Epoch 222/1000
# 3/3 [==============================] - 0s 136ms/step - loss: 0.2165 - mae: 0.2165
# Epoch 223/1000
# 3/3 [==============================] - 0s 140ms/step - loss: 0.2166 - mae: 0.2166
# Epoch 224/1000
# 3/3 [==============================] - 0s 137ms/step - loss: 0.2162 - mae: 0.2162
# Epoch 225/1000
# 3/3 [==============================] - 0s 138ms/step - loss: 0.2163 - mae: 0.2163
# Epoch 226/1000
# 3/3 [==============================] - 0s 142ms/step - loss: 0.2161 - mae: 0.2161
# Epoch 227/1000
# 3/3 [==============================] - 0s 142ms/step - loss: 0.2162 - mae: 0.2162
# Epoch 228/1000
# 3/3 [==============================] - 0s 137ms/step - loss: 0.2158 - mae: 0.2158
# Epoch 229/1000
# 3/3 [==============================] - 0s 133ms/step - loss: 0.2159 - mae: 0.2159
# Epoch 230/1000
# 3/3 [==============================] - 0s 139ms/step - loss: 0.2156 - mae: 0.2156
# Epoch 231/1000
# 3/3 [==============================] - 0s 135ms/step - loss: 0.2157 - mae: 0.2157
# Epoch 232/1000
# 3/3 [==============================] - 0s 136ms/step - loss: 0.2155 - mae: 0.2155
# Epoch 233/1000
# 3/3 [==============================] - 0s 131ms/step - loss: 0.2155 - mae: 0.2155
# Epoch 234/1000
# 3/3 [==============================] - 0s 137ms/step - loss: 0.2153 - mae: 0.2153
# Epoch 235/1000
# 3/3 [==============================] - 0s 154ms/step - loss: 0.2152 - mae: 0.2152
# Epoch 236/1000
# 3/3 [==============================] - 0s 137ms/step - loss: 0.2150 - mae: 0.2150
# Epoch 237/1000
# 3/3 [==============================] - 0s 137ms/step - loss: 0.2150 - mae: 0.2150
# Epoch 238/1000
# 3/3 [==============================] - 0s 135ms/step - loss: 0.2151 - mae: 0.2151
# Epoch 239/1000
# 3/3 [==============================] - 0s 137ms/step - loss: 0.2150 - mae: 0.2150
# Epoch 240/1000
# 3/3 [==============================] - 0s 134ms/step - loss: 0.2147 - mae: 0.2147
# Epoch 241/1000
# 3/3 [==============================] - 0s 138ms/step - loss: 0.2150 - mae: 0.2150
# Epoch 242/1000
# 3/3 [==============================] - 0s 142ms/step - loss: 0.2151 - mae: 0.2151
# Epoch 243/1000
# 3/3 [==============================] - 0s 136ms/step - loss: 0.2149 - mae: 0.2149
# Epoch 244/1000
# 3/3 [==============================] - 0s 136ms/step - loss: 0.2148 - mae: 0.2148
# Epoch 245/1000
# 3/3 [==============================] - 0s 131ms/step - loss: 0.2146 - mae: 0.2146
# Epoch 246/1000
# 3/3 [==============================] - 0s 129ms/step - loss: 0.2145 - mae: 0.2145
# Epoch 247/1000
# 3/3 [==============================] - 0s 128ms/step - loss: 0.2143 - mae: 0.2143
# Epoch 248/1000
# 3/3 [==============================] - 0s 137ms/step - loss: 0.2141 - mae: 0.2141
# Epoch 249/1000
# 3/3 [==============================] - 0s 141ms/step - loss: 0.2141 - mae: 0.2141
# Epoch 250/1000
# 3/3 [==============================] - 0s 147ms/step - loss: 0.2139 - mae: 0.2139
# Epoch 251/1000
# 3/3 [==============================] - 0s 136ms/step - loss: 0.2140 - mae: 0.2140
# Epoch 252/1000
# 3/3 [==============================] - 0s 137ms/step - loss: 0.2137 - mae: 0.2137
# Epoch 253/1000
# 3/3 [==============================] - 0s 136ms/step - loss: 0.2136 - mae: 0.2136
# Epoch 254/1000
# 3/3 [==============================] - 0s 140ms/step - loss: 0.2135 - mae: 0.2135
# Epoch 255/1000
# 3/3 [==============================] - 0s 140ms/step - loss: 0.2136 - mae: 0.2136
# Epoch 256/1000
# 3/3 [==============================] - 0s 138ms/step - loss: 0.2134 - mae: 0.2134
# Epoch 257/1000
# 3/3 [==============================] - 0s 131ms/step - loss: 0.2132 - mae: 0.2132
# Epoch 258/1000
# 3/3 [==============================] - 0s 129ms/step - loss: 0.2140 - mae: 0.2140
# Epoch 259/1000
# 3/3 [==============================] - 0s 134ms/step - loss: 0.2137 - mae: 0.2137
# Epoch 260/1000
# 3/3 [==============================] - 0s 141ms/step - loss: 0.2132 - mae: 0.2132
# Epoch 261/1000
# 3/3 [==============================] - 0s 139ms/step - loss: 0.2133 - mae: 0.2133
# Epoch 262/1000
# 3/3 [==============================] - 0s 142ms/step - loss: 0.2135 - mae: 0.2135
# Epoch 263/1000
# 3/3 [==============================] - 0s 139ms/step - loss: 0.2129 - mae: 0.2129
# Epoch 264/1000
# 3/3 [==============================] - 0s 144ms/step - loss: 0.2131 - mae: 0.2131
# Epoch 265/1000
# 3/3 [==============================] - 0s 135ms/step - loss: 0.2129 - mae: 0.2129
# Epoch 266/1000
# 3/3 [==============================] - 0s 131ms/step - loss: 0.2127 - mae: 0.2127
# Epoch 267/1000
# 3/3 [==============================] - 0s 140ms/step - loss: 0.2130 - mae: 0.2130
# Epoch 268/1000
# 3/3 [==============================] - 0s 134ms/step - loss: 0.2123 - mae: 0.2123
# Epoch 269/1000
# 3/3 [==============================] - 0s 136ms/step - loss: 0.2125 - mae: 0.2125
# Epoch 270/1000
# 3/3 [==============================] - 0s 135ms/step - loss: 0.2123 - mae: 0.2123
# Epoch 271/1000
# 3/3 [==============================] - 0s 136ms/step - loss: 0.2120 - mae: 0.2120
# Epoch 272/1000
# 3/3 [==============================] - 0s 146ms/step - loss: 0.2122 - mae: 0.2122
# Epoch 273/1000
# 3/3 [==============================] - 0s 130ms/step - loss: 0.2118 - mae: 0.2118
# Epoch 274/1000
# 3/3 [==============================] - 0s 153ms/step - loss: 0.2119 - mae: 0.2119
# Epoch 275/1000
# 3/3 [==============================] - 0s 139ms/step - loss: 0.2118 - mae: 0.2118
# Epoch 276/1000
# 3/3 [==============================] - 0s 134ms/step - loss: 0.2116 - mae: 0.2116
# Epoch 277/1000
# 3/3 [==============================] - 0s 142ms/step - loss: 0.2115 - mae: 0.2115
# Epoch 278/1000
# 3/3 [==============================] - 0s 140ms/step - loss: 0.2116 - mae: 0.2116
# Epoch 279/1000
# 3/3 [==============================] - 0s 143ms/step - loss: 0.2113 - mae: 0.2113
# Epoch 280/1000
# 3/3 [==============================] - 0s 146ms/step - loss: 0.2112 - mae: 0.2112
# Epoch 281/1000
# 3/3 [==============================] - 0s 145ms/step - loss: 0.2112 - mae: 0.2112
# Epoch 282/1000
# 3/3 [==============================] - 0s 134ms/step - loss: 0.2110 - mae: 0.2110
# Epoch 283/1000
# 3/3 [==============================] - 0s 129ms/step - loss: 0.2115 - mae: 0.2115
# Epoch 284/1000
# 3/3 [==============================] - 0s 131ms/step - loss: 0.2112 - mae: 0.2112
# Epoch 285/1000
# 3/3 [==============================] - 0s 128ms/step - loss: 0.2112 - mae: 0.2112
# Epoch 286/1000
# 3/3 [==============================] - 0s 135ms/step - loss: 0.2109 - mae: 0.2109
# Epoch 287/1000
# 3/3 [==============================] - 0s 136ms/step - loss: 0.2104 - mae: 0.2104
# Epoch 288/1000
# 3/3 [==============================] - 0s 129ms/step - loss: 0.2104 - mae: 0.2104
# Epoch 289/1000
# 3/3 [==============================] - 0s 138ms/step - loss: 0.2104 - mae: 0.2104
# Epoch 290/1000
# 3/3 [==============================] - 0s 132ms/step - loss: 0.2104 - mae: 0.2104
# Epoch 291/1000
# 3/3 [==============================] - 0s 135ms/step - loss: 0.2100 - mae: 0.2100
# Epoch 292/1000
# 3/3 [==============================] - 0s 131ms/step - loss: 0.2099 - mae: 0.2099
# Epoch 293/1000
# 3/3 [==============================] - 0s 134ms/step - loss: 0.2101 - mae: 0.2101
# Epoch 294/1000
# 3/3 [==============================] - 0s 138ms/step - loss: 0.2098 - mae: 0.2098
# Epoch 295/1000
# 3/3 [==============================] - 0s 134ms/step - loss: 0.2097 - mae: 0.2097
# Epoch 296/1000
# 3/3 [==============================] - 0s 141ms/step - loss: 0.2095 - mae: 0.2095
# Epoch 297/1000
# 3/3 [==============================] - 0s 127ms/step - loss: 0.2095 - mae: 0.2095
# Epoch 298/1000
# 3/3 [==============================] - 0s 135ms/step - loss: 0.2095 - mae: 0.2095
# Epoch 299/1000
# 3/3 [==============================] - 0s 150ms/step - loss: 0.2089 - mae: 0.2089
# Epoch 300/1000
# 3/3 [==============================] - 0s 135ms/step - loss: 0.2091 - mae: 0.2091
# Epoch 301/1000
# 3/3 [==============================] - 0s 145ms/step - loss: 0.2089 - mae: 0.2089
# Epoch 302/1000
# 3/3 [==============================] - 0s 137ms/step - loss: 0.2087 - mae: 0.2087
# Epoch 303/1000
# 3/3 [==============================] - 0s 146ms/step - loss: 0.2086 - mae: 0.2086
# Epoch 304/1000
# 3/3 [==============================] - 0s 137ms/step - loss: 0.2085 - mae: 0.2085
# Epoch 305/1000
# 3/3 [==============================] - 0s 142ms/step - loss: 0.2084 - mae: 0.2084
# Epoch 306/1000
# 3/3 [==============================] - 0s 146ms/step - loss: 0.2082 - mae: 0.2082
# Epoch 307/1000
# 3/3 [==============================] - 0s 138ms/step - loss: 0.2081 - mae: 0.2081
# Epoch 308/1000
# 3/3 [==============================] - 0s 135ms/step - loss: 0.2080 - mae: 0.2080
# Epoch 309/1000
# 3/3 [==============================] - 0s 140ms/step - loss: 0.2078 - mae: 0.2078
# Epoch 310/1000
# 3/3 [==============================] - 0s 154ms/step - loss: 0.2076 - mae: 0.2076
# Epoch 311/1000
# 3/3 [==============================] - 0s 136ms/step - loss: 0.2075 - mae: 0.2075
# Epoch 312/1000
# 3/3 [==============================] - 0s 137ms/step - loss: 0.2076 - mae: 0.2076
# Epoch 313/1000
# 3/3 [==============================] - 0s 133ms/step - loss: 0.2076 - mae: 0.2076
# Epoch 314/1000
# 3/3 [==============================] - 0s 139ms/step - loss: 0.2073 - mae: 0.2073
# Epoch 315/1000
# 3/3 [==============================] - 0s 138ms/step - loss: 0.2074 - mae: 0.2074
# Epoch 316/1000
# 3/3 [==============================] - 0s 142ms/step - loss: 0.2073 - mae: 0.2073
# Epoch 317/1000
# 3/3 [==============================] - 0s 140ms/step - loss: 0.2073 - mae: 0.2073
# Epoch 318/1000
# 3/3 [==============================] - 0s 131ms/step - loss: 0.2072 - mae: 0.2072
# Epoch 319/1000
# 3/3 [==============================] - 0s 139ms/step - loss: 0.2075 - mae: 0.2075
# Epoch 320/1000
# 3/3 [==============================] - 0s 136ms/step - loss: 0.2067 - mae: 0.2067
# Epoch 321/1000
# 3/3 [==============================] - 0s 135ms/step - loss: 0.2062 - mae: 0.2062
# Epoch 322/1000
# 3/3 [==============================] - 0s 136ms/step - loss: 0.2061 - mae: 0.2061
# Epoch 323/1000
# 3/3 [==============================] - 0s 128ms/step - loss: 0.2061 - mae: 0.2061
# Epoch 324/1000
# 3/3 [==============================] - 0s 141ms/step - loss: 0.2061 - mae: 0.2061
# Epoch 325/1000
# 3/3 [==============================] - 0s 141ms/step - loss: 0.2060 - mae: 0.2060
# Epoch 326/1000
# 3/3 [==============================] - 0s 130ms/step - loss: 0.2062 - mae: 0.2062
# Epoch 327/1000
# 3/3 [==============================] - 0s 144ms/step - loss: 0.2067 - mae: 0.2067
# Epoch 328/1000
# 3/3 [==============================] - 0s 128ms/step - loss: 0.2066 - mae: 0.2066
# Epoch 329/1000
# 3/3 [==============================] - 0s 142ms/step - loss: 0.2059 - mae: 0.2059
# Epoch 330/1000
# 3/3 [==============================] - 0s 138ms/step - loss: 0.2057 - mae: 0.2057
# Epoch 331/1000
# 3/3 [==============================] - 0s 136ms/step - loss: 0.2049 - mae: 0.2049
# Epoch 332/1000
# 3/3 [==============================] - 0s 143ms/step - loss: 0.2051 - mae: 0.2051
# Epoch 333/1000
# 3/3 [==============================] - 0s 133ms/step - loss: 0.2049 - mae: 0.2049
# Epoch 334/1000
# 3/3 [==============================] - 0s 134ms/step - loss: 0.2047 - mae: 0.2047
# Epoch 335/1000
# 3/3 [==============================] - 0s 149ms/step - loss: 0.2052 - mae: 0.2052
# Epoch 336/1000
# 3/3 [==============================] - 0s 134ms/step - loss: 0.2050 - mae: 0.2050
# Epoch 337/1000
# 3/3 [==============================] - 0s 134ms/step - loss: 0.2044 - mae: 0.2044
# Epoch 338/1000
# 3/3 [==============================] - 0s 130ms/step - loss: 0.2044 - mae: 0.2044
# Epoch 339/1000
# 3/3 [==============================] - 0s 138ms/step - loss: 0.2042 - mae: 0.2042
# Epoch 340/1000
# 3/3 [==============================] - 0s 139ms/step - loss: 0.2039 - mae: 0.2039
# Epoch 341/1000
# 3/3 [==============================] - 0s 140ms/step - loss: 0.2040 - mae: 0.2040
# Epoch 342/1000
# 3/3 [==============================] - 0s 144ms/step - loss: 0.2038 - mae: 0.2038
# Epoch 343/1000
# 3/3 [==============================] - 0s 141ms/step - loss: 0.2036 - mae: 0.2036
# Epoch 344/1000
# 3/3 [==============================] - 0s 139ms/step - loss: 0.2036 - mae: 0.2036
# Epoch 345/1000
# 3/3 [==============================] - 0s 146ms/step - loss: 0.2035 - mae: 0.2035
# Epoch 346/1000
# 3/3 [==============================] - 0s 149ms/step - loss: 0.2032 - mae: 0.2032
# Epoch 347/1000
# 3/3 [==============================] - 0s 142ms/step - loss: 0.2038 - mae: 0.2038
# Epoch 348/1000
# 3/3 [==============================] - 0s 141ms/step - loss: 0.2039 - mae: 0.2039
# Epoch 349/1000
# 3/3 [==============================] - 0s 137ms/step - loss: 0.2037 - mae: 0.2037
# Epoch 350/1000
# 3/3 [==============================] - 0s 137ms/step - loss: 0.2027 - mae: 0.2027
# Epoch 351/1000
# 3/3 [==============================] - 0s 144ms/step - loss: 0.2027 - mae: 0.2027
# Epoch 352/1000
# 3/3 [==============================] - 0s 139ms/step - loss: 0.2026 - mae: 0.2026
# Epoch 353/1000
# 3/3 [==============================] - 0s 146ms/step - loss: 0.2023 - mae: 0.2023
# Epoch 354/1000
# 3/3 [==============================] - 0s 145ms/step - loss: 0.2023 - mae: 0.2023
# Epoch 355/1000
# 3/3 [==============================] - 0s 136ms/step - loss: 0.2021 - mae: 0.2021
# Epoch 356/1000
# 3/3 [==============================] - 0s 141ms/step - loss: 0.2025 - mae: 0.2025
# Epoch 357/1000
# 3/3 [==============================] - 0s 137ms/step - loss: 0.2026 - mae: 0.2026
# Epoch 358/1000
# 3/3 [==============================] - 0s 138ms/step - loss: 0.2025 - mae: 0.2025
# Epoch 359/1000
# 3/3 [==============================] - 0s 147ms/step - loss: 0.2022 - mae: 0.2022
# Epoch 360/1000
# 3/3 [==============================] - 0s 137ms/step - loss: 0.2014 - mae: 0.2014
# Epoch 361/1000
# 3/3 [==============================] - 0s 137ms/step - loss: 0.2015 - mae: 0.2015
# Epoch 362/1000
# 3/3 [==============================] - 0s 134ms/step - loss: 0.2018 - mae: 0.2018
# Epoch 363/1000
# 3/3 [==============================] - 0s 165ms/step - loss: 0.2012 - mae: 0.2012
# Epoch 364/1000
# 3/3 [==============================] - 0s 138ms/step - loss: 0.2016 - mae: 0.2016
# Epoch 365/1000
# 3/3 [==============================] - 0s 140ms/step - loss: 0.2018 - mae: 0.2018
# Epoch 366/1000
# 3/3 [==============================] - 0s 146ms/step - loss: 0.2017 - mae: 0.2017
# Epoch 367/1000
# 3/3 [==============================] - 0s 143ms/step - loss: 0.2023 - mae: 0.2023
# Epoch 368/1000
# 3/3 [==============================] - 0s 139ms/step - loss: 0.2015 - mae: 0.2015
# Epoch 369/1000
# 3/3 [==============================] - 0s 137ms/step - loss: 0.2017 - mae: 0.2017
# Epoch 370/1000
# 3/3 [==============================] - 0s 135ms/step - loss: 0.2014 - mae: 0.2014
# Epoch 371/1000
# 3/3 [==============================] - 0s 131ms/step - loss: 0.2008 - mae: 0.2008
# Epoch 372/1000
# 3/3 [==============================] - 0s 154ms/step - loss: 0.2005 - mae: 0.2005
# Epoch 373/1000
# 3/3 [==============================] - 0s 133ms/step - loss: 0.2004 - mae: 0.2004
# Epoch 374/1000
# 3/3 [==============================] - 0s 136ms/step - loss: 0.1996 - mae: 0.1996
# Epoch 375/1000
# 3/3 [==============================] - 0s 140ms/step - loss: 0.2000 - mae: 0.2000
# Epoch 376/1000
# 3/3 [==============================] - 0s 136ms/step - loss: 0.1995 - mae: 0.1995
# Epoch 377/1000
# 3/3 [==============================] - 0s 133ms/step - loss: 0.1992 - mae: 0.1992
# Epoch 378/1000
# 3/3 [==============================] - 0s 133ms/step - loss: 0.1996 - mae: 0.1996
# Epoch 379/1000
# 3/3 [==============================] - 0s 134ms/step - loss: 0.1992 - mae: 0.1992
# Epoch 380/1000
# 3/3 [==============================] - 0s 132ms/step - loss: 0.1990 - mae: 0.1990
# Epoch 381/1000
# 3/3 [==============================] - 0s 145ms/step - loss: 0.1988 - mae: 0.1988
# Epoch 382/1000
# 3/3 [==============================] - 0s 131ms/step - loss: 0.1985 - mae: 0.1985
# Epoch 383/1000
# 3/3 [==============================] - 0s 136ms/step - loss: 0.1984 - mae: 0.1984
# Epoch 384/1000
# 3/3 [==============================] - 0s 132ms/step - loss: 0.1985 - mae: 0.1985
# Epoch 385/1000
# 3/3 [==============================] - 0s 134ms/step - loss: 0.1985 - mae: 0.1985
# Epoch 386/1000
# 3/3 [==============================] - 0s 141ms/step - loss: 0.1984 - mae: 0.1984
# Epoch 387/1000
# 3/3 [==============================] - 0s 136ms/step - loss: 0.1979 - mae: 0.1979
# Epoch 388/1000
# 3/3 [==============================] - 0s 138ms/step - loss: 0.1982 - mae: 0.1982
# Epoch 389/1000
# 3/3 [==============================] - 0s 140ms/step - loss: 0.1982 - mae: 0.1982
# Epoch 390/1000
# 3/3 [==============================] - 0s 140ms/step - loss: 0.1976 - mae: 0.1976
# Epoch 391/1000
# 3/3 [==============================] - 0s 133ms/step - loss: 0.1972 - mae: 0.1972
# Epoch 392/1000
# 3/3 [==============================] - 0s 133ms/step - loss: 0.1978 - mae: 0.1978
# Epoch 393/1000
# 3/3 [==============================] - 0s 138ms/step - loss: 0.1972 - mae: 0.1972
# Epoch 394/1000
# 3/3 [==============================] - 0s 171ms/step - loss: 0.1972 - mae: 0.1972
# Epoch 395/1000
# 3/3 [==============================] - 1s 190ms/step - loss: 0.1971 - mae: 0.1971
# Epoch 396/1000
# 3/3 [==============================] - 0s 139ms/step - loss: 0.1970 - mae: 0.1970
# Epoch 397/1000
# 3/3 [==============================] - 0s 136ms/step - loss: 0.1967 - mae: 0.1967
# Epoch 398/1000
# 3/3 [==============================] - 0s 135ms/step - loss: 0.1970 - mae: 0.1970
# Epoch 399/1000
# 3/3 [==============================] - 0s 135ms/step - loss: 0.1983 - mae: 0.1983
# Epoch 400/1000
# 3/3 [==============================] - 0s 144ms/step - loss: 0.1981 - mae: 0.1981
# Epoch 401/1000
# 3/3 [==============================] - 0s 135ms/step - loss: 0.1981 - mae: 0.1981
# Epoch 402/1000
# 3/3 [==============================] - 0s 138ms/step - loss: 0.1968 - mae: 0.1968
# Epoch 403/1000
# 3/3 [==============================] - 0s 136ms/step - loss: 0.1972 - mae: 0.1972
# Epoch 404/1000
# 3/3 [==============================] - 0s 131ms/step - loss: 0.1961 - mae: 0.1961
# Epoch 405/1000
# 3/3 [==============================] - 0s 146ms/step - loss: 0.1957 - mae: 0.1957
# Epoch 406/1000
# 3/3 [==============================] - 0s 155ms/step - loss: 0.1960 - mae: 0.1960
# Epoch 407/1000
# 3/3 [==============================] - 0s 143ms/step - loss: 0.1959 - mae: 0.1959
# Epoch 408/1000
# 3/3 [==============================] - 0s 135ms/step - loss: 0.1956 - mae: 0.1956
# Epoch 409/1000
# 3/3 [==============================] - 0s 131ms/step - loss: 0.1953 - mae: 0.1953
# Epoch 410/1000
# 3/3 [==============================] - 0s 145ms/step - loss: 0.1950 - mae: 0.1950
# Epoch 411/1000
# 3/3 [==============================] - 0s 141ms/step - loss: 0.1948 - mae: 0.1948
# Epoch 412/1000
# 3/3 [==============================] - 0s 150ms/step - loss: 0.1950 - mae: 0.1950
# Epoch 413/1000
# 3/3 [==============================] - 0s 151ms/step - loss: 0.1943 - mae: 0.1943
# Epoch 414/1000
# 3/3 [==============================] - 0s 138ms/step - loss: 0.1942 - mae: 0.1942
# Epoch 415/1000
# 3/3 [==============================] - 0s 135ms/step - loss: 0.1950 - mae: 0.1950
# Epoch 416/1000
# 3/3 [==============================] - 0s 138ms/step - loss: 0.1940 - mae: 0.1940
# Epoch 417/1000
# 3/3 [==============================] - 0s 133ms/step - loss: 0.1939 - mae: 0.1939
# Epoch 418/1000
# 3/3 [==============================] - 0s 136ms/step - loss: 0.1935 - mae: 0.1935
# Epoch 419/1000
# 3/3 [==============================] - 0s 131ms/step - loss: 0.1938 - mae: 0.1938
# Epoch 420/1000
# 3/3 [==============================] - 0s 132ms/step - loss: 0.1939 - mae: 0.1939
# Epoch 421/1000
# 3/3 [==============================] - 0s 140ms/step - loss: 0.1940 - mae: 0.1940
# Epoch 422/1000
# 3/3 [==============================] - 0s 134ms/step - loss: 0.1935 - mae: 0.1935
# Epoch 423/1000
# 3/3 [==============================] - 0s 131ms/step - loss: 0.1931 - mae: 0.1931
# Epoch 424/1000
# 3/3 [==============================] - 0s 145ms/step - loss: 0.1934 - mae: 0.1934
# Epoch 425/1000
# 3/3 [==============================] - 0s 129ms/step - loss: 0.1928 - mae: 0.1928
# Epoch 426/1000
# 3/3 [==============================] - 0s 147ms/step - loss: 0.1925 - mae: 0.1925
# Epoch 427/1000
# 3/3 [==============================] - 0s 141ms/step - loss: 0.1926 - mae: 0.1926
# Epoch 428/1000
# 3/3 [==============================] - 0s 142ms/step - loss: 0.1924 - mae: 0.1924
# Epoch 429/1000
# 3/3 [==============================] - 0s 129ms/step - loss: 0.1925 - mae: 0.1925
# Epoch 430/1000
# 3/3 [==============================] - 0s 136ms/step - loss: 0.1921 - mae: 0.1921
# Epoch 431/1000
# 3/3 [==============================] - 0s 136ms/step - loss: 0.1916 - mae: 0.1916
# Epoch 432/1000
# 3/3 [==============================] - 0s 135ms/step - loss: 0.1913 - mae: 0.1913
# Epoch 433/1000
# 3/3 [==============================] - 0s 138ms/step - loss: 0.1913 - mae: 0.1913
# Epoch 434/1000
# 3/3 [==============================] - 0s 141ms/step - loss: 0.1914 - mae: 0.1914
# Epoch 435/1000
# 3/3 [==============================] - 0s 132ms/step - loss: 0.1912 - mae: 0.1912
# Epoch 436/1000
# 3/3 [==============================] - 0s 136ms/step - loss: 0.1923 - mae: 0.1923
# Epoch 437/1000
# 3/3 [==============================] - 0s 141ms/step - loss: 0.1907 - mae: 0.1907
# Epoch 438/1000
# 3/3 [==============================] - 0s 131ms/step - loss: 0.1904 - mae: 0.1904
# Epoch 439/1000
# 3/3 [==============================] - 0s 138ms/step - loss: 0.1904 - mae: 0.1904
# Epoch 440/1000
# 3/3 [==============================] - 0s 143ms/step - loss: 0.1910 - mae: 0.1910
# Epoch 441/1000
# 3/3 [==============================] - 0s 144ms/step - loss: 0.1907 - mae: 0.1907
# Epoch 442/1000
# 3/3 [==============================] - 0s 153ms/step - loss: 0.1905 - mae: 0.1905
# Epoch 443/1000
# 3/3 [==============================] - 0s 148ms/step - loss: 0.1900 - mae: 0.1900
# Epoch 444/1000
# 3/3 [==============================] - 0s 144ms/step - loss: 0.1910 - mae: 0.1910
# Epoch 445/1000
# 3/3 [==============================] - 0s 146ms/step - loss: 0.1901 - mae: 0.1901
# Epoch 446/1000
# 3/3 [==============================] - 0s 148ms/step - loss: 0.1919 - mae: 0.1919
# Epoch 447/1000
# 3/3 [==============================] - 0s 156ms/step - loss: 0.1905 - mae: 0.1905
# Epoch 448/1000
# 3/3 [==============================] - 0s 139ms/step - loss: 0.1899 - mae: 0.1899
# Epoch 449/1000
# 3/3 [==============================] - 0s 136ms/step - loss: 0.1897 - mae: 0.1897
# Epoch 450/1000
# 3/3 [==============================] - 0s 138ms/step - loss: 0.1887 - mae: 0.1887
# Epoch 451/1000
# 3/3 [==============================] - 0s 146ms/step - loss: 0.1888 - mae: 0.1888
# Epoch 452/1000
# 3/3 [==============================] - 0s 143ms/step - loss: 0.1885 - mae: 0.1885
# Epoch 453/1000
# 3/3 [==============================] - 0s 147ms/step - loss: 0.1888 - mae: 0.1888
# Epoch 454/1000
# 3/3 [==============================] - 0s 140ms/step - loss: 0.1881 - mae: 0.1881
# Epoch 455/1000
# 3/3 [==============================] - 0s 139ms/step - loss: 0.1879 - mae: 0.1879
# Epoch 456/1000
# 3/3 [==============================] - 0s 138ms/step - loss: 0.1881 - mae: 0.1881
# Epoch 457/1000
# 3/3 [==============================] - 0s 136ms/step - loss: 0.1878 - mae: 0.1878
# Epoch 458/1000
# 3/3 [==============================] - 0s 136ms/step - loss: 0.1873 - mae: 0.1873
# Epoch 459/1000
# 3/3 [==============================] - 0s 128ms/step - loss: 0.1873 - mae: 0.1873
# Epoch 460/1000
# 3/3 [==============================] - 0s 140ms/step - loss: 0.1871 - mae: 0.1871
# Epoch 461/1000
# 3/3 [==============================] - 0s 153ms/step - loss: 0.1868 - mae: 0.1868
# Epoch 462/1000
# 3/3 [==============================] - 0s 147ms/step - loss: 0.1865 - mae: 0.1865
# Epoch 463/1000
# 3/3 [==============================] - 0s 142ms/step - loss: 0.1872 - mae: 0.1872
# Epoch 464/1000
# 3/3 [==============================] - 0s 139ms/step - loss: 0.1870 - mae: 0.1870
# Epoch 465/1000
# 3/3 [==============================] - 0s 143ms/step - loss: 0.1862 - mae: 0.1862
# Epoch 466/1000
# 3/3 [==============================] - 0s 137ms/step - loss: 0.1863 - mae: 0.1863
# Epoch 467/1000
# 3/3 [==============================] - 0s 140ms/step - loss: 0.1862 - mae: 0.1862
# Epoch 468/1000
# 3/3 [==============================] - 0s 138ms/step - loss: 0.1861 - mae: 0.1861
# Epoch 469/1000
# 3/3 [==============================] - 0s 144ms/step - loss: 0.1881 - mae: 0.1881
# Epoch 470/1000
# 3/3 [==============================] - 0s 143ms/step - loss: 0.1873 - mae: 0.1873
# Epoch 471/1000
# 3/3 [==============================] - 0s 143ms/step - loss: 0.1875 - mae: 0.1875
# Epoch 472/1000
# 3/3 [==============================] - 0s 139ms/step - loss: 0.1861 - mae: 0.1861
# Epoch 473/1000
# 3/3 [==============================] - 0s 134ms/step - loss: 0.1860 - mae: 0.1860
# Epoch 474/1000
# 3/3 [==============================] - 0s 149ms/step - loss: 0.1856 - mae: 0.1856
# Epoch 475/1000
# 3/3 [==============================] - 0s 135ms/step - loss: 0.1851 - mae: 0.1851
# Epoch 476/1000
# 3/3 [==============================] - 0s 138ms/step - loss: 0.1855 - mae: 0.1855
# Epoch 477/1000
# 3/3 [==============================] - 0s 134ms/step - loss: 0.1849 - mae: 0.1849
# Epoch 478/1000
# 3/3 [==============================] - 0s 147ms/step - loss: 0.1852 - mae: 0.1852
# Epoch 479/1000
# 3/3 [==============================] - 0s 139ms/step - loss: 0.1851 - mae: 0.1851
# Epoch 480/1000
# 3/3 [==============================] - 0s 137ms/step - loss: 0.1874 - mae: 0.1874
# Epoch 481/1000
# 3/3 [==============================] - 0s 137ms/step - loss: 0.1857 - mae: 0.1857
# Epoch 482/1000
# 3/3 [==============================] - 0s 135ms/step - loss: 0.1877 - mae: 0.1877
# Epoch 483/1000
# 3/3 [==============================] - 0s 151ms/step - loss: 0.1867 - mae: 0.1867
# Epoch 484/1000
# 3/3 [==============================] - 0s 142ms/step - loss: 0.1903 - mae: 0.1903
# Epoch 485/1000
# 3/3 [==============================] - 0s 142ms/step - loss: 0.1888 - mae: 0.1888
# Epoch 486/1000
# 3/3 [==============================] - 0s 136ms/step - loss: 0.1869 - mae: 0.1869
# Epoch 487/1000
# 3/3 [==============================] - 0s 142ms/step - loss: 0.1868 - mae: 0.1868
# Epoch 488/1000
# 3/3 [==============================] - 0s 131ms/step - loss: 0.1869 - mae: 0.1869
# Epoch 489/1000
# 3/3 [==============================] - 0s 142ms/step - loss: 0.1844 - mae: 0.1844
# Epoch 490/1000
# 3/3 [==============================] - 0s 130ms/step - loss: 0.1846 - mae: 0.1846
# Epoch 491/1000
# 3/3 [==============================] - 0s 141ms/step - loss: 0.1844 - mae: 0.1844
# Epoch 492/1000
# 3/3 [==============================] - 0s 128ms/step - loss: 0.1846 - mae: 0.1846
# Epoch 493/1000
# 3/3 [==============================] - 0s 131ms/step - loss: 0.1841 - mae: 0.1841
# Epoch 494/1000
# 3/3 [==============================] - 0s 140ms/step - loss: 0.1846 - mae: 0.1846
# Epoch 495/1000
# 3/3 [==============================] - 0s 136ms/step - loss: 0.1829 - mae: 0.1829
# Epoch 496/1000
# ...
# 3/3 [==============================] - 0s 140ms/step - loss: 0.1750 - mae: 0.1750
# Epoch 595/1000
# 3/3 [==============================] - 0s 130ms/step - loss: 0.1754 - mae: 0.1754
# Epoch 596/1000
# 3/3 [==============================] - 0s 138ms/step - loss: 0.1759 - mae: 0.1759
# Epoch 597/1000
# 3/3 [==============================] - 0s 133ms/step - loss: 0.1754 - mae: 0.1754
# Epoch 598/1000
# 3/3 [==============================] - 0s 132ms/step - loss: 0.1757 - mae: 0.1757
# Epoch 599/1000
# 3/3 [==============================] - 0s 130ms/step - loss: 0.1753 - mae: 0.1753
# Epoch 600/1000
# 3/3 [==============================] - 0s 140ms/step - loss: 0.1765 - mae: 0.1765
# Epoch 601/1000
# 3/3 [==============================] - 0s 135ms/step - loss: 0.1746 - mae: 0.1746
# Epoch 602/1000
# 3/3 [==============================] - 0s 129ms/step - loss: 0.1747 - mae: 0.1747
# Epoch 603/1000
# 3/3 [==============================] - 0s 136ms/step - loss: 0.1743 - mae: 0.1743
# Epoch 604/1000
# 3/3 [==============================] - 0s 140ms/step - loss: 0.1748 - mae: 0.1748
# Epoch 605/1000
# 3/3 [==============================] - 0s 143ms/step - loss: 0.1752 - mae: 0.1752
# Epoch 606/1000
# 3/3 [==============================] - 0s 134ms/step - loss: 0.1770 - mae: 0.1770
# Epoch 607/1000
# 3/3 [==============================] - 0s 134ms/step - loss: 0.1745 - mae: 0.1745
# Epoch 608/1000
# 3/3 [==============================] - 0s 134ms/step - loss: 0.1752 - mae: 0.1752
# Epoch 609/1000
# 3/3 [==============================] - 0s 134ms/step - loss: 0.1748 - mae: 0.1748
# Epoch 610/1000
# 3/3 [==============================] - 0s 128ms/step - loss: 0.1746 - mae: 0.1746
# Epoch 611/1000
# 3/3 [==============================] - 0s 132ms/step - loss: 0.1740 - mae: 0.1740
# Epoch 612/1000
# 3/3 [==============================] - 0s 139ms/step - loss: 0.1741 - mae: 0.1741
# Epoch 613/1000
# 3/3 [==============================] - 0s 131ms/step - loss: 0.1739 - mae: 0.1739
# Epoch 614/1000
# 3/3 [==============================] - 0s 136ms/step - loss: 0.1737 - mae: 0.1737
# Epoch 615/1000
# 3/3 [==============================] - 0s 134ms/step - loss: 0.1738 - mae: 0.1738
# Epoch 616/1000
# 3/3 [==============================] - 0s 133ms/step - loss: 0.1740 - mae: 0.1740
# Epoch 617/1000
# 3/3 [==============================] - 0s 147ms/step - loss: 0.1744 - mae: 0.1744
# Epoch 618/1000
# 3/3 [==============================] - 0s 135ms/step - loss: 0.1735 - mae: 0.1735
# Epoch 619/1000
# 3/3 [==============================] - 0s 134ms/step - loss: 0.1743 - mae: 0.1743
# Epoch 620/1000
# 3/3 [==============================] - 0s 130ms/step - loss: 0.1744 - mae: 0.1744
# Epoch 621/1000
# 3/3 [==============================] - 0s 138ms/step - loss: 0.1738 - mae: 0.1738
# Epoch 622/1000
# 3/3 [==============================] - 0s 134ms/step - loss: 0.1742 - mae: 0.1742
# Epoch 623/1000
# 3/3 [==============================] - 0s 145ms/step - loss: 0.1733 - mae: 0.1733
# Epoch 624/1000
# 3/3 [==============================] - 0s 137ms/step - loss: 0.1734 - mae: 0.1734
# Epoch 625/1000
# 3/3 [==============================] - 0s 139ms/step - loss: 0.1749 - mae: 0.1749
# Epoch 626/1000
# 3/3 [==============================] - 0s 129ms/step - loss: 0.1750 - mae: 0.1750
# Epoch 627/1000
# 3/3 [==============================] - 0s 130ms/step - loss: 0.1744 - mae: 0.1744
# Epoch 628/1000
# 3/3 [==============================] - 0s 129ms/step - loss: 0.1745 - mae: 0.1745
# Epoch 629/1000
# 3/3 [==============================] - 0s 136ms/step - loss: 0.1737 - mae: 0.1737
# Epoch 630/1000
# 3/3 [==============================] - 0s 133ms/step - loss: 0.1736 - mae: 0.1736
# Epoch 631/1000
# 3/3 [==============================] - 0s 135ms/step - loss: 0.1741 - mae: 0.1741
# Epoch 632/1000
# 3/3 [==============================] - 0s 133ms/step - loss: 0.1750 - mae: 0.1750
# Epoch 633/1000
# 3/3 [==============================] - 0s 137ms/step - loss: 0.1745 - mae: 0.1745
# Epoch 634/1000
# 3/3 [==============================] - 0s 130ms/step - loss: 0.1740 - mae: 0.1740
# Epoch 635/1000
# 3/3 [==============================] - 0s 133ms/step - loss: 0.1725 - mae: 0.1725
# Epoch 636/1000
# 3/3 [==============================] - 0s 138ms/step - loss: 0.1732 - mae: 0.1732
# Epoch 637/1000
# 3/3 [==============================] - 0s 132ms/step - loss: 0.1724 - mae: 0.1724
# Epoch 638/1000
# 3/3 [==============================] - 0s 140ms/step - loss: 0.1721 - mae: 0.1721
# Epoch 639/1000
# 3/3 [==============================] - 0s 135ms/step - loss: 0.1724 - mae: 0.1724
# Epoch 640/1000
# 3/3 [==============================] - 0s 134ms/step - loss: 0.1719 - mae: 0.1719
# Epoch 641/1000
# 3/3 [==============================] - 0s 132ms/step - loss: 0.1724 - mae: 0.1724
# Epoch 642/1000
# 3/3 [==============================] - 0s 135ms/step - loss: 0.1721 - mae: 0.1721
# Epoch 643/1000
# 3/3 [==============================] - 0s 134ms/step - loss: 0.1717 - mae: 0.1717
# Epoch 644/1000
# 3/3 [==============================] - 0s 129ms/step - loss: 0.1735 - mae: 0.1735
# Epoch 645/1000
# 3/3 [==============================] - 0s 138ms/step - loss: 0.1737 - mae: 0.1737
# Epoch 646/1000
# 3/3 [==============================] - 0s 138ms/step - loss: 0.1718 - mae: 0.1718
# Epoch 647/1000
# 3/3 [==============================] - 0s 135ms/step - loss: 0.1721 - mae: 0.1721
# Epoch 648/1000
# 3/3 [==============================] - 0s 131ms/step - loss: 0.1716 - mae: 0.1716
# Epoch 649/1000
# 3/3 [==============================] - 0s 130ms/step - loss: 0.1721 - mae: 0.1721
# Epoch 650/1000
# 3/3 [==============================] - 0s 133ms/step - loss: 0.1722 - mae: 0.1722
# Epoch 651/1000
# 3/3 [==============================] - 0s 133ms/step - loss: 0.1718 - mae: 0.1718
# Epoch 652/1000
# 3/3 [==============================] - 0s 137ms/step - loss: 0.1725 - mae: 0.1725
# Epoch 653/1000
# 3/3 [==============================] - 0s 132ms/step - loss: 0.1730 - mae: 0.1730
# Epoch 654/1000
# 3/3 [==============================] - 0s 130ms/step - loss: 0.1724 - mae: 0.1724
# Epoch 655/1000
# 3/3 [==============================] - 0s 135ms/step - loss: 0.1716 - mae: 0.1716
# Epoch 656/1000
# 3/3 [==============================] - 0s 139ms/step - loss: 0.1707 - mae: 0.1707
# Epoch 657/1000
# 3/3 [==============================] - 0s 129ms/step - loss: 0.1708 - mae: 0.1708
# Epoch 658/1000
# 3/3 [==============================] - 0s 138ms/step - loss: 0.1709 - mae: 0.1709
# Epoch 659/1000
# 3/3 [==============================] - 0s 137ms/step - loss: 0.1719 - mae: 0.1719
# Epoch 660/1000
# 3/3 [==============================] - 0s 129ms/step - loss: 0.1717 - mae: 0.1717
# Epoch 661/1000
# 3/3 [==============================] - 0s 152ms/step - loss: 0.1709 - mae: 0.1709
# Epoch 662/1000
# 3/3 [==============================] - 0s 130ms/step - loss: 0.1708 - mae: 0.1708
# Epoch 663/1000
# 3/3 [==============================] - 0s 136ms/step - loss: 0.1706 - mae: 0.1706
# Epoch 664/1000
# 3/3 [==============================] - 0s 145ms/step - loss: 0.1710 - mae: 0.1710
# Epoch 665/1000
# 3/3 [==============================] - 0s 131ms/step - loss: 0.1712 - mae: 0.1712
# Epoch 666/1000
# 3/3 [==============================] - 0s 135ms/step - loss: 0.1719 - mae: 0.1719
# Epoch 667/1000
# 3/3 [==============================] - 0s 144ms/step - loss: 0.1704 - mae: 0.1704
# Epoch 668/1000
# 3/3 [==============================] - 0s 142ms/step - loss: 0.1709 - mae: 0.1709
# Epoch 669/1000
# 3/3 [==============================] - 0s 135ms/step - loss: 0.1718 - mae: 0.1718
# Epoch 670/1000
# 3/3 [==============================] - 0s 139ms/step - loss: 0.1710 - mae: 0.1710
# Epoch 671/1000
# 3/3 [==============================] - 0s 136ms/step - loss: 0.1727 - mae: 0.1727
# Epoch 672/1000
# 3/3 [==============================] - 0s 135ms/step - loss: 0.1724 - mae: 0.1724
# Epoch 673/1000
# 3/3 [==============================] - 0s 137ms/step - loss: 0.1709 - mae: 0.1709
# Epoch 674/1000
# 3/3 [==============================] - 0s 139ms/step - loss: 0.1707 - mae: 0.1707
# Epoch 675/1000
# 3/3 [==============================] - 0s 138ms/step - loss: 0.1705 - mae: 0.1705
# Epoch 676/1000
# 3/3 [==============================] - 0s 139ms/step - loss: 0.1702 - mae: 0.1702
# Epoch 677/1000
# 3/3 [==============================] - 0s 131ms/step - loss: 0.1707 - mae: 0.1707
# Epoch 678/1000
# 3/3 [==============================] - 0s 138ms/step - loss: 0.1700 - mae: 0.1700
# Epoch 679/1000
# 3/3 [==============================] - 0s 144ms/step - loss: 0.1694 - mae: 0.1694
# Epoch 680/1000
# 3/3 [==============================] - 0s 135ms/step - loss: 0.1691 - mae: 0.1691
# Epoch 681/1000
# 3/3 [==============================] - 0s 132ms/step - loss: 0.1691 - mae: 0.1691
# Epoch 682/1000
# 3/3 [==============================] - 0s 132ms/step - loss: 0.1690 - mae: 0.1690
# Epoch 683/1000
# 3/3 [==============================] - 0s 128ms/step - loss: 0.1694 - mae: 0.1694
# Epoch 684/1000
# 3/3 [==============================] - 0s 131ms/step - loss: 0.1692 - mae: 0.1692
# Epoch 685/1000
# 3/3 [==============================] - 0s 143ms/step - loss: 0.1700 - mae: 0.1700
# Epoch 686/1000
# 3/3 [==============================] - 0s 141ms/step - loss: 0.1704 - mae: 0.1704
# Epoch 687/1000
# 3/3 [==============================] - 0s 132ms/step - loss: 0.1702 - mae: 0.1702
# Epoch 688/1000
# 3/3 [==============================] - 0s 129ms/step - loss: 0.1704 - mae: 0.1704
# Epoch 689/1000
# 3/3 [==============================] - 0s 134ms/step - loss: 0.1701 - mae: 0.1701
# Epoch 690/1000
# 3/3 [==============================] - 0s 130ms/step - loss: 0.1719 - mae: 0.1719
# Epoch 691/1000
# 3/3 [==============================] - 0s 147ms/step - loss: 0.1706 - mae: 0.1706
# Epoch 692/1000
# 3/3 [==============================] - 0s 136ms/step - loss: 0.1701 - mae: 0.1701
# Epoch 693/1000
# 3/3 [==============================] - 0s 134ms/step - loss: 0.1692 - mae: 0.1692
# Epoch 694/1000
# 3/3 [==============================] - 0s 133ms/step - loss: 0.1684 - mae: 0.1684
# Epoch 695/1000
# 3/3 [==============================] - 0s 141ms/step - loss: 0.1686 - mae: 0.1686
# Epoch 696/1000
# 3/3 [==============================] - 0s 145ms/step - loss: 0.1683 - mae: 0.1683
# Epoch 697/1000
# 3/3 [==============================] - 0s 136ms/step - loss: 0.1696 - mae: 0.1696
# Epoch 698/1000
# 3/3 [==============================] - 0s 136ms/step - loss: 0.1691 - mae: 0.1691
# Epoch 699/1000
# 3/3 [==============================] - 0s 141ms/step - loss: 0.1693 - mae: 0.1693
# Epoch 700/1000
# 3/3 [==============================] - 0s 145ms/step - loss: 0.1688 - mae: 0.1688
# Epoch 701/1000
# 3/3 [==============================] - 0s 136ms/step - loss: 0.1693 - mae: 0.1693
# Epoch 702/1000
# 3/3 [==============================] - 0s 138ms/step - loss: 0.1692 - mae: 0.1692
# Epoch 703/1000
# 3/3 [==============================] - 0s 132ms/step - loss: 0.1688 - mae: 0.1688
# Epoch 704/1000
# 3/3 [==============================] - 0s 135ms/step - loss: 0.1681 - mae: 0.1681
# Epoch 705/1000
# 3/3 [==============================] - 0s 134ms/step - loss: 0.1680 - mae: 0.1680
# Epoch 706/1000
# 3/3 [==============================] - 0s 146ms/step - loss: 0.1676 - mae: 0.1676
# Epoch 707/1000
# 3/3 [==============================] - 0s 132ms/step - loss: 0.1676 - mae: 0.1676
# Epoch 708/1000
# 3/3 [==============================] - 0s 137ms/step - loss: 0.1683 - mae: 0.1683
# Epoch 709/1000
# 3/3 [==============================] - 0s 132ms/step - loss: 0.1678 - mae: 0.1678
# Epoch 710/1000
# 3/3 [==============================] - 0s 144ms/step - loss: 0.1678 - mae: 0.1678
# Epoch 711/1000
# 3/3 [==============================] - 0s 135ms/step - loss: 0.1678 - mae: 0.1678
# Epoch 712/1000
# 3/3 [==============================] - 0s 149ms/step - loss: 0.1674 - mae: 0.1674
# Epoch 713/1000
# 3/3 [==============================] - 0s 136ms/step - loss: 0.1671 - mae: 0.1671
# Epoch 714/1000
# 3/3 [==============================] - 0s 132ms/step - loss: 0.1674 - mae: 0.1674
# Epoch 715/1000
# 3/3 [==============================] - 0s 141ms/step - loss: 0.1673 - mae: 0.1673
# Epoch 716/1000
# 3/3 [==============================] - 0s 136ms/step - loss: 0.1680 - mae: 0.1680
# Epoch 717/1000
# 3/3 [==============================] - 0s 138ms/step - loss: 0.1680 - mae: 0.1680
# Epoch 718/1000
# 3/3 [==============================] - 0s 132ms/step - loss: 0.1677 - mae: 0.1677
# Epoch 719/1000
# 3/3 [==============================] - 0s 136ms/step - loss: 0.1680 - mae: 0.1680
# Epoch 720/1000
# 3/3 [==============================] - 0s 131ms/step - loss: 0.1675 - mae: 0.1675
# Epoch 721/1000
# 3/3 [==============================] - 0s 128ms/step - loss: 0.1678 - mae: 0.1678
# Epoch 722/1000
# 3/3 [==============================] - 0s 132ms/step - loss: 0.1674 - mae: 0.1674
# Epoch 723/1000
# 3/3 [==============================] - 1s 194ms/step - loss: 0.1670 - mae: 0.1670
# Epoch 724/1000
# 3/3 [==============================] - 0s 146ms/step - loss: 0.1672 - mae: 0.1672
# Epoch 725/1000
# 3/3 [==============================] - 0s 132ms/step - loss: 0.1665 - mae: 0.1665
# Epoch 726/1000
# 3/3 [==============================] - 0s 133ms/step - loss: 0.1665 - mae: 0.1665
# Epoch 727/1000
# 3/3 [==============================] - 0s 132ms/step - loss: 0.1666 - mae: 0.1666
# Epoch 728/1000
# 3/3 [==============================] - 0s 127ms/step - loss: 0.1677 - mae: 0.1677
# Epoch 729/1000
# 3/3 [==============================] - 0s 131ms/step - loss: 0.1668 - mae: 0.1668
# Epoch 730/1000
# 3/3 [==============================] - 0s 128ms/step - loss: 0.1668 - mae: 0.1668
# Epoch 731/1000
# 3/3 [==============================] - 0s 135ms/step - loss: 0.1667 - mae: 0.1667
# Epoch 732/1000
# 3/3 [==============================] - 0s 131ms/step - loss: 0.1675 - mae: 0.1675
# Epoch 733/1000
# 3/3 [==============================] - 0s 130ms/step - loss: 0.1671 - mae: 0.1671
# Epoch 734/1000
# 3/3 [==============================] - 0s 132ms/step - loss: 0.1666 - mae: 0.1666
# Epoch 735/1000
# 3/3 [==============================] - 0s 127ms/step - loss: 0.1665 - mae: 0.1665
# Epoch 736/1000
# 3/3 [==============================] - 0s 137ms/step - loss: 0.1660 - mae: 0.1660
# Epoch 737/1000
# 3/3 [==============================] - 0s 130ms/step - loss: 0.1666 - mae: 0.1666
# Epoch 738/1000
# 3/3 [==============================] - 0s 134ms/step - loss: 0.1660 - mae: 0.1660
# Epoch 739/1000
# 3/3 [==============================] - 0s 132ms/step - loss: 0.1660 - mae: 0.1660
# Epoch 740/1000
# 3/3 [==============================] - 0s 143ms/step - loss: 0.1658 - mae: 0.1658
# Epoch 741/1000
# 3/3 [==============================] - 0s 141ms/step - loss: 0.1660 - mae: 0.1660
# Epoch 742/1000
# 3/3 [==============================] - 0s 127ms/step - loss: 0.1660 - mae: 0.1660
# Epoch 743/1000
# 3/3 [==============================] - 0s 132ms/step - loss: 0.1655 - mae: 0.1655
# Epoch 744/1000
# 3/3 [==============================] - 0s 130ms/step - loss: 0.1658 - mae: 0.1658
# Epoch 745/1000
# 3/3 [==============================] - 0s 134ms/step - loss: 0.1681 - mae: 0.1681
# Epoch 746/1000
# 3/3 [==============================] - 0s 137ms/step - loss: 0.1660 - mae: 0.1660
# Epoch 747/1000
# 3/3 [==============================] - 0s 134ms/step - loss: 0.1660 - mae: 0.1660
# Epoch 748/1000
# 3/3 [==============================] - 0s 133ms/step - loss: 0.1657 - mae: 0.1657
# Epoch 749/1000
# 3/3 [==============================] - 0s 129ms/step - loss: 0.1658 - mae: 0.1658
# Epoch 750/1000
# 3/3 [==============================] - 0s 133ms/step - loss: 0.1665 - mae: 0.1665
# Epoch 751/1000
# 3/3 [==============================] - 0s 137ms/step - loss: 0.1673 - mae: 0.1673
# Epoch 752/1000
# 3/3 [==============================] - 0s 133ms/step - loss: 0.1690 - mae: 0.1690
# Epoch 753/1000
# 3/3 [==============================] - 0s 136ms/step - loss: 0.1688 - mae: 0.1688
# Epoch 754/1000
# 3/3 [==============================] - 0s 127ms/step - loss: 0.1676 - mae: 0.1676
# Epoch 755/1000
# 3/3 [==============================] - 0s 133ms/step - loss: 0.1685 - mae: 0.1685
# Epoch 756/1000
# 3/3 [==============================] - 0s 139ms/step - loss: 0.1691 - mae: 0.1691
# Epoch 757/1000
# 3/3 [==============================] - 0s 127ms/step - loss: 0.1673 - mae: 0.1673
# Epoch 758/1000
# 3/3 [==============================] - 0s 142ms/step - loss: 0.1673 - mae: 0.1673

# %%
model = load_model('0920_seq2seq_tensorflow_TEST.h5')
pred = model.predict(testx_elec)
pred = np.reshape(pred,(-1,1))

real = np.array(testy_elec)
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 40/40 [==============================] - 1s 13ms/step

# %%
from sklearn.metrics import mean_absolute_error
print('MAE : ', round(mean_absolute_error(real, pred),4)) 

from sklearn.metrics import mean_squared_error
print('MSE : ', round(mean_squared_error(real, pred),4))

from sklearn.metrics import r2_score
print('R2 : ', round(r2_score(real, pred),4))
# Out:
# MAE :  0.1358
# MSE :  0.031
# R2 :  0.4472

# %%
plt.figure(figsize=(30,5))
plt.ylabel('ELEC')
plt.plot(real, color='red', label='True')
plt.plot(pred, color='blue', label='Pred')
plt.legend()
plt.show()

# %%
# def seq2seq_model(input_shape):
#     model_input = tf.keras.layers.Input(shape=input_shape)

#     decoder_lstm2 = tf.keras.layers.LSTM(32, return_sequences=True, activation='tanh', use_bias=False)
#     decoder_lstm3 = tf.keras.layers.LSTM(64, return_sequences=True, activation='tanh', use_bias=False)


#     #디코더
#     decoder_lstm2_output = decoder_lstm2(model_input)
#     decoder_lstm3_output = decoder_lstm3(decoder_lstm2_output)

#     flatten = tf.keras.layers.Flatten()(decoder_lstm3_output)
#     model_output = tf.keras.layers.Dense(1)(flatten)
    
#     model = tf.keras.models.Model(model_input, model_output)
    
#     return model

# %%
# class Seq2SeqModel(tf.keras.Model):
#     def __init__(self):
#         super(Seq2SeqModel, self).__init__()
        
#         # for feature extracting
#         self.conv1 = tf.keras.layers.Conv1D(64, 1)
#         self.pool1 = tf.keras.layers.MaxPool1D(pool_size=2, strides=1, padding='same')
#         self.conv2 = tf.keras.layers.Conv1D(32, 1)
#         self.pool2 = tf.keras.layers.MaxPool1D(pool_size=2, strides=1, padding='same')
#         self.conv3 = tf.keras.layers.Conv1D(128, 1)
#         self.pool3 = tf.keras.layers.MaxPool1D(pool_size=2, strides=1, padding='same')
        
#         # Encoder
#         self.encoder1 = tf.keras.layers.LSTM(64, return_sequences=True, activation='tanh', use_bias=False)
#         self.encoder2 = tf.keras.layers.LSTM(32, return_sequences=True, activation='tanh', use_bias=False)
#         self.encoder3 = tf.keras.layers.LSTM(128, return_sequences=True, activation='tanh', use_bias=False)
        
#         # Decoder
#         self.decoder1 = tf.keras.layers.LSTM(128, return_sequences=True, activation='tanh', use_bias=False)
#         self.decoder2 = tf.keras.layers.LSTM(32, return_sequences=True, activation='tanh', use_bias=False)
#         self.decoder3 = tf.keras.layers.LSTM(64, return_sequences=True, activation='tanh', use_bias=False)
        
#         self.flatten = tf.keras.layers.Flatten()
#         self.dense = tf.keras.layers.Dense(1, activation='linear')
#         self.tanh = tf.keras.layers.Activation('tanh')
#         self.swish = Swish()  # 이 활성화 함수는 따로 정의해야 합니다.

#     def call(self, inputs):
#         x = tf.transpose(inputs, perm=[0, 2, 1])
#         x = self.conv1(x)
#         x = self.swish(x)
#         x = tf.transpose(x, perm=[0, 2, 1])
#         x = self.pool1(x)
#         x = tf.pad(x, [[0, 0], [0, 0], [0, 1]], mode='REFLECT')
        
#         x = tf.transpose(x, perm=[0, 2, 1])
#         x = self.conv2(x)
#         x = self.swish(x)
#         x = tf.transpose(x, perm=[0, 2, 1])
#         x = self.pool2(x)
#         x = tf.pad(x, [[0, 0], [0, 0], [0, 1]], mode='REFLECT')
        
#         x = tf.transpose(x, perm=[0, 2, 1])
#         x = self.conv3(x)
#         x = self.swish(x)
#         x = tf.transpose(x, perm=[0, 2, 1])
#         x = self.pool3(x)
#         x = tf.pad(x, [[0, 0], [0, 0], [0, 1]], mode='REFLECT')
        
#         x = self.encoder1(x)
#         x = self.tanh(x)
#         x = self.encoder2(x)
#         x = self.tanh(x)
#         x = self.encoder3(x)
#         x = self.tanh(x)
#         x = self.decoder1(x)
#         x = self.tanh(x)
#         x = self.decoder2(x)
#         x = self.tanh(x)
#         x = self.decoder3(x)
#         x = self.tanh(x)
#         x = self.flatten(x)
#         x = self.dense(x)
#         x = self.swish(x)
#         return x

# # Swish 활성화 함수 정의
# class Swish(tf.keras.layers.Layer):
#     def call(self, inputs):
#         return tf.keras.backend.sigmoid(inputs) * inputs

# %%
# # 모델 생성
# model = Seq2SeqModel()

# %%
# model = Seq2SeqModel()
# model.build(input_shape=(None, 24, 12))  # 입력 데이터의 크기에 맞게 모델을 빌드합니다.
# model.summary()
