# %%
from tqdm.notebook import tqdm
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.utils.data as data_util
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader
from sklearn.preprocessing import MinMaxScaler
from torchsummary import summary
from sklearn.metrics import r2_score
import math
import torch.nn as nn
import torch.nn.functional as F
from sklearn.model_selection import train_test_split

# %%
CUDA = torch.cuda.is_available()
print(CUDA)

device = torch.device('cuda:0' if CUDA else 'cpu')
# Out:
# True

# %%
dhw_merge = pd.read_csv('dhw_merge.csv')
elec_merge  = pd.read_csv('elec_merge.csv')

# %%
elec_merge = elec_merge.drop(['YEAR'], axis=1)
dhw_merge = dhw_merge.drop(['YEAR'], axis=1)

# %%
dhw_X = dhw_merge.drop(['DHW'], axis=1)
dhw_Y = dhw_merge[['DHW']]

scaler_dhw = MinMaxScaler()
scaler_dhw.fit(dhw_X)
scaled_dhw_X = scaler_dhw.transform(dhw_X)

new_dhw_X = pd.DataFrame(scaled_dhw_X, index=dhw_X.index, columns=dhw_X.columns)
new_dhw = pd.concat([new_dhw_X, dhw_Y], axis=1)

# %%
elec_X = elec_merge.drop(['ELEC'], axis=1)
elec_Y = elec_merge[['ELEC']]

scaler_elec = MinMaxScaler()
scaler_elec.fit(elec_X)
scaled_elec_X = scaler_elec.transform(elec_X)

new_elec_X = pd.DataFrame(scaled_elec_X, index=elec_X.index, columns=elec_X.columns)
new_elec = pd.concat([new_elec_X, elec_Y], axis=1)

# %%
input_dhw = new_dhw.iloc[:-1,]
target_dhw = new_dhw[['DHW']].iloc[1:]

trainX_dhw, testX_dhw, trainY_dhw, testY_dhw = train_test_split(input_dhw,target_dhw,test_size=0.3,shuffle=False,random_state=0)

# %%
input_elec = new_elec.iloc[:-1,]
target_elec = new_elec[['ELEC']].iloc[1:]

trainX_elec, testX_elec, trainY_elec, testY_elec = train_test_split(input_elec,target_elec,test_size=0.3,shuffle=False,random_state=0)

# %%
seqLength = 24
def buildDataSet(input, target, seqLength):
    xdata = []
    ydata = []
    for i in range(len(input) - seqLength):
        tx = input.iloc[i:i+seqLength]
        ty = target.iloc[i+seqLength-1]
        xdata.append(tx)
        ydata.append(ty)
    return np.array(xdata), np.array(ydata)

# %%
trainx_dhw, trainy_dhw = buildDataSet(trainX_dhw, trainY_dhw, 24)
testx_dhw, testy_dhw = buildDataSet(testX_dhw, testY_dhw, 24)
trainx_elec, trainy_elec = buildDataSet(trainX_elec, trainY_elec, 24)
testx_elec, testy_elec = buildDataSet(testX_elec, testY_elec, 24)

# %%
# 텐서로 변환
elec_trainx_tensor = torch.FloatTensor(trainx_elec)
elec_trainy_tensor = torch.FloatTensor(trainy_elec)

elec_testx_tensor = torch.FloatTensor(testx_elec)
elec_testy_tensor = torch.FloatTensor(testy_elec)

dhw_trainx_tensor = torch.FloatTensor(trainx_dhw)
dhw_trainy_tensor = torch.FloatTensor(trainy_dhw)

dhw_testx_tensor = torch.FloatTensor(testx_dhw)
dhw_testy_tensor = torch.FloatTensor(testy_dhw)

# %%
# 텐서 형태로 데이터 정의
elec_train = TensorDataset(elec_trainx_tensor, elec_trainy_tensor)
elec_test = TensorDataset(elec_testx_tensor, elec_testy_tensor)

dhw_train = TensorDataset(dhw_trainx_tensor, dhw_trainy_tensor)
dhw_test = TensorDataset(dhw_testx_tensor, dhw_testy_tensor)

# %%
batch_for_elec_train = 128
batch_for_elec_test = 128
batch_for_dhw_train = 128
batch_for_dhw_test = 128

ELEC_train = DataLoader(elec_train,
                        batch_size=batch_for_elec_train,
                        shuffle=False,  
                        drop_last=False)

ELEC_test = DataLoader(elec_test,
                        batch_size=batch_for_elec_test,
                        shuffle=False,  
                        drop_last=False)

DHW_train = DataLoader(dhw_train,
                        batch_size=batch_for_dhw_train,
                        shuffle=False,  
                        drop_last=True)

DHW_test = DataLoader(dhw_test,
                        batch_size=batch_for_dhw_test,
                        shuffle=False,  
                        drop_last=True)

# %%
# 데이터셋의 개수를 가정하여 변수에 저장
elec_train_size = len(elec_train)
elec_test_size = len(elec_test)
dhw_train_size = len(dhw_train)
dhw_test_size = len(dhw_test)

# 각 DataLoader에서 생성되는 배치의 개수 계산
elec_train_batches = math.ceil(elec_train_size / batch_for_elec_train)
elec_test_batches = math.ceil(elec_test_size / batch_for_elec_test)
dhw_train_batches = math.ceil(dhw_train_size / batch_for_dhw_train)
dhw_test_batches = math.ceil(dhw_test_size / batch_for_dhw_test)

# 결과 출력
print("elec_train batches:", elec_train_batches)
print("elec_test batches:", elec_test_batches)
print("dhw_train batches:", dhw_train_batches)
print("dhw_test batches:", dhw_test_batches)
# Out:
# elec_train batches: 24
# elec_test batches: 10
# dhw_train batches: 160
# dhw_test batches: 69

# %% [markdown]
# # 모델 구조 선언

# %%
class Swish(nn.Module):
    def __init__(self):
        super().__init__()
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        return x * self.sigmoid(x)

# %%
class Seq2SeqModel(nn.Module):
    def __init__(self):
        super(Seq2SeqModel, self).__init__()
        
        # for feature extracting
        self.conv1 = nn.Conv1d(12, 64, kernel_size=1)
        self.pool1 = nn.MaxPool1d(kernel_size=2, stride=1, padding=0)
        self.conv2 = nn.Conv1d(64, 32, kernel_size=1)
        self.pool2 = nn.MaxPool1d(kernel_size=2, stride=1, padding=0)
        self.conv3 = nn.Conv1d(32, 128, kernel_size=1)
        self.pool3 = nn.MaxPool1d(kernel_size=2, stride=1, padding=0)
        
        # Encoder
        self.encoder1 = nn.LSTM(128, 64, batch_first=True, bias=False)
        self.encoder2 = nn.LSTM(64, 32, batch_first=True, bias=False)
        self.encoder3 = nn.LSTM(32, 128, batch_first=True, bias=False)
        
        # Decoder
        self.decoder1 = nn.LSTM(128, 128, batch_first=True, bias=False)
        self.decoder2 = nn.LSTM(128, 32, batch_first=True, bias=False)
        self.decoder3 = nn.LSTM(32, 64, batch_first=True, bias=False)
        
        self.flatten = nn.Flatten()
        self.dense = nn.Linear(24 * 64, 1)
        self.tanh = nn.Tanh()
        self.swish = Swish()
        
    def forward(self, x):
        x = x.transpose(1,2)
        x = self.conv1(x)
        x = self.swish(x)
        x = x.transpose(2,1)
        x = self.pool1(x)
        x = F.pad(x, (0, 1), 'replicate', 0)
        
        x = x.transpose(1,2)
        x = self.conv2(x)
        x = self.swish(x)
        x = x.transpose(2,1)
        x = self.pool2(x)
        x = F.pad(x, (0, 1), 'replicate', 0)
        
        x = x.transpose(1,2)
        x = self.conv3(x)
        x = self.swish(x)
        x = x.transpose(2,1)
        x = self.pool3(x)
        x = F.pad(x, (0, 1), 'replicate', 0)
        
        #x = x.transpose(2,1)
        x, _ = self.encoder1(x)
        x = self.tanh(x)
        x, _ = self.encoder2(x)
        x = self.tanh(x)
        x, (h, c) = self.encoder3(x)
        x = self.tanh(x)
        x, _ = self.decoder1(x, (h, c))
        x = self.tanh(x)
        x, _ = self.decoder2(x)
        x = self.tanh(x)
        x, _ = self.decoder3(x)
        x = self.tanh(x)
        x = x.reshape(-1, 64 * 24)
        x = self.dense(x)
        return x

# %%
class seq_loss(nn.Module):
    def __init__(self):
        super(seq_loss, self).__init__()
        self.reg = nn.L1Loss()
        
    def forward(self, pred, real):
        x = pred
        loss = self.reg(x, real)
        
        return loss

# %%
# hoxy = Seq2SeqModel()
# inputx = torch.randn(512,24,12)
# hoxy2 = hoxy(inputx)
# print(hoxy2.shape)

# %%
model = Seq2SeqModel().to(device)
loss_fn = seq_loss().to(device)

# %%
from torchinfo import summary

summary(model, (1024,24,12))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Seq2SeqModel                             [1024, 1]                 --
# ├─Conv1d: 1-1                            [1024, 64, 24]            832
# ├─Swish: 1-2                             [1024, 64, 24]            --
# │    └─Sigmoid: 2-1                      [1024, 64, 24]            --
# ├─MaxPool1d: 1-3                         [1024, 24, 63]            --
# ├─Conv1d: 1-4                            [1024, 32, 24]            2,080
# ├─Swish: 1-5                             [1024, 32, 24]            --
# │    └─Sigmoid: 2-2                      [1024, 32, 24]            --
# ├─MaxPool1d: 1-6                         [1024, 24, 31]            --
# ├─Conv1d: 1-7                            [1024, 128, 24]           4,224
# ├─Swish: 1-8                             [1024, 128, 24]           --
# │    └─Sigmoid: 2-3                      [1024, 128, 24]           --
# ├─MaxPool1d: 1-9                         [1024, 24, 127]           --
# ├─LSTM: 1-10                             [1024, 24, 64]            49,152
# ├─Tanh: 1-11                             [1024, 24, 64]            --
# ├─LSTM: 1-12                             [1024, 24, 32]            12,288
# ├─Tanh: 1-13                             [1024, 24, 32]            --
# ├─LSTM: 1-14                             [1024, 24, 128]           81,920
# ├─Tanh: 1-15                             [1024, 24, 128]           --
# ├─LSTM: 1-16                             [1024, 24, 128]           131,072
# ├─Tanh: 1-17                             [1024, 24, 128]           --
# ├─LSTM: 1-18                             [1024, 24, 32]            20,480
# ├─Tanh: 1-19                             [1024, 24, 32]            --
# ├─LSTM: 1-20                             [1024, 24, 64]            24,576
# ├─Tanh: 1-21                             [1024, 24, 64]            --
# ├─Linear: 1-22                           [1024, 1]                 1,537
# ==========================================================================================
# Total params: 328,161
# Trainable params: 328,161
# Non-trainable params: 0
# Total mult-adds (G): 8.03
# ==========================================================================================
# Input size (MB): 1.18
# Forward/backward pass size (MB): 132.13
# Params size (MB): 1.31
# Estimated Total Size (MB): 134.62
# ==========================================================================================

# %%
from torch.optim.lr_scheduler import LinearLR

# 손실 함수와 옵티마이저 정의
epochs = 1000
model.train()

optimizer = torch.optim.Adamax(model.parameters(), lr=3e-4)#, weight_decay=0.01)
#scheduler = LinearLR(optimizer, start_factor=1.0, end_factor=0.0, total_iters = epochs * len(DHW_train))

patience = 30  # Early stopping을 위한 기다리는 최대 epoch 수
best_loss = float('inf')
best_model_state_dict = None
counter = 0  # Early stopping 카운터

# 모델 학습
model.train() # 훈련 모드 설정

for epoch in range(1, epochs+1):
    running_loss = 0
    for step, samples in enumerate(DHW_train):
        inputs = samples[0].to(device)
        targets = samples[1].to(device)
        pred = model(inputs)
        loss = loss_fn(pred, targets)
        
        running_loss += loss.item()
        # 그래디언트 계산 및 업데이트
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        #scheduler.step()
    # early stopping 및 모델 저장
    if running_loss / len(DHW_train) < best_loss:
        best_loss = running_loss / len(DHW_train)
        best_model_state_dict = model.state_dict()
        counter = 0  # Counter 초기화
    else:
        counter += 1
        if counter >= patience:
            print(f'Early stopping at epoch {epoch}')
            break
    print('Epoch : %d, Loss : %.4f' % (epoch, running_loss / len(DHW_train)))
    print('')

# 최상의 모델을 파일로 저장
if best_model_state_dict is not None:
    torch.save(best_model_state_dict, '0922_seq2seq_in_the_lab.pth')
# Out:
# Epoch : 1, Loss : 0.8050
#
# Epoch : 2, Loss : 0.7993
#
# Epoch : 3, Loss : 0.4304
#
# Epoch : 4, Loss : 0.2566
#
# Epoch : 5, Loss : 0.2033
#
# Epoch : 6, Loss : 0.1758
#
# Epoch : 7, Loss : 0.1682
#
# Epoch : 8, Loss : 0.1715
#
# Epoch : 9, Loss : 0.1638
#
# Epoch : 10, Loss : 0.1491
#
# Epoch : 11, Loss : 0.1892
#
# Epoch : 12, Loss : 0.1575
#
# Epoch : 13, Loss : 0.1389
#
# Epoch : 14, Loss : 0.1494
#
# Epoch : 15, Loss : 0.1800
#
# Epoch : 16, Loss : 0.1379
#
# Epoch : 17, Loss : 0.1729
#
# Epoch : 18, Loss : 0.1389
#
# Epoch : 19, Loss : 0.1266
#
# Epoch : 20, Loss : 0.1410
#
# Epoch : 21, Loss : 0.1610
#
# Epoch : 22, Loss : 0.1214
#
# Epoch : 23, Loss : 0.1548
#
# Epoch : 24, Loss : 0.1423
#
# Epoch : 25, Loss : 0.1188
#
# Epoch : 26, Loss : 0.1151
#
# Epoch : 27, Loss : 0.1710
#
# Epoch : 28, Loss : 0.1144
#
# Epoch : 29, Loss : 0.1262
#
# Epoch : 30, Loss : 0.1178
#
# Epoch : 31, Loss : 0.1061
#
# Epoch : 32, Loss : 0.1501
#
# Epoch : 33, Loss : 0.1151
#
# Epoch : 34, Loss : 0.1280
#
# Epoch : 35, Loss : 0.1100
#
# Epoch : 36, Loss : 0.0967
#
# Epoch : 37, Loss : 0.1465
#
# Epoch : 38, Loss : 0.1041
#
# Epoch : 39, Loss : 0.1145
#
# Epoch : 40, Loss : 0.1128
#
# Epoch : 41, Loss : 0.0928
#
# Epoch : 42, Loss : 0.1439
#
# Epoch : 43, Loss : 0.0912
#
# Epoch : 44, Loss : 0.0793
#
# Epoch : 45, Loss : 0.1176
#
# Epoch : 46, Loss : 0.1005
#
# Epoch : 47, Loss : 0.0887
#
# Epoch : 48, Loss : 0.1392
#
# Epoch : 49, Loss : 0.0953
#
# Epoch : 50, Loss : 0.0776
#
# Epoch : 51, Loss : 0.1219
#
# Epoch : 52, Loss : 0.1176
#
# Epoch : 53, Loss : 0.0873
#
# Epoch : 54, Loss : 0.1131
#
# Epoch : 55, Loss : 0.0973
#
# Epoch : 56, Loss : 0.0774
#
# Epoch : 57, Loss : 0.0724
#
# Epoch : 58, Loss : 0.1321
#
# Epoch : 59, Loss : 0.0819
#
# Epoch : 60, Loss : 0.0685
#
# Epoch : 61, Loss : 0.1018
#
# Epoch : 62, Loss : 0.0822
#
# Epoch : 63, Loss : 0.0657
#
# Epoch : 64, Loss : 0.0865
#
# Epoch : 65, Loss : 0.1075
#
# Epoch : 66, Loss : 0.0733
#
# Epoch : 67, Loss : 0.0711
#
# Epoch : 68, Loss : 0.1231
#
# Epoch : 69, Loss : 0.0713
#
# Epoch : 70, Loss : 0.0646
#
# Epoch : 71, Loss : 0.1143
#
# Epoch : 72, Loss : 0.0874
#
# Epoch : 73, Loss : 0.0663
#
# Epoch : 74, Loss : 0.1157
#
# Epoch : 75, Loss : 0.0739
#
# Epoch : 76, Loss : 0.0635
#
# Epoch : 77, Loss : 0.1082
#
# Epoch : 78, Loss : 0.0857
#
# Epoch : 79, Loss : 0.0640
#
# Epoch : 80, Loss : 0.1065
#
# Epoch : 81, Loss : 0.0687
#
# Epoch : 82, Loss : 0.0612
#
# Epoch : 83, Loss : 0.1005
#
# Epoch : 84, Loss : 0.0763
#
# Epoch : 85, Loss : 0.0639
#
# Epoch : 86, Loss : 0.1049
#
# Epoch : 87, Loss : 0.0599
#
# Epoch : 88, Loss : 0.0583
#
# Epoch : 89, Loss : 0.0930
#
# Epoch : 90, Loss : 0.0623
#
# Epoch : 91, Loss : 0.0654
#
# Epoch : 92, Loss : 0.0961
#
# Epoch : 93, Loss : 0.0605
#
# Epoch : 94, Loss : 0.0944
#
# Epoch : 95, Loss : 0.0636
#
# Epoch : 96, Loss : 0.0583
#
# Epoch : 97, Loss : 0.0991
#
# Epoch : 98, Loss : 0.0567
#
# Epoch : 99, Loss : 0.0715
#
# Epoch : 100, Loss : 0.0754
#
# Epoch : 101, Loss : 0.0582
#
# Epoch : 102, Loss : 0.0967
#
# Epoch : 103, Loss : 0.0550
#
# Epoch : 104, Loss : 0.0736
#
# Epoch : 105, Loss : 0.0709
#
# Epoch : 106, Loss : 0.0567
#
# Epoch : 107, Loss : 0.0939
#
# Epoch : 108, Loss : 0.0528
#
# Epoch : 109, Loss : 0.0693
#
# Epoch : 110, Loss : 0.0722
#
# Epoch : 111, Loss : 0.0589
#
# Epoch : 112, Loss : 0.0926
#
# Epoch : 113, Loss : 0.0545
#
# Epoch : 114, Loss : 0.0838
#
# Epoch : 115, Loss : 0.0546
#
# Epoch : 116, Loss : 0.0516
#
# Epoch : 117, Loss : 0.0660
#
# Epoch : 118, Loss : 0.0589
#
# Epoch : 119, Loss : 0.0835
#
# Epoch : 120, Loss : 0.0503
#
# Epoch : 121, Loss : 0.0681
#
# Epoch : 122, Loss : 0.0605
#
# Epoch : 123, Loss : 0.0678
#
# Epoch : 124, Loss : 0.0708
#
# Epoch : 125, Loss : 0.0566
#
# Epoch : 126, Loss : 0.0885
#
# Epoch : 127, Loss : 0.0524
#
# Epoch : 128, Loss : 0.0795
#
# Epoch : 129, Loss : 0.0555
#
# Epoch : 130, Loss : 0.0597
#
# Epoch : 131, Loss : 0.0752
#
# Epoch : 132, Loss : 0.0612
#
# Epoch : 133, Loss : 0.0844
#
# Epoch : 134, Loss : 0.0550
#
# Epoch : 135, Loss : 0.0822
#
# Epoch : 136, Loss : 0.0514
#
# Epoch : 137, Loss : 0.0766
#
# Epoch : 138, Loss : 0.0525
#
# Epoch : 139, Loss : 0.0645
#
# Epoch : 140, Loss : 0.0589
#
# Epoch : 141, Loss : 0.0683
#
# Epoch : 142, Loss : 0.0593
#
# Epoch : 143, Loss : 0.0512
#
# Epoch : 144, Loss : 0.0755
#
# Epoch : 145, Loss : 0.0519
#
# Epoch : 146, Loss : 0.0759
#
# Epoch : 147, Loss : 0.0505
#
# Epoch : 148, Loss : 0.0753
#
# Epoch : 149, Loss : 0.0492
#
# Epoch : 150, Loss : 0.0687
#
# Epoch : 151, Loss : 0.0525
#
# Epoch : 152, Loss : 0.0806
#
# Epoch : 153, Loss : 0.0479
#
# Epoch : 154, Loss : 0.0615
#
# Epoch : 155, Loss : 0.0580
#
# Epoch : 156, Loss : 0.0723
#
# Epoch : 157, Loss : 0.0522
#
# Epoch : 158, Loss : 0.0471
#
# Epoch : 159, Loss : 0.0530
#
# Epoch : 160, Loss : 0.0549
#
# Epoch : 161, Loss : 0.0809
#
# Epoch : 162, Loss : 0.0496
#
# Epoch : 163, Loss : 0.0722
#
# Epoch : 164, Loss : 0.0514
#
# Epoch : 165, Loss : 0.0754
#
# Epoch : 166, Loss : 0.0484
#
# Epoch : 167, Loss : 0.0635
#
# Epoch : 168, Loss : 0.0516
#
# Epoch : 169, Loss : 0.0786
#
# Epoch : 170, Loss : 0.0478
#
# Epoch : 171, Loss : 0.0552
#
# Epoch : 172, Loss : 0.0591
#
# Epoch : 173, Loss : 0.0677
#
# Epoch : 174, Loss : 0.0524
#
# Epoch : 175, Loss : 0.0465
#
# Epoch : 176, Loss : 0.0580
#
# Epoch : 177, Loss : 0.0509
#
# Epoch : 178, Loss : 0.0754
#
# Epoch : 179, Loss : 0.0467
#
# Epoch : 180, Loss : 0.0663
#
# Epoch : 181, Loss : 0.0514
#
# Epoch : 182, Loss : 0.0734
#
# Epoch : 183, Loss : 0.0474
#
# Epoch : 184, Loss : 0.0634
#
# Epoch : 185, Loss : 0.0495
#
# Epoch : 186, Loss : 0.0739
#
# Epoch : 187, Loss : 0.0476
#
# Epoch : 188, Loss : 0.0584
#
# Epoch : 189, Loss : 0.0510
#
# Epoch : 190, Loss : 0.0749
#
# Epoch : 191, Loss : 0.0466
#
# Epoch : 192, Loss : 0.0557
#
# Epoch : 193, Loss : 0.0513
#
# Epoch : 194, Loss : 0.0777
#
# Epoch : 195, Loss : 0.0480
#
# Epoch : 196, Loss : 0.0607
#
# Epoch : 197, Loss : 0.0499
#
# Epoch : 198, Loss : 0.0728
#
# Epoch : 199, Loss : 0.0455
#
# Epoch : 200, Loss : 0.0568
#
# Epoch : 201, Loss : 0.0531
#
# Epoch : 202, Loss : 0.0760
#
# Epoch : 203, Loss : 0.0451
#
# Epoch : 204, Loss : 0.0541
#
# Epoch : 205, Loss : 0.0538
#
# Epoch : 206, Loss : 0.0728
#
# Epoch : 207, Loss : 0.0449
#
# Epoch : 208, Loss : 0.0599
#
# Epoch : 209, Loss : 0.0495
#
# Epoch : 210, Loss : 0.0727
#
# Epoch : 211, Loss : 0.0466
#
# Epoch : 212, Loss : 0.0580
#
# Epoch : 213, Loss : 0.0485
#
# Epoch : 214, Loss : 0.0726
#
# Epoch : 215, Loss : 0.0453
#
# Epoch : 216, Loss : 0.0588
#
# Epoch : 217, Loss : 0.0503
#
# Epoch : 218, Loss : 0.0748
#
# Epoch : 219, Loss : 0.0438
#
# Epoch : 220, Loss : 0.0548
#
# Epoch : 221, Loss : 0.0515
#
# Epoch : 222, Loss : 0.0740
#
# Epoch : 223, Loss : 0.0445
#
# Epoch : 224, Loss : 0.0490
#
# Epoch : 225, Loss : 0.0548
#
# Epoch : 226, Loss : 0.0700
#
# Epoch : 227, Loss : 0.0450
#
# Epoch : 228, Loss : 0.0480
#
# Epoch : 229, Loss : 0.0484
#
# Epoch : 230, Loss : 0.0687
#
# Epoch : 231, Loss : 0.0469
#
# Epoch : 232, Loss : 0.0595
#
# Epoch : 233, Loss : 0.0492
#
# Epoch : 234, Loss : 0.0690
#
# Epoch : 235, Loss : 0.0468
#
# Epoch : 236, Loss : 0.0614
#
# Epoch : 237, Loss : 0.0492
#
# Epoch : 238, Loss : 0.0672
#
# Epoch : 239, Loss : 0.0468
#
# Epoch : 240, Loss : 0.0609
#
# Epoch : 241, Loss : 0.0483
#
# Epoch : 242, Loss : 0.0658
#
# Epoch : 243, Loss : 0.0476
#
# Epoch : 244, Loss : 0.0585
#
# Epoch : 245, Loss : 0.0514
#
# Epoch : 246, Loss : 0.0664
#
# Epoch : 247, Loss : 0.0499
#
# Epoch : 248, Loss : 0.0627
#
# Early stopping at epoch 249

# %%
# # 모델의 가중치를 출력
# for name, param in model.named_parameters():
#     if param.requires_grad:
#         print(name, param.data)

# %%
best_model = Seq2SeqModel().to(device)
best_model.load_state_dict(torch.load('0922_seq2seq_in_the_lab.pth'))
best_model.eval()

train_pred_list = []
train_target_list = []

for step, samples in enumerate(DHW_train):
    inputs = samples[0].to(device)
    targets = samples[1].to(device)
    #print(inputs)
    pred = best_model(inputs)
    #print(pred)    
    train_target_list.extend(targets.detach().cpu().numpy())
    train_pred_list.extend(pred.detach().cpu().numpy())
#print(np.shape(train_pred_list))
#print(np.shape(train_target_list))
#    
r2 = r2_score(train_target_list, train_pred_list)
print('r2 score', r2)
# Out:
# r2 score 0.9564432015525869

# %%
plt.figure(figsize=(40,10))
plt.plot(train_target_list, color='red', label='real')
plt.plot(train_pred_list, color='blue', label='pred')
plt.legend()
plt.show()

# %%
best_model = Seq2SeqModel().to(device)
best_model.load_state_dict(torch.load('0922_seq2seq_in_the_lab.pth'))
best_model.eval()

test_pred_list = []
test_output_list = []
for step, samples in enumerate(DHW_test):
    inputs = samples[0].to(device)
    targets = samples[1].to(device)
    
    pred = best_model(inputs)
    
    test_output_list.extend(targets.detach().cpu().numpy())
    test_pred_list.extend(pred.detach().cpu().numpy())
r2 = r2_score(test_output_list, test_pred_list)
print('r2 score', r2)
# Out:
# r2 score 0.965507461472959

# %%
plt.figure(figsize=(40,10))
plt.plot(test_output_list, color='red', label='real')
plt.plot(test_pred_list, color='blue', label='pred')
plt.legend()
plt.show()

# %%
# class Seq2SeqModel(nn.Module):
#     def __init__(self):
#         super(Seq2SeqModel, self).__init__()
#         self.decoder2 = nn.LSTM(12, 32, batch_first=True, bias=False)
#         self.decoder3 = nn.LSTM(32, 64, batch_first=True, bias=False)
        
#         self.flatten = nn.Flatten()
#         self.dense = nn.Linear(24*64, 1)
#         self.tanh = nn.Tanh()
#         self.swish = Swish()
        
#     def forward(self, x):
#         x, _ = self.decoder2(x)
#         x = self.tanh(x)
#         x, _ = self.decoder3(x)
#         x = self.tanh(x)
#         x = x.reshape(-1, 24*64)
#         x = self.dense(x)
#         x = self.swish(x)
#         return x

# %%
# model2 = Seq2SeqModel().to(device)

# %%
# from torchinfo import summary

# summary(model2, (1024,24,12))
