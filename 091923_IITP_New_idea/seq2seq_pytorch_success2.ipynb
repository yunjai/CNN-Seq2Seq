# %%
from tqdm.notebook import tqdm
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.utils.data as data_util
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader
from sklearn.preprocessing import MinMaxScaler
from torchsummary import summary
from sklearn.metrics import r2_score
import math
import torch.nn as nn
import torch.nn.functional as F
from sklearn.model_selection import train_test_split

# %%
CUDA = torch.cuda.is_available()
print(CUDA)

device = torch.device('cuda:0' if CUDA else 'cpu')
# Out:
# True

# %%
dhw_merge = pd.read_csv('dhw_merge.csv')
elec_merge  = pd.read_csv('elec_merge.csv')

# %%
elec_merge = elec_merge.drop(['YEAR'], axis=1)
dhw_merge = dhw_merge.drop(['YEAR'], axis=1)

# %%
dhw_X = dhw_merge.drop(['DHW'], axis=1)
dhw_Y = dhw_merge[['DHW']]

scaler_dhw = MinMaxScaler()
scaler_dhw.fit(dhw_X)
scaled_dhw_X = scaler_dhw.transform(dhw_X)

new_dhw_X = pd.DataFrame(scaled_dhw_X, index=dhw_X.index, columns=dhw_X.columns)
new_dhw = pd.concat([new_dhw_X, dhw_Y], axis=1)

# %%
elec_X = elec_merge.drop(['ELEC'], axis=1)
elec_Y = elec_merge[['ELEC']]

scaler_elec = MinMaxScaler()
scaler_elec.fit(elec_X)
scaled_elec_X = scaler_elec.transform(elec_X)

new_elec_X = pd.DataFrame(scaled_elec_X, index=elec_X.index, columns=elec_X.columns)
new_elec = pd.concat([new_elec_X, elec_Y], axis=1)

# %%
input_dhw = new_dhw.iloc[:-1,]
target_dhw = new_dhw[['DHW']].iloc[1:]

trainX_dhw, testX_dhw, trainY_dhw, testY_dhw = train_test_split(input_dhw,target_dhw,test_size=0.3,shuffle=False,random_state=0)

# %%
input_elec = new_elec.iloc[:-1,]
target_elec = new_elec[['ELEC']].iloc[1:]

trainX_elec, testX_elec, trainY_elec, testY_elec = train_test_split(input_elec,target_elec,test_size=0.3,shuffle=False,random_state=0)

# %%
seqLength = 24
def buildDataSet(input, target, seqLength):
    xdata = []
    ydata = []
    for i in range(len(input) - seqLength):
        tx = input.iloc[i:i+seqLength]
        ty = target.iloc[i+seqLength-1]
        xdata.append(tx)
        ydata.append(ty)
    return np.array(xdata), np.array(ydata)

# %%
trainx_dhw, trainy_dhw = buildDataSet(trainX_dhw, trainY_dhw, 24)
testx_dhw, testy_dhw = buildDataSet(testX_dhw, testY_dhw, 24)
trainx_elec, trainy_elec = buildDataSet(trainX_elec, trainY_elec, 24)
testx_elec, testy_elec = buildDataSet(testX_elec, testY_elec, 24)

# %%
# 텐서로 변환
elec_trainx_tensor = torch.FloatTensor(trainx_elec)
elec_trainy_tensor = torch.FloatTensor(trainy_elec)

elec_testx_tensor = torch.FloatTensor(testx_elec)
elec_testy_tensor = torch.FloatTensor(testy_elec)

dhw_trainx_tensor = torch.FloatTensor(trainx_dhw)
dhw_trainy_tensor = torch.FloatTensor(trainy_dhw)

dhw_testx_tensor = torch.FloatTensor(testx_dhw)
dhw_testy_tensor = torch.FloatTensor(testy_dhw)

# %%
# 텐서 형태로 데이터 정의
elec_train = TensorDataset(elec_trainx_tensor, elec_trainy_tensor)
elec_test = TensorDataset(elec_testx_tensor, elec_testy_tensor)

dhw_train = TensorDataset(dhw_trainx_tensor, dhw_trainy_tensor)
dhw_test = TensorDataset(dhw_testx_tensor, dhw_testy_tensor)

# %%
batch_for_elec_train = 128
batch_for_elec_test = 128
batch_for_dhw_train = 128
batch_for_dhw_test = 128

ELEC_train = DataLoader(elec_train,
                        batch_size=batch_for_elec_train,
                        shuffle=False,  
                        drop_last=False)

ELEC_test = DataLoader(elec_test,
                        batch_size=batch_for_elec_test,
                        shuffle=False,  
                        drop_last=False)

DHW_train = DataLoader(dhw_train,
                        batch_size=batch_for_dhw_train,
                        shuffle=False,  
                        drop_last=True)

DHW_test = DataLoader(dhw_test,
                        batch_size=batch_for_dhw_test,
                        shuffle=False,  
                        drop_last=True)

# %%
# 데이터셋의 개수를 가정하여 변수에 저장
elec_train_size = len(elec_train)
elec_test_size = len(elec_test)
dhw_train_size = len(dhw_train)
dhw_test_size = len(dhw_test)

# 각 DataLoader에서 생성되는 배치의 개수 계산
elec_train_batches = math.ceil(elec_train_size / batch_for_elec_train)
elec_test_batches = math.ceil(elec_test_size / batch_for_elec_test)
dhw_train_batches = math.ceil(dhw_train_size / batch_for_dhw_train)
dhw_test_batches = math.ceil(dhw_test_size / batch_for_dhw_test)

# 결과 출력
print("elec_train batches:", elec_train_batches)
print("elec_test batches:", elec_test_batches)
print("dhw_train batches:", dhw_train_batches)
print("dhw_test batches:", dhw_test_batches)
# Out:
# elec_train batches: 24
# elec_test batches: 10
# dhw_train batches: 160
# dhw_test batches: 69

# %% [markdown]
# # 모델 구조 선언

# %%
class Swish(nn.Module):
    def __init__(self):
        super().__init__()
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        return x * self.sigmoid(x)

# %%
class Seq2SeqModel(nn.Module):
    def __init__(self):
        super(Seq2SeqModel, self).__init__()
        
        # for feature extracting
        self.conv1 = nn.Conv1d(12, 64, kernel_size=1)
        self.pool1 = nn.MaxPool1d(kernel_size=2, stride=1, padding=0)
        self.conv2 = nn.Conv1d(64, 32, kernel_size=1)
        self.pool2 = nn.MaxPool1d(kernel_size=2, stride=1, padding=0)
        self.conv3 = nn.Conv1d(32, 128, kernel_size=1)
        self.pool3 = nn.MaxPool1d(kernel_size=2, stride=1, padding=0)
        
        # Encoder
        self.encoder1 = nn.LSTM(128, 64, batch_first=True, bias=False)
        self.encoder2 = nn.LSTM(64, 32, batch_first=True, bias=False)
        self.encoder3 = nn.LSTM(32, 128, batch_first=True, bias=False)
        
        # Decoder
        self.decoder1 = nn.LSTM(128, 128, batch_first=True, bias=False)
        self.decoder2 = nn.LSTM(128, 32, batch_first=True, bias=False)
        self.decoder3 = nn.LSTM(32, 64, batch_first=True, bias=False)
        
        self.flatten = nn.Flatten()
        self.dense = nn.Linear(24 * 64, 1)
        self.tanh = nn.Tanh()
        self.swish = Swish()
        
    def forward(self, x):
        x = x.transpose(1,2)
        x = self.conv1(x)
        x = self.swish(x)
        x = x.transpose(2,1)
        x = self.pool1(x)
        x = F.pad(x, (0, 1), 'replicate', 0)
        
        x = x.transpose(1,2)
        x = self.conv2(x)
        x = self.swish(x)
        x = x.transpose(2,1)
        x = self.pool2(x)
        x = F.pad(x, (0, 1), 'replicate', 0)
        
        x = x.transpose(1,2)
        x = self.conv3(x)
        x = self.swish(x)
        x = x.transpose(2,1)
        x = self.pool3(x)
        x = F.pad(x, (0, 1), 'replicate', 0)
        
        #x = x.transpose(2,1)
        x, _ = self.encoder1(x)
        x = self.tanh(x)
        x, _ = self.encoder2(x)
        x = self.tanh(x)
        x, (h, c) = self.encoder3(x)
        x = self.tanh(x)
        x, _ = self.decoder1(x, (h, c))
        x = self.tanh(x)
        x, _ = self.decoder2(x)
        x = self.tanh(x)
        x, _ = self.decoder3(x)
        x = self.tanh(x)
        x = x.reshape(-1, 64 * 24)
        x = self.dense(x)
        return x

# %%
class seq_loss(nn.Module):
    def __init__(self):
        super(seq_loss, self).__init__()
        self.reg = nn.L1Loss()
        
    def forward(self, pred, real):
        x = pred
        loss = self.reg(x, real)
        
        return loss

# %%
# hoxy = Seq2SeqModel()
# inputx = torch.randn(512,24,12)
# hoxy2 = hoxy(inputx)
# print(hoxy2.shape)

# %%
model = Seq2SeqModel().to(device)
loss_fn = seq_loss().to(device)

# %%
from torchinfo import summary

summary(model, (1024,24,12))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Seq2SeqModel                             [1024, 1]                 --
# ├─Conv1d: 1-1                            [1024, 64, 24]            832
# ├─Swish: 1-2                             [1024, 64, 24]            --
# │    └─Sigmoid: 2-1                      [1024, 64, 24]            --
# ├─MaxPool1d: 1-3                         [1024, 24, 63]            --
# ├─Conv1d: 1-4                            [1024, 32, 24]            2,080
# ├─Swish: 1-5                             [1024, 32, 24]            --
# │    └─Sigmoid: 2-2                      [1024, 32, 24]            --
# ├─MaxPool1d: 1-6                         [1024, 24, 31]            --
# ├─Conv1d: 1-7                            [1024, 128, 24]           4,224
# ├─Swish: 1-8                             [1024, 128, 24]           --
# │    └─Sigmoid: 2-3                      [1024, 128, 24]           --
# ├─MaxPool1d: 1-9                         [1024, 24, 127]           --
# ├─LSTM: 1-10                             [1024, 24, 64]            49,152
# ├─Tanh: 1-11                             [1024, 24, 64]            --
# ├─LSTM: 1-12                             [1024, 24, 32]            12,288
# ├─Tanh: 1-13                             [1024, 24, 32]            --
# ├─LSTM: 1-14                             [1024, 24, 128]           81,920
# ├─Tanh: 1-15                             [1024, 24, 128]           --
# ├─LSTM: 1-16                             [1024, 24, 128]           131,072
# ├─Tanh: 1-17                             [1024, 24, 128]           --
# ├─LSTM: 1-18                             [1024, 24, 32]            20,480
# ├─Tanh: 1-19                             [1024, 24, 32]            --
# ├─LSTM: 1-20                             [1024, 24, 64]            24,576
# ├─Tanh: 1-21                             [1024, 24, 64]            --
# ├─Linear: 1-22                           [1024, 1]                 1,537
# ==========================================================================================
# Total params: 328,161
# Trainable params: 328,161
# Non-trainable params: 0
# Total mult-adds (G): 8.03
# ==========================================================================================
# Input size (MB): 1.18
# Forward/backward pass size (MB): 132.13
# Params size (MB): 1.31
# Estimated Total Size (MB): 134.62
# ==========================================================================================

# %%
from torch.optim.lr_scheduler import LinearLR

# 손실 함수와 옵티마이저 정의
epochs = 1000
model.train()

optimizer = torch.optim.Adamax(model.parameters(), lr=3e-4)#, weight_decay=0.01)
#scheduler = LinearLR(optimizer, start_factor=1.0, end_factor=0.0, total_iters = epochs * len(ELEC_train))

patience = 30  # Early stopping을 위한 기다리는 최대 epoch 수
best_loss = float('inf')
best_model_state_dict = None
counter = 0  # Early stopping 카운터

# 모델 학습
model.train() # 훈련 모드 설정

for epoch in range(1, epochs+1):
    running_loss = 0
    for step, samples in enumerate(ELEC_train):
        inputs = samples[0].to(device)
        targets = samples[1].to(device)
        pred = model(inputs)
        loss = loss_fn(pred, targets)
        
        running_loss += loss.item()
        # 그래디언트 계산 및 업데이트
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        #scheduler.step()
    # early stopping 및 모델 저장
    if running_loss / len(ELEC_train) < best_loss:
        best_loss = running_loss / len(ELEC_train)
        best_model_state_dict = model.state_dict()
        counter = 0  # Counter 초기화
    else:
        counter += 1
        if counter >= patience:
            print(f'Early stopping at epoch {epoch}')
            break
    print('Epoch : %d, Loss : %.4f' % (epoch, running_loss / len(ELEC_train)))
    print('')

# 최상의 모델을 파일로 저장
if best_model_state_dict is not None:
    torch.save(best_model_state_dict, '0922_seq2seq_pytorch.pth')
# Out:
# Epoch : 1, Loss : 0.5978
#
# Epoch : 2, Loss : 0.5426
#
# Epoch : 3, Loss : 0.2724
#
# Epoch : 4, Loss : 0.3560
#
# Epoch : 5, Loss : 0.2794
#
# Epoch : 6, Loss : 0.3318
#
# Epoch : 7, Loss : 0.2886
#
# Epoch : 8, Loss : 0.3163
#
# Epoch : 9, Loss : 0.2944
#
# Epoch : 10, Loss : 0.3031
#
# Epoch : 11, Loss : 0.2935
#
# Epoch : 12, Loss : 0.2932
#
# Epoch : 13, Loss : 0.2885
#
# Epoch : 14, Loss : 0.2825
#
# Epoch : 15, Loss : 0.2790
#
# Epoch : 16, Loss : 0.2720
#
# Epoch : 17, Loss : 0.2658
#
# Epoch : 18, Loss : 0.2610
#
# Epoch : 19, Loss : 0.2555
#
# Epoch : 20, Loss : 0.2521
#
# Epoch : 21, Loss : 0.2484
#
# Epoch : 22, Loss : 0.2454
#
# Epoch : 23, Loss : 0.2436
#
# Epoch : 24, Loss : 0.2417
#
# Epoch : 25, Loss : 0.2404
#
# Epoch : 26, Loss : 0.2393
#
# Epoch : 27, Loss : 0.2386
#
# Epoch : 28, Loss : 0.2378
#
# Epoch : 29, Loss : 0.2371
#
# Epoch : 30, Loss : 0.2364
#
# Epoch : 31, Loss : 0.2356
#
# Epoch : 32, Loss : 0.2347
#
# Epoch : 33, Loss : 0.2338
#
# Epoch : 34, Loss : 0.2331
#
# Epoch : 35, Loss : 0.2326
#
# Epoch : 36, Loss : 0.2321
#
# Epoch : 37, Loss : 0.2314
#
# Epoch : 38, Loss : 0.2308
#
# Epoch : 39, Loss : 0.2303
#
# Epoch : 40, Loss : 0.2300
#
# Epoch : 41, Loss : 0.2299
#
# Epoch : 42, Loss : 0.2297
#
# Epoch : 43, Loss : 0.2293
#
# Epoch : 44, Loss : 0.2290
#
# Epoch : 45, Loss : 0.2287
#
# Epoch : 46, Loss : 0.2282
#
# Epoch : 47, Loss : 0.2277
#
# Epoch : 48, Loss : 0.2273
#
# Epoch : 49, Loss : 0.2273
#
# Epoch : 50, Loss : 0.2267
#
# Epoch : 51, Loss : 0.2264
#
# Epoch : 52, Loss : 0.2262
#
# Epoch : 53, Loss : 0.2259
#
# Epoch : 54, Loss : 0.2256
#
# Epoch : 55, Loss : 0.2253
#
# Epoch : 56, Loss : 0.2251
#
# Epoch : 57, Loss : 0.2249
#
# Epoch : 58, Loss : 0.2248
#
# Epoch : 59, Loss : 0.2248
#
# Epoch : 60, Loss : 0.2245
#
# Epoch : 61, Loss : 0.2243
#
# Epoch : 62, Loss : 0.2240
#
# Epoch : 63, Loss : 0.2235
#
# Epoch : 64, Loss : 0.2230
#
# Epoch : 65, Loss : 0.2222
#
# Epoch : 66, Loss : 0.2214
#
# Epoch : 67, Loss : 0.2215
#
# Epoch : 68, Loss : 0.2215
#
# Epoch : 69, Loss : 0.2224
#
# Epoch : 70, Loss : 0.2225
#
# Epoch : 71, Loss : 0.2220
#
# Epoch : 72, Loss : 0.2220
#
# Epoch : 73, Loss : 0.2228
#
# Epoch : 74, Loss : 0.2235
#
# Epoch : 75, Loss : 0.2238
#
# Epoch : 76, Loss : 0.2238
#
# Epoch : 77, Loss : 0.2211
#
# Epoch : 78, Loss : 0.2184
#
# Epoch : 79, Loss : 0.2165
#
# Epoch : 80, Loss : 0.2168
#
# Epoch : 81, Loss : 0.2189
#
# Epoch : 82, Loss : 0.2199
#
# Epoch : 83, Loss : 0.2196
#
# Epoch : 84, Loss : 0.2177
#
# Epoch : 85, Loss : 0.2167
#
# Epoch : 86, Loss : 0.2171
#
# Epoch : 87, Loss : 0.2177
#
# Epoch : 88, Loss : 0.2146
#
# Epoch : 89, Loss : 0.2108
#
# Epoch : 90, Loss : 0.2090
#
# Epoch : 91, Loss : 0.2082
#
# Epoch : 92, Loss : 0.2082
#
# Epoch : 93, Loss : 0.2078
#
# Epoch : 94, Loss : 0.2076
#
# Epoch : 95, Loss : 0.2070
#
# Epoch : 96, Loss : 0.2064
#
# Epoch : 97, Loss : 0.2053
#
# Epoch : 98, Loss : 0.2050
#
# Epoch : 99, Loss : 0.2042
#
# Epoch : 100, Loss : 0.2052
#
# Epoch : 101, Loss : 0.2071
#
# Epoch : 102, Loss : 0.2070
#
# Epoch : 103, Loss : 0.2053
#
# Epoch : 104, Loss : 0.2024
#
# Epoch : 105, Loss : 0.2003
#
# Epoch : 106, Loss : 0.1992
#
# Epoch : 107, Loss : 0.2000
#
# Epoch : 108, Loss : 0.2018
#
# Epoch : 109, Loss : 0.2016
#
# Epoch : 110, Loss : 0.2009
#
# Epoch : 111, Loss : 0.1996
#
# Epoch : 112, Loss : 0.1981
#
# Epoch : 113, Loss : 0.1967
#
# Epoch : 114, Loss : 0.1966
#
# Epoch : 115, Loss : 0.1985
#
# Epoch : 116, Loss : 0.2010
#
# Epoch : 117, Loss : 0.1999
#
# Epoch : 118, Loss : 0.1959
#
# Epoch : 119, Loss : 0.1912
#
# Epoch : 120, Loss : 0.1896
#
# Epoch : 121, Loss : 0.1895
#
# Epoch : 122, Loss : 0.1903
#
# Epoch : 123, Loss : 0.1917
#
# Epoch : 124, Loss : 0.1914
#
# Epoch : 125, Loss : 0.1902
#
# Epoch : 126, Loss : 0.1888
#
# Epoch : 127, Loss : 0.1887
#
# Epoch : 128, Loss : 0.1878
#
# Epoch : 129, Loss : 0.1861
#
# Epoch : 130, Loss : 0.1860
#
# Epoch : 131, Loss : 0.1868
#
# Epoch : 132, Loss : 0.1883
#
# Epoch : 133, Loss : 0.1895
#
# Epoch : 134, Loss : 0.1875
#
# Epoch : 135, Loss : 0.1839
#
# Epoch : 136, Loss : 0.1805
#
# Epoch : 137, Loss : 0.1832
#
# Epoch : 138, Loss : 0.1871
#
# Epoch : 139, Loss : 0.1881
#
# Epoch : 140, Loss : 0.1864
#
# Epoch : 141, Loss : 0.1834
#
# Epoch : 142, Loss : 0.1808
#
# Epoch : 143, Loss : 0.1787
#
# Epoch : 144, Loss : 0.1771
#
# Epoch : 145, Loss : 0.1758
#
# Epoch : 146, Loss : 0.1751
#
# Epoch : 147, Loss : 0.1751
#
# Epoch : 148, Loss : 0.1769
#
# Epoch : 149, Loss : 0.1780
#
# Epoch : 150, Loss : 0.1786
#
# Epoch : 151, Loss : 0.1788
#
# Epoch : 152, Loss : 0.1770
#
# Epoch : 153, Loss : 0.1753
#
# Epoch : 154, Loss : 0.1753
#
# Epoch : 155, Loss : 0.1803
#
# Epoch : 156, Loss : 0.1883
#
# Epoch : 157, Loss : 0.1886
#
# Epoch : 158, Loss : 0.1847
#
# Epoch : 159, Loss : 0.1792
#
# Epoch : 160, Loss : 0.1734
#
# Epoch : 161, Loss : 0.1706
#
# Epoch : 162, Loss : 0.1702
#
# Epoch : 163, Loss : 0.1693
#
# Epoch : 164, Loss : 0.1682
#
# Epoch : 165, Loss : 0.1668
#
# Epoch : 166, Loss : 0.1659
#
# Epoch : 167, Loss : 0.1652
#
# Epoch : 168, Loss : 0.1650
#
# Epoch : 169, Loss : 0.1651
#
# Epoch : 170, Loss : 0.1652
#
# Epoch : 171, Loss : 0.1658
#
# Epoch : 172, Loss : 0.1658
#
# Epoch : 173, Loss : 0.1661
#
# Epoch : 174, Loss : 0.1662
#
# Epoch : 175, Loss : 0.1666
#
# Epoch : 176, Loss : 0.1671
#
# Epoch : 177, Loss : 0.1682
#
# Epoch : 178, Loss : 0.1712
#
# Epoch : 179, Loss : 0.1722
#
# Epoch : 180, Loss : 0.1802
#
# Epoch : 181, Loss : 0.1847
#
# Epoch : 182, Loss : 0.1788
#
# Epoch : 183, Loss : 0.1664
#
# Epoch : 184, Loss : 0.1613
#
# Epoch : 185, Loss : 0.1615
#
# Epoch : 186, Loss : 0.1617
#
# Epoch : 187, Loss : 0.1616
#
# Epoch : 188, Loss : 0.1614
#
# Epoch : 189, Loss : 0.1607
#
# Epoch : 190, Loss : 0.1603
#
# Epoch : 191, Loss : 0.1601
#
# Epoch : 192, Loss : 0.1601
#
# Epoch : 193, Loss : 0.1611
#
# Epoch : 194, Loss : 0.1624
#
# Epoch : 195, Loss : 0.1637
#
# Epoch : 196, Loss : 0.1649
#
# Epoch : 197, Loss : 0.1659
#
# Epoch : 198, Loss : 0.1667
#
# Epoch : 199, Loss : 0.1663
#
# Epoch : 200, Loss : 0.1646
#
# Epoch : 201, Loss : 0.1643
#
# Epoch : 202, Loss : 0.1651
#
# Epoch : 203, Loss : 0.1652
#
# Epoch : 204, Loss : 0.1676
#
# Epoch : 205, Loss : 0.1698
#
# Epoch : 206, Loss : 0.1735
#
# Epoch : 207, Loss : 0.1730
#
# Epoch : 208, Loss : 0.1694
#
# Epoch : 209, Loss : 0.1702
#
# Epoch : 210, Loss : 0.1695
#
# Epoch : 211, Loss : 0.1668
#
# Epoch : 212, Loss : 0.1624
#
# Epoch : 213, Loss : 0.1595
#
# Epoch : 214, Loss : 0.1591
#
# Epoch : 215, Loss : 0.1594
#
# Epoch : 216, Loss : 0.1599
#
# Epoch : 217, Loss : 0.1612
#
# Epoch : 218, Loss : 0.1617
#
# Epoch : 219, Loss : 0.1629
#
# Epoch : 220, Loss : 0.1628
#
# Epoch : 221, Loss : 0.1635
#
# Epoch : 222, Loss : 0.1629
#
# Epoch : 223, Loss : 0.1639
#
# Epoch : 224, Loss : 0.1704
#
# Epoch : 225, Loss : 0.1759
#
# Epoch : 226, Loss : 0.1719
#
# Epoch : 227, Loss : 0.1624
#
# Epoch : 228, Loss : 0.1589
#
# Epoch : 229, Loss : 0.1590
#
# Epoch : 230, Loss : 0.1593
#
# Epoch : 231, Loss : 0.1591
#
# Epoch : 232, Loss : 0.1585
#
# Epoch : 233, Loss : 0.1579
#
# Epoch : 234, Loss : 0.1581
#
# Epoch : 235, Loss : 0.1604
#
# Epoch : 236, Loss : 0.1618
#
# Epoch : 237, Loss : 0.1617
#
# Epoch : 238, Loss : 0.1610
#
# Epoch : 239, Loss : 0.1596
#
# Epoch : 240, Loss : 0.1590
#
# Epoch : 241, Loss : 0.1588
#
# Epoch : 242, Loss : 0.1585
#
# Epoch : 243, Loss : 0.1584
#
# Epoch : 244, Loss : 0.1583
#
# Epoch : 245, Loss : 0.1590
#
# Epoch : 246, Loss : 0.1593
#
# Epoch : 247, Loss : 0.1606
#
# Epoch : 248, Loss : 0.1607
#
# Epoch : 249, Loss : 0.1629
#
# Epoch : 250, Loss : 0.1636
#
# Epoch : 251, Loss : 0.1680
#
# Epoch : 252, Loss : 0.1783
#
# Epoch : 253, Loss : 0.1728
#
# Epoch : 254, Loss : 0.1613
#
# Epoch : 255, Loss : 0.1569
#
# Epoch : 256, Loss : 0.1562
#
# Epoch : 257, Loss : 0.1561
#
# Epoch : 258, Loss : 0.1559
#
# Epoch : 259, Loss : 0.1560
#
# Epoch : 260, Loss : 0.1556
#
# Epoch : 261, Loss : 0.1560
#
# Epoch : 262, Loss : 0.1555
#
# Epoch : 263, Loss : 0.1557
#
# Epoch : 264, Loss : 0.1561
#
# Epoch : 265, Loss : 0.1565
#
# Epoch : 266, Loss : 0.1569
#
# Epoch : 267, Loss : 0.1567
#
# Epoch : 268, Loss : 0.1568
#
# Epoch : 269, Loss : 0.1565
#
# Epoch : 270, Loss : 0.1563
#
# Epoch : 271, Loss : 0.1562
#
# Epoch : 272, Loss : 0.1559
#
# Epoch : 273, Loss : 0.1557
#
# Epoch : 274, Loss : 0.1555
#
# Epoch : 275, Loss : 0.1550
#
# Epoch : 276, Loss : 0.1552
#
# Epoch : 277, Loss : 0.1551
#
# Epoch : 278, Loss : 0.1551
#
# Epoch : 279, Loss : 0.1549
#
# Epoch : 280, Loss : 0.1550
#
# Epoch : 281, Loss : 0.1555
#
# Epoch : 282, Loss : 0.1547
#
# Epoch : 283, Loss : 0.1548
#
# Epoch : 284, Loss : 0.1548
#
# Epoch : 285, Loss : 0.1554
#
# Epoch : 286, Loss : 0.1559
#
# Epoch : 287, Loss : 0.1560
#
# Epoch : 288, Loss : 0.1551
#
# Epoch : 289, Loss : 0.1555
#
# Epoch : 290, Loss : 0.1564
#
# Epoch : 291, Loss : 0.1573
#
# Epoch : 292, Loss : 0.1568
#
# Epoch : 293, Loss : 0.1584
#
# Epoch : 294, Loss : 0.1587
#
# Epoch : 295, Loss : 0.1610
#
# Epoch : 296, Loss : 0.1681
#
# Epoch : 297, Loss : 0.1819
#
# Epoch : 298, Loss : 0.1770
#
# Epoch : 299, Loss : 0.1618
#
# Epoch : 300, Loss : 0.1555
#
# Epoch : 301, Loss : 0.1548
#
# Epoch : 302, Loss : 0.1546
#
# Epoch : 303, Loss : 0.1542
#
# Epoch : 304, Loss : 0.1540
#
# Epoch : 305, Loss : 0.1539
#
# Epoch : 306, Loss : 0.1538
#
# Epoch : 307, Loss : 0.1537
#
# Epoch : 308, Loss : 0.1537
#
# Epoch : 309, Loss : 0.1539
#
# Epoch : 310, Loss : 0.1550
#
# Epoch : 311, Loss : 0.1570
#
# Epoch : 312, Loss : 0.1592
#
# Epoch : 313, Loss : 0.1607
#
# Epoch : 314, Loss : 0.1611
#
# Epoch : 315, Loss : 0.1606
#
# Epoch : 316, Loss : 0.1619
#
# Epoch : 317, Loss : 0.1640
#
# Epoch : 318, Loss : 0.1633
#
# Epoch : 319, Loss : 0.1605
#
# Epoch : 320, Loss : 0.1573
#
# Epoch : 321, Loss : 0.1559
#
# Epoch : 322, Loss : 0.1561
#
# Epoch : 323, Loss : 0.1565
#
# Epoch : 324, Loss : 0.1557
#
# Epoch : 325, Loss : 0.1548
#
# Epoch : 326, Loss : 0.1542
#
# Epoch : 327, Loss : 0.1540
#
# Epoch : 328, Loss : 0.1539
#
# Epoch : 329, Loss : 0.1544
#
# Epoch : 330, Loss : 0.1552
#
# Epoch : 331, Loss : 0.1564
#
# Epoch : 332, Loss : 0.1568
#
# Epoch : 333, Loss : 0.1564
#
# Epoch : 334, Loss : 0.1574
#
# Epoch : 335, Loss : 0.1577
#
# Epoch : 336, Loss : 0.1595
#
# Early stopping at epoch 337

# %%
# # 모델의 가중치를 출력
# for name, param in model.named_parameters():
#     if param.requires_grad:
#         print(name, param.data)

# %%
best_model = Seq2SeqModel().to(device)
best_model.load_state_dict(torch.load('0922_seq2seq_pytorch.pth'))
best_model.eval()

train_pred_list = []
train_target_list = []

for step, samples in enumerate(ELEC_train):
    inputs = samples[0].to(device)
    targets = samples[1].to(device)
    #print(inputs)
    pred = best_model(inputs)
    #print(pred)    
    train_target_list.extend(targets.detach().cpu().numpy())
    train_pred_list.extend(pred.detach().cpu().numpy())
#print(np.shape(train_pred_list))
#print(np.shape(train_target_list))
#    
r2 = r2_score(train_target_list, train_pred_list)
print('r2 score', r2)
# Out:
# r2 score 0.5702759756614102

# %%
plt.figure(figsize=(40,10))
plt.plot(train_target_list, color='red', label='real')
plt.plot(train_pred_list, color='blue', label='pred')
plt.legend()
plt.show()

# %%
best_model = Seq2SeqModel().to(device)
best_model.load_state_dict(torch.load('0922_seq2seq_pytorch.pth'))
best_model.eval()

test_pred_list = []
test_output_list = []
for step, samples in enumerate(ELEC_test):
    inputs = samples[0].to(device)
    targets = samples[1].to(device)
    
    pred = best_model(inputs)
    
    test_output_list.extend(targets.detach().cpu().numpy())
    test_pred_list.extend(pred.detach().cpu().numpy())
r2 = r2_score(test_output_list, test_pred_list)
print('r2 score', r2)
# Out:
# r2 score 0.5096605525098565

# %%
plt.figure(figsize=(40,10))
plt.plot(test_output_list, color='red', label='real')
plt.plot(test_pred_list, color='blue', label='pred')
plt.legend()
plt.show()

# %%
# class Seq2SeqModel(nn.Module):
#     def __init__(self):
#         super(Seq2SeqModel, self).__init__()
#         self.decoder2 = nn.LSTM(12, 32, batch_first=True, bias=False)
#         self.decoder3 = nn.LSTM(32, 64, batch_first=True, bias=False)
        
#         self.flatten = nn.Flatten()
#         self.dense = nn.Linear(24*64, 1)
#         self.tanh = nn.Tanh()
#         self.swish = Swish()
        
#     def forward(self, x):
#         x, _ = self.decoder2(x)
#         x = self.tanh(x)
#         x, _ = self.decoder3(x)
#         x = self.tanh(x)
#         x = x.reshape(-1, 24*64)
#         x = self.dense(x)
#         x = self.swish(x)
#         return x

# %%
# model2 = Seq2SeqModel().to(device)

# %%
# from torchinfo import summary

# summary(model2, (1024,24,12))
