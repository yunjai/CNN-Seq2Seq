# %%
from tqdm.notebook import tqdm
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.utils.data as data_util
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader
from sklearn.preprocessing import MinMaxScaler
from torchsummary import summary
from sklearn.metrics import r2_score
import math
import torch.nn as nn
import torch.nn.functional as F
from sklearn.model_selection import train_test_split

# %%
CUDA = torch.cuda.is_available()
print(CUDA)

device = torch.device('cuda:0' if CUDA else 'cpu')
# Out:
# True

# %%
dhw_merge = pd.read_csv('dhw_merge.csv')
elec_merge  = pd.read_csv('elec_merge.csv')

# %%
elec_merge = elec_merge.drop(['YEAR'], axis=1)
dhw_merge = dhw_merge.drop(['YEAR'], axis=1)

# %%
dhw_X = dhw_merge.drop(['DHW'], axis=1)
dhw_Y = dhw_merge[['DHW']]

scaler_dhw = MinMaxScaler()
scaler_dhw.fit(dhw_X)
scaled_dhw_X = scaler_dhw.transform(dhw_X)

new_dhw_X = pd.DataFrame(scaled_dhw_X, index=dhw_X.index, columns=dhw_X.columns)
new_dhw = pd.concat([new_dhw_X, dhw_Y], axis=1)

# %%
elec_X = elec_merge.drop(['ELEC'], axis=1)
elec_Y = elec_merge[['ELEC']]

scaler_elec = MinMaxScaler()
scaler_elec.fit(elec_X)
scaled_elec_X = scaler_elec.transform(elec_X)

new_elec_X = pd.DataFrame(scaled_elec_X, index=elec_X.index, columns=elec_X.columns)
new_elec = pd.concat([new_elec_X, elec_Y], axis=1)

# %%
input_dhw = new_dhw.iloc[:-1,]
target_dhw = new_dhw[['DHW']].iloc[1:]

trainX_dhw, testX_dhw, trainY_dhw, testY_dhw = train_test_split(input_dhw,target_dhw,test_size=0.3,shuffle=False,random_state=0)

# %%
input_elec = new_elec.iloc[:-1,]
target_elec = new_elec[['ELEC']].iloc[1:]

trainX_elec, testX_elec, trainY_elec, testY_elec = train_test_split(input_elec,target_elec,test_size=0.3,shuffle=False,random_state=0)

# %%
seqLength = 24
def buildDataSet(input, target, seqLength):
    xdata = []
    ydata = []
    for i in range(len(input) - seqLength):
        tx = input.iloc[i:i+seqLength]
        ty = target.iloc[i+seqLength-1]
        xdata.append(tx)
        ydata.append(ty)
    return np.array(xdata), np.array(ydata)

# %%
trainx_dhw, trainy_dhw = buildDataSet(trainX_dhw, trainY_dhw, 24)
testx_dhw, testy_dhw = buildDataSet(testX_dhw, testY_dhw, 24)
trainx_elec, trainy_elec = buildDataSet(trainX_elec, trainY_elec, 24)
testx_elec, testy_elec = buildDataSet(testX_elec, testY_elec, 24)

# %%
# 텐서로 변환
elec_trainx_tensor = torch.FloatTensor(trainx_elec)
elec_trainy_tensor = torch.FloatTensor(trainy_elec)

elec_testx_tensor = torch.FloatTensor(testx_elec)
elec_testy_tensor = torch.FloatTensor(testy_elec)

dhw_trainx_tensor = torch.FloatTensor(trainx_dhw)
dhw_trainy_tensor = torch.FloatTensor(trainy_dhw)

dhw_testx_tensor = torch.FloatTensor(testx_dhw)
dhw_testy_tensor = torch.FloatTensor(testy_dhw)

# %%
# 텐서 형태로 데이터 정의
elec_train = TensorDataset(elec_trainx_tensor, elec_trainy_tensor)
elec_test = TensorDataset(elec_testx_tensor, elec_testy_tensor)

dhw_train = TensorDataset(dhw_trainx_tensor, dhw_trainy_tensor)
dhw_test = TensorDataset(dhw_testx_tensor, dhw_testy_tensor)

# %%
batch_for_elec_train = 128
batch_for_elec_test = 128
batch_for_dhw_train = 128
batch_for_dhw_test = 128

ELEC_train = DataLoader(elec_train,
                        batch_size=batch_for_elec_train,
                        shuffle=False,  
                        drop_last=False)

ELEC_test = DataLoader(elec_test,
                        batch_size=batch_for_elec_test,
                        shuffle=False,  
                        drop_last=False)

DHW_train = DataLoader(dhw_train,
                        batch_size=batch_for_dhw_train,
                        shuffle=False,  
                        drop_last=True)

DHW_test = DataLoader(dhw_test,
                        batch_size=batch_for_dhw_test,
                        shuffle=False,  
                        drop_last=True)

# %%
# 데이터셋의 개수를 가정하여 변수에 저장
elec_train_size = len(elec_train)
elec_test_size = len(elec_test)
dhw_train_size = len(dhw_train)
dhw_test_size = len(dhw_test)

# 각 DataLoader에서 생성되는 배치의 개수 계산
elec_train_batches = math.ceil(elec_train_size / batch_for_elec_train)
elec_test_batches = math.ceil(elec_test_size / batch_for_elec_test)
dhw_train_batches = math.ceil(dhw_train_size / batch_for_dhw_train)
dhw_test_batches = math.ceil(dhw_test_size / batch_for_dhw_test)

# 결과 출력
print("elec_train batches:", elec_train_batches)
print("elec_test batches:", elec_test_batches)
print("dhw_train batches:", dhw_train_batches)
print("dhw_test batches:", dhw_test_batches)
# Out:
# elec_train batches: 24
# elec_test batches: 10
# dhw_train batches: 160
# dhw_test batches: 69

# %% [markdown]
# # 모델 구조 선언

# %%
class Swish(nn.Module):
    def __init__(self):
        super().__init__()
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        return x * self.sigmoid(x)

# %%
class Seq2SeqModel(nn.Module):
    def __init__(self):
        super(Seq2SeqModel, self).__init__()
        
        # for feature extracting
        self.conv1 = nn.Conv1d(12, 64, kernel_size=1)
        self.pool1 = nn.MaxPool1d(kernel_size=2, stride=1, padding=0)
        self.conv2 = nn.Conv1d(64, 32, kernel_size=1)
        self.pool2 = nn.MaxPool1d(kernel_size=2, stride=1, padding=0)
        self.conv3 = nn.Conv1d(32, 128, kernel_size=1)
        self.pool3 = nn.MaxPool1d(kernel_size=2, stride=1, padding=0)
        
        # Encoder
        self.encoder1 = nn.LSTM(128, 64, batch_first=True, bias=False)
        self.encoder2 = nn.LSTM(64, 32, batch_first=True, bias=False)
        self.encoder3 = nn.LSTM(32, 128, batch_first=True, bias=False)
        
        # Decoder
        self.decoder1 = nn.LSTM(128, 128, batch_first=True, bias=False)
        self.decoder2 = nn.LSTM(128, 32, batch_first=True, bias=False)
        self.decoder3 = nn.LSTM(32, 64, batch_first=True, bias=False)
        
        self.flatten = nn.Flatten()
        self.dense = nn.Linear(24 * 64, 1)
        self.tanh = nn.Tanh()
        self.swish = Swish()
        
    def forward(self, x):
        x = x.transpose(1,2)
        x = self.conv1(x)
        x = self.swish(x)
        x = x.transpose(2,1)
        x = self.pool1(x)
        x = F.pad(x, (0, 1), 'replicate', 0)
        
        x = x.transpose(1,2)
        x = self.conv2(x)
        x = self.swish(x)
        x = x.transpose(2,1)
        x = self.pool2(x)
        x = F.pad(x, (0, 1), 'replicate', 0)
        
        x = x.transpose(1,2)
        x = self.conv3(x)
        x = self.swish(x)
        x = x.transpose(2,1)
        x = self.pool3(x)
        x = F.pad(x, (0, 1), 'replicate', 0)
        
        #x = x.transpose(2,1)
        x, _ = self.encoder1(x)
        #x = self.tanh(x)
        x, _ = self.encoder2(x)
        #x = self.tanh(x)
        x, (h, c) = self.encoder3(x)
        #x = self.tanh(x)
        x, _ = self.decoder1(x, (h, c))
        #x = self.tanh(x)
        x, _ = self.decoder2(x)
        #x = self.tanh(x)
        x, _ = self.decoder3(x)
        #x = self.tanh(x)
        x = x.reshape(-1, 64 * 24)
        #x = self.swish(x)
        x = self.dense(x)

        return x

# %%
class seq_loss(nn.Module):
    def __init__(self):
        super(seq_loss, self).__init__()
        self.reg = nn.L1Loss()
        
    def forward(self, pred, real):
        x = pred
        loss = self.reg(x, real)
        
        return loss

# %%
# hoxy = Seq2SeqModel()
# inputx = torch.randn(512,24,12)
# hoxy2 = hoxy(inputx)
# print(hoxy2.shape)

# %%
model = Seq2SeqModel().to(device)
loss_fn = seq_loss().to(device)

# %%
from torchinfo import summary

summary(model, (1024,24,12))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Seq2SeqModel                             [1024, 1]                 --
# ├─Conv1d: 1-1                            [1024, 64, 24]            832
# ├─Swish: 1-2                             [1024, 64, 24]            --
# │    └─Sigmoid: 2-1                      [1024, 64, 24]            --
# ├─MaxPool1d: 1-3                         [1024, 24, 63]            --
# ├─Conv1d: 1-4                            [1024, 32, 24]            2,080
# ├─Swish: 1-5                             [1024, 32, 24]            --
# │    └─Sigmoid: 2-2                      [1024, 32, 24]            --
# ├─MaxPool1d: 1-6                         [1024, 24, 31]            --
# ├─Conv1d: 1-7                            [1024, 128, 24]           4,224
# ├─Swish: 1-8                             [1024, 128, 24]           --
# │    └─Sigmoid: 2-3                      [1024, 128, 24]           --
# ├─MaxPool1d: 1-9                         [1024, 24, 127]           --
# ├─LSTM: 1-10                             [1024, 24, 64]            49,152
# ├─LSTM: 1-11                             [1024, 24, 32]            12,288
# ├─LSTM: 1-12                             [1024, 24, 128]           81,920
# ├─LSTM: 1-13                             [1024, 24, 128]           131,072
# ├─LSTM: 1-14                             [1024, 24, 32]            20,480
# ├─LSTM: 1-15                             [1024, 24, 64]            24,576
# ├─Linear: 1-16                           [1024, 1]                 1,537
# ==========================================================================================
# Total params: 328,161
# Trainable params: 328,161
# Non-trainable params: 0
# Total mult-adds (G): 8.03
# ==========================================================================================
# Input size (MB): 1.18
# Forward/backward pass size (MB): 132.13
# Params size (MB): 1.31
# Estimated Total Size (MB): 134.62
# ==========================================================================================

# %%
from torch.optim.lr_scheduler import LinearLR

# 손실 함수와 옵티마이저 정의
epochs = 1000
model.train()

optimizer = torch.optim.Adamax(model.parameters(), lr=3e-4)#, weight_decay=0.01)
#scheduler = LinearLR(optimizer, start_factor=1.0, end_factor=0.0, total_iters = epochs * len(ELEC_train))

patience = 30  # Early stopping을 위한 기다리는 최대 epoch 수
best_loss = float('inf')
best_model_state_dict = None
counter = 0  # Early stopping 카운터

# 모델 학습
model.train() # 훈련 모드 설정

for epoch in range(1, epochs+1):
    running_loss = 0
    for step, samples in enumerate(ELEC_train):
        inputs = samples[0].to(device)
        targets = samples[1].to(device)
        pred = model(inputs)
        loss = loss_fn(pred, targets)
        
        running_loss += loss.item()
        # 그래디언트 계산 및 업데이트
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        #scheduler.step()
    
    # early stopping 및 모델 저장
    if running_loss / len(ELEC_train) < best_loss:
        best_loss = running_loss / len(ELEC_train)
        best_model_state_dict = model.state_dict()
        counter = 0  # Counter 초기화
    else:
        counter += 1
        if counter >= patience:
            print(f'Early stopping at epoch {epoch}')
            break
    print('Epoch : %d, Loss : %.4f' % (epoch, running_loss/ len(ELEC_train)))
    print('')

# 최상의 모델을 파일로 저장
if best_model_state_dict is not None:
    torch.save(best_model_state_dict, '0919_seq2seq_pytorch.pth')
# Out:
# Epoch : 1, Loss : 0.5980
#
# Epoch : 2, Loss : 0.5401
#
# Epoch : 3, Loss : 0.2783
#
# Epoch : 4, Loss : 0.4008
#
# Epoch : 5, Loss : 0.2813
#
# Epoch : 6, Loss : 0.3533
#
# Epoch : 7, Loss : 0.2950
#
# Epoch : 8, Loss : 0.3269
#
# Epoch : 9, Loss : 0.2979
#
# Epoch : 10, Loss : 0.3171
#
# Epoch : 11, Loss : 0.2961
#
# Epoch : 12, Loss : 0.3084
#
# Epoch : 13, Loss : 0.2933
#
# Epoch : 14, Loss : 0.2972
#
# Epoch : 15, Loss : 0.2879
#
# Epoch : 16, Loss : 0.2842
#
# Epoch : 17, Loss : 0.2789
#
# Epoch : 18, Loss : 0.2706
#
# Epoch : 19, Loss : 0.2606
#
# Epoch : 20, Loss : 0.2518
#
# Epoch : 21, Loss : 0.2446
#
# Epoch : 22, Loss : 0.2378
#
# Epoch : 23, Loss : 0.2342
#
# Epoch : 24, Loss : 0.2321
#
# Epoch : 25, Loss : 0.2307
#
# Epoch : 26, Loss : 0.2301
#
# Epoch : 27, Loss : 0.2298
#
# Epoch : 28, Loss : 0.2294
#
# Epoch : 29, Loss : 0.2291
#
# Epoch : 30, Loss : 0.2287
#
# Epoch : 31, Loss : 0.2284
#
# Epoch : 32, Loss : 0.2283
#
# Epoch : 33, Loss : 0.2280
#
# Epoch : 34, Loss : 0.2278
#
# Epoch : 35, Loss : 0.2275
#
# Epoch : 36, Loss : 0.2273
#
# Epoch : 37, Loss : 0.2270
#
# Epoch : 38, Loss : 0.2268
#
# Epoch : 39, Loss : 0.2266
#
# Epoch : 40, Loss : 0.2265
#
# Epoch : 41, Loss : 0.2262
#
# Epoch : 42, Loss : 0.2259
#
# Epoch : 43, Loss : 0.2257
#
# Epoch : 44, Loss : 0.2255
#
# Epoch : 45, Loss : 0.2252
#
# Epoch : 46, Loss : 0.2249
#
# Epoch : 47, Loss : 0.2251
#
# Epoch : 48, Loss : 0.2254
#
# Epoch : 49, Loss : 0.2253
#
# Epoch : 50, Loss : 0.2252
#
# Epoch : 51, Loss : 0.2252
#
# Epoch : 52, Loss : 0.2253
#
# Epoch : 53, Loss : 0.2251
#
# Epoch : 54, Loss : 0.2250
#
# Epoch : 55, Loss : 0.2247
#
# Epoch : 56, Loss : 0.2239
#
# Epoch : 57, Loss : 0.2232
#
# Epoch : 58, Loss : 0.2223
#
# Epoch : 59, Loss : 0.2226
#
# Epoch : 60, Loss : 0.2236
#
# Epoch : 61, Loss : 0.2253
#
# Epoch : 62, Loss : 0.2265
#
# Epoch : 63, Loss : 0.2266
#
# Epoch : 64, Loss : 0.2253
#
# Epoch : 65, Loss : 0.2250
#
# Epoch : 66, Loss : 0.2259
#
# Epoch : 67, Loss : 0.2260
#
# Epoch : 68, Loss : 0.2266
#
# Epoch : 69, Loss : 0.2259
#
# Epoch : 70, Loss : 0.2232
#
# Epoch : 71, Loss : 0.2210
#
# Epoch : 72, Loss : 0.2201
#
# Epoch : 73, Loss : 0.2216
#
# Epoch : 74, Loss : 0.2265
#
# Epoch : 75, Loss : 0.2306
#
# Epoch : 76, Loss : 0.2270
#
# Epoch : 77, Loss : 0.2217
#
# Epoch : 78, Loss : 0.2202
#
# Epoch : 79, Loss : 0.2198
#
# Epoch : 80, Loss : 0.2197
#
# Epoch : 81, Loss : 0.2201
#
# Epoch : 82, Loss : 0.2205
#
# Epoch : 83, Loss : 0.2202
#
# Epoch : 84, Loss : 0.2199
#
# Epoch : 85, Loss : 0.2198
#
# Epoch : 86, Loss : 0.2197
#
# Epoch : 87, Loss : 0.2196
#
# Epoch : 88, Loss : 0.2193
#
# Epoch : 89, Loss : 0.2192
#
# Epoch : 90, Loss : 0.2189
#
# Epoch : 91, Loss : 0.2188
#
# Epoch : 92, Loss : 0.2187
#
# Epoch : 93, Loss : 0.2187
#
# Epoch : 94, Loss : 0.2185
#
# Epoch : 95, Loss : 0.2185
#
# Epoch : 96, Loss : 0.2184
#
# Epoch : 97, Loss : 0.2183
#
# Epoch : 98, Loss : 0.2181
#
# Epoch : 99, Loss : 0.2181
#
# Epoch : 100, Loss : 0.2179
#
# Epoch : 101, Loss : 0.2178
#
# Epoch : 102, Loss : 0.2176
#
# Epoch : 103, Loss : 0.2173
#
# Epoch : 104, Loss : 0.2174
#
# Epoch : 105, Loss : 0.2173
#
# Epoch : 106, Loss : 0.2167
#
# Epoch : 107, Loss : 0.2175
#
# Epoch : 108, Loss : 0.2183
#
# Epoch : 109, Loss : 0.2202
#
# Epoch : 110, Loss : 0.2286
#
# Epoch : 111, Loss : 0.2266
#
# Epoch : 112, Loss : 0.2201
#
# Epoch : 113, Loss : 0.2156
#
# Epoch : 114, Loss : 0.2186
#
# Epoch : 115, Loss : 0.2205
#
# Epoch : 116, Loss : 0.2172
#
# Epoch : 117, Loss : 0.2144
#
# Epoch : 118, Loss : 0.2136
#
# Epoch : 119, Loss : 0.2133
#
# Epoch : 120, Loss : 0.2138
#
# Epoch : 121, Loss : 0.2148
#
# Epoch : 122, Loss : 0.2146
#
# Epoch : 123, Loss : 0.2136
#
# Epoch : 124, Loss : 0.2119
#
# Epoch : 125, Loss : 0.2108
#
# Epoch : 126, Loss : 0.2108
#
# Epoch : 127, Loss : 0.2124
#
# Epoch : 128, Loss : 0.2180
#
# Epoch : 129, Loss : 0.2166
#
# Epoch : 130, Loss : 0.2128
#
# Epoch : 131, Loss : 0.2099
#
# Epoch : 132, Loss : 0.2084
#
# Epoch : 133, Loss : 0.2089
#
# Epoch : 134, Loss : 0.2109
#
# Epoch : 135, Loss : 0.2108
#
# Epoch : 136, Loss : 0.2107
#
# Epoch : 137, Loss : 0.2064
#
# Epoch : 138, Loss : 0.2026
#
# Epoch : 139, Loss : 0.1997
#
# Epoch : 140, Loss : 0.1996
#
# Epoch : 141, Loss : 0.2006
#
# Epoch : 142, Loss : 0.2019
#
# Epoch : 143, Loss : 0.2068
#
# Epoch : 144, Loss : 0.2041
#
# Epoch : 145, Loss : 0.1954
#
# Epoch : 146, Loss : 0.1932
#
# Epoch : 147, Loss : 0.1927
#
# Epoch : 148, Loss : 0.1948
#
# Epoch : 149, Loss : 0.1986
#
# Epoch : 150, Loss : 0.1986
#
# Epoch : 151, Loss : 0.1915
#
# Epoch : 152, Loss : 0.1858
#
# Epoch : 153, Loss : 0.1839
#
# Epoch : 154, Loss : 0.1847
#
# Epoch : 155, Loss : 0.1861
#
# Epoch : 156, Loss : 0.1854
#
# Epoch : 157, Loss : 0.1839
#
# Epoch : 158, Loss : 0.1823
#
# Epoch : 159, Loss : 0.1813
#
# Epoch : 160, Loss : 0.1805
#
# Epoch : 161, Loss : 0.1799
#
# Epoch : 162, Loss : 0.1819
#
# Epoch : 163, Loss : 0.1860
#
# Epoch : 164, Loss : 0.1917
#
# Epoch : 165, Loss : 0.1885
#
# Epoch : 166, Loss : 0.1812
#
# Epoch : 167, Loss : 0.1767
#
# Epoch : 168, Loss : 0.1810
#
# Epoch : 169, Loss : 0.1869
#
# Epoch : 170, Loss : 0.1888
#
# Epoch : 171, Loss : 0.1867
#
# Epoch : 172, Loss : 0.1809
#
# Epoch : 173, Loss : 0.1780
#
# Epoch : 174, Loss : 0.1767
#
# Epoch : 175, Loss : 0.1753
#
# Epoch : 176, Loss : 0.1755
#
# Epoch : 177, Loss : 0.1778
#
# Epoch : 178, Loss : 0.1820
#
# Epoch : 179, Loss : 0.1850
#
# Epoch : 180, Loss : 0.1820
#
# Epoch : 181, Loss : 0.1758
#
# Epoch : 182, Loss : 0.1729
#
# Epoch : 183, Loss : 0.1775
#
# Epoch : 184, Loss : 0.1813
#
# Epoch : 185, Loss : 0.1781
#
# Epoch : 186, Loss : 0.1731
#
# Epoch : 187, Loss : 0.1709
#
# Epoch : 188, Loss : 0.1702
#
# Epoch : 189, Loss : 0.1692
#
# Epoch : 190, Loss : 0.1703
#
# Epoch : 191, Loss : 0.1724
#
# Epoch : 192, Loss : 0.1741
#
# Epoch : 193, Loss : 0.1742
#
# Epoch : 194, Loss : 0.1722
#
# Epoch : 195, Loss : 0.1680
#
# Epoch : 196, Loss : 0.1670
#
# Epoch : 197, Loss : 0.1687
#
# Epoch : 198, Loss : 0.1718
#
# Epoch : 199, Loss : 0.1744
#
# Epoch : 200, Loss : 0.1740
#
# Epoch : 201, Loss : 0.1718
#
# Epoch : 202, Loss : 0.1696
#
# Epoch : 203, Loss : 0.1692
#
# Epoch : 204, Loss : 0.1684
#
# Epoch : 205, Loss : 0.1689
#
# Epoch : 206, Loss : 0.1724
#
# Epoch : 207, Loss : 0.1761
#
# Epoch : 208, Loss : 0.1779
#
# Epoch : 209, Loss : 0.1727
#
# Epoch : 210, Loss : 0.1653
#
# Epoch : 211, Loss : 0.1638
#
# Epoch : 212, Loss : 0.1645
#
# Epoch : 213, Loss : 0.1632
#
# Epoch : 214, Loss : 0.1620
#
# Epoch : 215, Loss : 0.1613
#
# Epoch : 216, Loss : 0.1608
#
# Epoch : 217, Loss : 0.1611
#
# Epoch : 218, Loss : 0.1624
#
# Epoch : 219, Loss : 0.1628
#
# Epoch : 220, Loss : 0.1617
#
# Epoch : 221, Loss : 0.1600
#
# Epoch : 222, Loss : 0.1592
#
# Epoch : 223, Loss : 0.1593
#
# Epoch : 224, Loss : 0.1602
#
# Epoch : 225, Loss : 0.1619
#
# Epoch : 226, Loss : 0.1639
#
# Epoch : 227, Loss : 0.1654
#
# Epoch : 228, Loss : 0.1673
#
# Epoch : 229, Loss : 0.1659
#
# Epoch : 230, Loss : 0.1651
#
# Epoch : 231, Loss : 0.1648
#
# Epoch : 232, Loss : 0.1672
#
# Epoch : 233, Loss : 0.1724
#
# Epoch : 234, Loss : 0.1770
#
# Epoch : 235, Loss : 0.1716
#
# Epoch : 236, Loss : 0.1612
#
# Epoch : 237, Loss : 0.1578
#
# Epoch : 238, Loss : 0.1578
#
# Epoch : 239, Loss : 0.1582
#
# Epoch : 240, Loss : 0.1581
#
# Epoch : 241, Loss : 0.1580
#
# Epoch : 242, Loss : 0.1577
#
# Epoch : 243, Loss : 0.1579
#
# Epoch : 244, Loss : 0.1576
#
# Epoch : 245, Loss : 0.1585
#
# Epoch : 246, Loss : 0.1614
#
# Epoch : 247, Loss : 0.1649
#
# Epoch : 248, Loss : 0.1668
#
# Epoch : 249, Loss : 0.1643
#
# Epoch : 250, Loss : 0.1607
#
# Epoch : 251, Loss : 0.1611
#
# Epoch : 252, Loss : 0.1638
#
# Epoch : 253, Loss : 0.1640
#
# Epoch : 254, Loss : 0.1613
#
# Epoch : 255, Loss : 0.1595
#
# Epoch : 256, Loss : 0.1586
#
# Epoch : 257, Loss : 0.1600
#
# Epoch : 258, Loss : 0.1627
#
# Epoch : 259, Loss : 0.1661
#
# Epoch : 260, Loss : 0.1638
#
# Epoch : 261, Loss : 0.1595
#
# Epoch : 262, Loss : 0.1587
#
# Epoch : 263, Loss : 0.1602
#
# Epoch : 264, Loss : 0.1615
#
# Epoch : 265, Loss : 0.1603
#
# Epoch : 266, Loss : 0.1587
#
# Epoch : 267, Loss : 0.1575
#
# Epoch : 268, Loss : 0.1582
#
# Epoch : 269, Loss : 0.1611
#
# Epoch : 270, Loss : 0.1633
#
# Epoch : 271, Loss : 0.1634
#
# Epoch : 272, Loss : 0.1604
#
# Epoch : 273, Loss : 0.1584
#
# Epoch : 274, Loss : 0.1585
#
# Epoch : 275, Loss : 0.1603
#
# Epoch : 276, Loss : 0.1632
#
# Epoch : 277, Loss : 0.1653
#
# Epoch : 278, Loss : 0.1618
#
# Epoch : 279, Loss : 0.1599
#
# Epoch : 280, Loss : 0.1598
#
# Epoch : 281, Loss : 0.1604
#
# Epoch : 282, Loss : 0.1645
#
# Epoch : 283, Loss : 0.1691
#
# Epoch : 284, Loss : 0.1661
#
# Epoch : 285, Loss : 0.1591
#
# Epoch : 286, Loss : 0.1579
#
# Epoch : 287, Loss : 0.1596
#
# Epoch : 288, Loss : 0.1599
#
# Epoch : 289, Loss : 0.1584
#
# Epoch : 290, Loss : 0.1570
#
# Epoch : 291, Loss : 0.1566
#
# Epoch : 292, Loss : 0.1576
#
# Epoch : 293, Loss : 0.1591
#
# Epoch : 294, Loss : 0.1607
#
# Epoch : 295, Loss : 0.1598
#
# Epoch : 296, Loss : 0.1580
#
# Epoch : 297, Loss : 0.1572
#
# Epoch : 298, Loss : 0.1583
#
# Epoch : 299, Loss : 0.1607
#
# Epoch : 300, Loss : 0.1627
#
# Epoch : 301, Loss : 0.1611
#
# Epoch : 302, Loss : 0.1592
#
# Epoch : 303, Loss : 0.1591
#
# Epoch : 304, Loss : 0.1592
#
# Epoch : 305, Loss : 0.1638
#
# Epoch : 306, Loss : 0.1689
#
# Epoch : 307, Loss : 0.1652
#
# Epoch : 308, Loss : 0.1583
#
# Epoch : 309, Loss : 0.1570
#
# Epoch : 310, Loss : 0.1580
#
# Epoch : 311, Loss : 0.1580
#
# Epoch : 312, Loss : 0.1573
#
# Epoch : 313, Loss : 0.1559
#
# Epoch : 314, Loss : 0.1560
#
# Epoch : 315, Loss : 0.1569
#
# Epoch : 316, Loss : 0.1579
#
# Epoch : 317, Loss : 0.1584
#
# Epoch : 318, Loss : 0.1580
#
# Epoch : 319, Loss : 0.1573
#
# Epoch : 320, Loss : 0.1573
#
# Epoch : 321, Loss : 0.1584
#
# Epoch : 322, Loss : 0.1619
#
# Epoch : 323, Loss : 0.1637
#
# Epoch : 324, Loss : 0.1597
#
# Epoch : 325, Loss : 0.1580
#
# Epoch : 326, Loss : 0.1569
#
# Epoch : 327, Loss : 0.1573
#
# Epoch : 328, Loss : 0.1596
#
# Epoch : 329, Loss : 0.1627
#
# Epoch : 330, Loss : 0.1621
#
# Epoch : 331, Loss : 0.1592
#
# Epoch : 332, Loss : 0.1565
#
# Epoch : 333, Loss : 0.1578
#
# Epoch : 334, Loss : 0.1596
#
# Epoch : 335, Loss : 0.1574
#
# Epoch : 336, Loss : 0.1554
#
# Epoch : 337, Loss : 0.1552
#
# Epoch : 338, Loss : 0.1561
#
# Epoch : 339, Loss : 0.1568
#
# Epoch : 340, Loss : 0.1569
#
# Epoch : 341, Loss : 0.1559
#
# Epoch : 342, Loss : 0.1555
#
# Epoch : 343, Loss : 0.1554
#
# Epoch : 344, Loss : 0.1571
#
# Epoch : 345, Loss : 0.1613
#
# Epoch : 346, Loss : 0.1614
#
# Epoch : 347, Loss : 0.1585
#
# Epoch : 348, Loss : 0.1585
#
# Epoch : 349, Loss : 0.1582
#
# Epoch : 350, Loss : 0.1618
#
# Epoch : 351, Loss : 0.1660
#
# Epoch : 352, Loss : 0.1616
#
# Epoch : 353, Loss : 0.1566
#
# Epoch : 354, Loss : 0.1548
#
# Epoch : 355, Loss : 0.1547
#
# Epoch : 356, Loss : 0.1551
#
# Epoch : 357, Loss : 0.1547
#
# Epoch : 358, Loss : 0.1541
#
# Epoch : 359, Loss : 0.1538
#
# Epoch : 360, Loss : 0.1539
#
# Epoch : 361, Loss : 0.1539
#
# Epoch : 362, Loss : 0.1536
#
# Epoch : 363, Loss : 0.1533
#
# Epoch : 364, Loss : 0.1534
#
# Epoch : 365, Loss : 0.1535
#
# Epoch : 366, Loss : 0.1538
#
# Epoch : 367, Loss : 0.1536
#
# Epoch : 368, Loss : 0.1534
#
# Epoch : 369, Loss : 0.1539
#
# Epoch : 370, Loss : 0.1550
#
# Epoch : 371, Loss : 0.1587
#
# Epoch : 372, Loss : 0.1613
#
# Epoch : 373, Loss : 0.1588
#
# Epoch : 374, Loss : 0.1549
#
# Epoch : 375, Loss : 0.1557
#
# Epoch : 376, Loss : 0.1556
#
# Epoch : 377, Loss : 0.1550
#
# Epoch : 378, Loss : 0.1539
#
# Epoch : 379, Loss : 0.1535
#
# Epoch : 380, Loss : 0.1536
#
# Epoch : 381, Loss : 0.1541
#
# Epoch : 382, Loss : 0.1544
#
# Epoch : 383, Loss : 0.1539
#
# Epoch : 384, Loss : 0.1532
#
# Epoch : 385, Loss : 0.1536
#
# Epoch : 386, Loss : 0.1558
#
# Epoch : 387, Loss : 0.1564
#
# Epoch : 388, Loss : 0.1558
#
# Epoch : 389, Loss : 0.1551
#
# Epoch : 390, Loss : 0.1540
#
# Epoch : 391, Loss : 0.1551
#
# Epoch : 392, Loss : 0.1604
#
# Epoch : 393, Loss : 0.1636
#
# Epoch : 394, Loss : 0.1597
#
# Epoch : 395, Loss : 0.1531
#
# Epoch : 396, Loss : 0.1537
#
# Epoch : 397, Loss : 0.1534
#
# Epoch : 398, Loss : 0.1528
#
# Epoch : 399, Loss : 0.1524
#
# Epoch : 400, Loss : 0.1521
#
# Epoch : 401, Loss : 0.1522
#
# Epoch : 402, Loss : 0.1519
#
# Epoch : 403, Loss : 0.1518
#
# Epoch : 404, Loss : 0.1518
#
# Epoch : 405, Loss : 0.1520
#
# Epoch : 406, Loss : 0.1522
#
# Epoch : 407, Loss : 0.1520
#
# Epoch : 408, Loss : 0.1518
#
# Epoch : 409, Loss : 0.1527
#
# Epoch : 410, Loss : 0.1553
#
# Epoch : 411, Loss : 0.1593
#
# Epoch : 412, Loss : 0.1559
#
# Epoch : 413, Loss : 0.1540
#
# Epoch : 414, Loss : 0.1545
#
# Epoch : 415, Loss : 0.1558
#
# Epoch : 416, Loss : 0.1533
#
# Epoch : 417, Loss : 0.1524
#
# Epoch : 418, Loss : 0.1522
#
# Epoch : 419, Loss : 0.1538
#
# Epoch : 420, Loss : 0.1550
#
# Epoch : 421, Loss : 0.1543
#
# Epoch : 422, Loss : 0.1527
#
# Epoch : 423, Loss : 0.1527
#
# Epoch : 424, Loss : 0.1542
#
# Epoch : 425, Loss : 0.1557
#
# Epoch : 426, Loss : 0.1564
#
# Epoch : 427, Loss : 0.1546
#
# Epoch : 428, Loss : 0.1537
#
# Epoch : 429, Loss : 0.1545
#
# Epoch : 430, Loss : 0.1592
#
# Epoch : 431, Loss : 0.1627
#
# Epoch : 432, Loss : 0.1557
#
# Early stopping at epoch 433

# %%
# 모델의 가중치를 출력
for name, param in model.named_parameters():
    if param.requires_grad:
        print(name, param.data)
# Out:
# conv1.weight tensor([[[ 0.2752],
#          [ 0.1048],
#          [ 0.1850],
#          [ 0.0480],
#          [ 0.0302],
#          [-0.1712],
#          [ 0.0835],
#          [ 0.1503],
#          [-0.1223],
#          [-0.0358],
#          [-0.2309],
#          [ 0.0065]],
#
#         [[-0.2103],
#          [ 0.0858],
#          [ 0.2735],
#          [ 0.2543],
#          [-0.0808],
#          [ 0.1580],
#          [-0.0828],
#          [-0.1111],
#          [-0.2583],
#          [ 0.1997],
#          [-0.2961],
#          [-0.2705]],
#
#         [[-0.0605],
#          [ 0.2502],
#          [ 0.2872],
#          [-0.1571],
#          [-0.2456],
#          [ 0.2729],
#          [ 0.0734],
#          [ 0.1865],
#          [-0.2553],
#          [-0.1034],
#          [ 0.1505],
#          [-0.2543]],
#
#         [[ 0.2832],
#          [-0.1581],
#          [-0.1534],
#          [-0.0581],
#          [ 0.1003],
#          [-0.2080],
#          [-0.2734],
#          [ 0.1639],
#          [ 0.2806],
#          [-0.0858],
#          [ 0.1019],
#          [-0.0231]],
#
#         [[ 0.0805],
#          [-0.1646],
#          [-0.0844],
#          [ 0.2232],
#          [ 0.0633],
#          [ 0.2775],
#          [-0.2563],
#          [ 0.1124],
#          [ 0.2471],
#          [ 0.0198],
#          [ 0.2705],
#          [-0.1840]],
#
#         [[-0.0189],
#          [ 0.0712],
#          [ 0.0113],
#          [-0.2161],
#          [ 0.0330],
#          [-0.0970],
#          [ 0.0185],
#          [-0.2454],
#          [-0.2274],
#          [ 0.0318],
#          [-0.2735],
#          [ 0.0996]],
#
#         [[-0.1773],
#          [-0.1174],
#          [ 0.2258],
#          [ 0.2097],
#          [-0.1542],
#          [ 0.2015],
#          [ 0.2128],
#          [-0.0548],
#          [ 0.0388],
#          [ 0.2126],
#          [-0.0545],
#          [ 0.3130]],
#
#         [[ 0.0507],
#          [ 0.1251],
#          [-0.0690],
#          [-0.2778],
#          [ 0.2710],
#          [-0.1934],
#          [ 0.1809],
#          [-0.0611],
#          [-0.0872],
#          [ 0.0739],
#          [-0.2512],
#          [-0.0620]],
#
#         [[ 0.2546],
#          [-0.2046],
#          [-0.2249],
#          [ 0.0297],
#          [-0.3051],
#          [-0.0856],
#          [-0.0860],
#          [ 0.0215],
#          [ 0.0316],
#          [ 0.0031],
#          [ 0.1299],
#          [-0.1174]],
#
#         [[-0.1549],
#          [ 0.1487],
#          [-0.2024],
#          [ 0.2333],
#          [-0.2085],
#          [-0.2163],
#          [ 0.2040],
#          [-0.1541],
#          [-0.0763],
#          [-0.2094],
#          [ 0.0232],
#          [-0.1694]],
#
#         [[-0.3490],
#          [ 0.2852],
#          [-0.0027],
#          [ 0.1461],
#          [ 0.0960],
#          [-0.2525],
#          [-0.2612],
#          [-0.0206],
#          [-0.0963],
#          [ 0.2026],
#          [ 0.0720],
#          [-0.1699]],
#
#         [[ 0.1648],
#          [-0.2154],
#          [ 0.1946],
#          [-0.0831],
#          [-0.1215],
#          [-0.0670],
#          [ 0.2976],
#          [-0.0910],
#          [ 0.0021],
#          [ 0.0754],
#          [ 0.1204],
#          [-0.2003]],
#
#         [[ 0.0572],
#          [-0.1828],
#          [-0.1216],
#          [ 0.0127],
#          [-0.1094],
#          [-0.2720],
#          [-0.1874],
#          [ 0.0364],
#          [-0.3300],
#          [ 0.1680],
#          [ 0.2281],
#          [ 0.1565]],
#
#         [[-0.0069],
#          [-0.0868],
#          [ 0.0506],
#          [-0.0343],
#          [ 0.1970],
#          [-0.2288],
#          [ 0.2586],
#          [ 0.2069],
#          [-0.2553],
#          [ 0.1273],
#          [-0.1043],
#          [ 0.3221]],
#
#         [[-0.0403],
#          [ 0.2181],
#          [ 0.1037],
#          [-0.1555],
#          [-0.0680],
#          [ 0.0360],
#          [ 0.0155],
#          [-0.0083],
#          [ 0.0523],
#          [-0.2811],
#          [-0.1749],
#          [-0.2598]],
#
#         [[-0.0093],
#          [ 0.2130],
#          [-0.2544],
#          [ 0.3007],
#          [-0.0708],
#          [ 0.2954],
#          [-0.0789],
#          [-0.1074],
#          [-0.2306],
#          [-0.1895],
#          [ 0.2191],
#          [-0.1917]],
#
#         [[-0.1274],
#          [-0.1320],
#          [-0.0815],
#          [ 0.2372],
#          [-0.2893],
#          [ 0.2530],
#          [ 0.1140],
#          [-0.0840],
#          [ 0.2608],
#          [ 0.1344],
#          [-0.2702],
#          [-0.0429]],
#
#         [[ 0.2841],
#          [ 0.1376],
#          [-0.1867],
#          [ 0.1526],
#          [-0.1072],
#          [-0.2547],
#          [ 0.2951],
#          [ 0.0743],
#          [ 0.1609],
#          [-0.1281],
#          [-0.1131],
#          [-0.1832]],
#
#         [[-0.2172],
#          [-0.1349],
#          [-0.1164],
#          [ 0.2122],
#          [-0.0184],
#          [ 0.1739],
#          [ 0.0794],
#          [ 0.2155],
#          [ 0.0408],
#          [-0.2322],
#          [ 0.1936],
#          [-0.1843]],
#
#         [[-0.2947],
#          [-0.2524],
#          [ 0.1963],
#          [ 0.2375],
#          [-0.0527],
#          [-0.0013],
#          [ 0.2205],
#          [-0.0939],
#          [ 0.2951],
#          [-0.2399],
#          [ 0.0683],
#          [-0.0935]],
#
#         [[ 0.0006],
#          [-0.1259],
#          [ 0.2202],
#          [-0.1070],
#          [ 0.1753],
#          [ 0.2279],
#          [-0.2500],
#          [ 0.0596],
#          [ 0.2514],
#          [-0.0353],
#          [ 0.2334],
#          [-0.2270]],
#
#         [[ 0.1615],
#          [-0.0280],
#          [-0.0136],
#          [ 0.0234],
#          [-0.1232],
#          [ 0.0947],
#          [-0.1924],
#          [-0.3057],
#          [-0.2958],
#          [-0.0151],
#          [ 0.0958],
#          [-0.0749]],
#
#         [[-0.1625],
#          [ 0.1906],
#          [-0.1378],
#          [ 0.2639],
#          [ 0.0081],
#          [ 0.2588],
#          [-0.0237],
#          [-0.0353],
#          [ 0.1272],
#          [-0.2391],
#          [ 0.2515],
#          [-0.0308]],
#
#         [[-0.0226],
#          [ 0.0249],
#          [-0.0971],
#          [ 0.0769],
#          [-0.2064],
#          [ 0.2172],
#          [ 0.2572],
#          [ 0.0415],
#          [-0.0431],
#          [-0.2421],
#          [ 0.1203],
#          [ 0.3338]],
#
#         [[ 0.0377],
#          [-0.0943],
#          [-0.1587],
#          [-0.0055],
#          [ 0.0747],
#          [-0.2432],
#          [-0.2425],
#          [ 0.0224],
#          [ 0.2542],
#          [ 0.0764],
#          [-0.1264],
#          [-0.2272]],
#
#         [[-0.1523],
#          [ 0.0677],
#          [-0.2464],
#          [-0.1508],
#          [ 0.1031],
#          [-0.2636],
#          [ 0.1628],
#          [ 0.1065],
#          [ 0.2688],
#          [ 0.1088],
#          [ 0.2552],
#          [-0.1096]],
#
#         [[ 0.1886],
#          [ 0.1739],
#          [ 0.1084],
#          [ 0.1309],
#          [ 0.1778],
#          [-0.0810],
#          [ 0.0272],
#          [-0.0539],
#          [ 0.2175],
#          [-0.1219],
#          [ 0.1418],
#          [ 0.0715]],
#
#         [[ 0.0015],
#          [-0.2527],
#          [ 0.0217],
#          [-0.2044],
#          [ 0.0479],
#          [ 0.0730],
#          [-0.1209],
#          [-0.1197],
#          [-0.1947],
#          [-0.2485],
#          [ 0.1574],
#          [-0.1681]],
#
#         [[-0.1116],
#          [ 0.0413],
#          [ 0.0813],
#          [-0.1487],
#          [ 0.0203],
#          [-0.1438],
#          [-0.1429],
#          [ 0.1309],
#          [ 0.1059],
#          [-0.2714],
#          [ 0.1585],
#          [ 0.3070]],
#
#         [[-0.0124],
#          [ 0.0572],
#          [ 0.2583],
#          [ 0.1056],
#          [-0.1327],
#          [-0.1069],
#          [ 0.1470],
#          [-0.1957],
#          [-0.2450],
#          [ 0.2586],
#          [ 0.2054],
#          [-0.1805]],
#
#         [[ 0.3051],
#          [-0.2549],
#          [-0.1764],
#          [-0.1366],
#          [ 0.2478],
#          [ 0.1236],
#          [-0.1190],
#          [ 0.2033],
#          [-0.1746],
#          [-0.1066],
#          [-0.0602],
#          [ 0.0856]],
#
#         [[ 0.1419],
#          [-0.2957],
#          [-0.1852],
#          [ 0.1561],
#          [-0.0479],
#          [ 0.2198],
#          [ 0.1454],
#          [-0.1400],
#          [-0.1314],
#          [ 0.1003],
#          [ 0.1258],
#          [ 0.1794]],
#
#         [[-0.1130],
#          [ 0.0790],
#          [-0.1613],
#          [-0.1103],
#          [-0.1470],
#          [-0.0689],
#          [-0.2792],
#          [ 0.0564],
#          [-0.0292],
#          [ 0.0110],
#          [ 0.2192],
#          [-0.0958]],
#
#         [[ 0.0689],
#          [-0.0447],
#          [-0.2032],
#          [-0.2421],
#          [-0.1343],
#          [ 0.1665],
#          [ 0.2431],
#          [-0.1373],
#          [-0.1660],
#          [ 0.1107],
#          [-0.0877],
#          [ 0.1335]],
#
#         [[ 0.0218],
#          [-0.2956],
#          [-0.0120],
#          [-0.1777],
#          [-0.0440],
#          [ 0.0801],
#          [ 0.2805],
#          [-0.1571],
#          [-0.2855],
#          [-0.0793],
#          [ 0.2322],
#          [-0.1781]],
#
#         [[-0.2655],
#          [-0.1016],
#          [-0.0028],
#          [ 0.2059],
#          [ 0.0682],
#          [-0.0103],
#          [-0.1459],
#          [ 0.1243],
#          [ 0.1725],
#          [-0.1434],
#          [-0.1583],
#          [ 0.2378]],
#
#         [[ 0.1343],
#          [-0.2494],
#          [ 0.1027],
#          [-0.1181],
#          [-0.0602],
#          [-0.0437],
#          [-0.2532],
#          [ 0.1741],
#          [ 0.0250],
#          [ 0.2831],
#          [-0.0222],
#          [ 0.3092]],
#
#         [[-0.1242],
#          [-0.2453],
#          [-0.1885],
#          [-0.1459],
#          [-0.1859],
#          [ 0.1468],
#          [-0.1431],
#          [-0.0964],
#          [ 0.0641],
#          [-0.1410],
#          [-0.2839],
#          [ 0.0951]],
#
#         [[-0.2422],
#          [ 0.1545],
#          [-0.0377],
#          [ 0.0594],
#          [-0.2177],
#          [-0.1796],
#          [ 0.0751],
#          [ 0.2508],
#          [-0.2291],
#          [-0.0098],
#          [-0.1080],
#          [ 0.1212]],
#
#         [[ 0.1330],
#          [ 0.1456],
#          [ 0.2695],
#          [-0.0458],
#          [-0.1590],
#          [ 0.2380],
#          [ 0.2211],
#          [-0.1042],
#          [-0.0921],
#          [-0.1879],
#          [ 0.2561],
#          [ 0.2484]],
#
#         [[ 0.2720],
#          [ 0.0408],
#          [-0.1057],
#          [ 0.0788],
#          [ 0.0173],
#          [ 0.2676],
#          [-0.0540],
#          [-0.1619],
#          [-0.1922],
#          [-0.0074],
#          [-0.2174],
#          [-0.0352]],
#
#         [[-0.0775],
#          [-0.2846],
#          [-0.0486],
#          [ 0.0149],
#          [ 0.1589],
#          [-0.2022],
#          [ 0.2761],
#          [-0.1990],
#          [-0.1427],
#          [ 0.1444],
#          [ 0.1746],
#          [ 0.1502]],
#
#         [[ 0.1950],
#          [ 0.1263],
#          [-0.2516],
#          [ 0.1976],
#          [-0.0176],
#          [-0.0961],
#          [ 0.0695],
#          [ 0.0020],
#          [-0.2512],
#          [-0.0624],
#          [ 0.0790],
#          [ 0.3402]],
#
#         [[-0.2118],
#          [-0.0760],
#          [ 0.2226],
#          [-0.0984],
#          [ 0.3060],
#          [ 0.0100],
#          [-0.2550],
#          [ 0.3070],
#          [ 0.2229],
#          [-0.2378],
#          [-0.0316],
#          [ 0.3522]],
#
#         [[ 0.2230],
#          [-0.0516],
#          [ 0.0739],
#          [-0.1839],
#          [ 0.2032],
#          [ 0.1357],
#          [-0.2709],
#          [ 0.1873],
#          [-0.1814],
#          [-0.2073],
#          [-0.1863],
#          [ 0.1078]],
#
#         [[ 0.2127],
#          [-0.0275],
#          [ 0.1309],
#          [-0.1097],
#          [-0.0339],
#          [-0.0241],
#          [-0.2408],
#          [-0.0160],
#          [-0.0693],
#          [ 0.2557],
#          [-0.2668],
#          [-0.2546]],
#
#         [[-0.2720],
#          [-0.0411],
#          [-0.0074],
#          [-0.2238],
#          [ 0.1607],
#          [-0.2039],
#          [ 0.1527],
#          [ 0.1698],
#          [-0.3282],
#          [ 0.1296],
#          [ 0.2228],
#          [ 0.0998]],
#
#         [[ 0.2776],
#          [-0.1221],
#          [ 0.0461],
#          [ 0.1862],
#          [ 0.0481],
#          [ 0.2563],
#          [-0.0427],
#          [-0.0674],
#          [-0.0172],
#          [ 0.1530],
#          [ 0.2075],
#          [-0.3047]],
#
#         [[-0.0133],
#          [-0.0346],
#          [-0.0388],
#          [ 0.0118],
#          [ 0.2826],
#          [ 0.0004],
#          [-0.1071],
#          [-0.1342],
#          [-0.2886],
#          [ 0.2010],
#          [-0.1675],
#          [-0.2167]],
#
#         [[-0.0364],
#          [-0.2335],
#          [ 0.2223],
#          [-0.0089],
#          [ 0.2315],
#          [ 0.0440],
#          [ 0.0116],
#          [ 0.1639],
#          [-0.0684],
#          [-0.0402],
#          [ 0.0104],
#          [ 0.2863]],
#
#         [[ 0.1589],
#          [-0.0929],
#          [-0.0706],
#          [-0.1993],
#          [ 0.1980],
#          [ 0.1817],
#          [-0.3122],
#          [-0.0260],
#          [-0.2627],
#          [-0.1737],
#          [-0.1908],
#          [ 0.2456]],
#
#         [[-0.0799],
#          [ 0.0900],
#          [ 0.2908],
#          [-0.1532],
#          [ 0.1960],
#          [-0.0014],
#          [ 0.1754],
#          [-0.0015],
#          [-0.1596],
#          [-0.0342],
#          [-0.0125],
#          [-0.1283]],
#
#         [[ 0.1283],
#          [ 0.2360],
#          [ 0.2220],
#          [ 0.0105],
#          [ 0.2810],
#          [ 0.0199],
#          [ 0.2561],
#          [-0.1128],
#          [-0.1552],
#          [-0.0825],
#          [-0.1396],
#          [ 0.2392]],
#
#         [[-0.1586],
#          [-0.1370],
#          [ 0.0433],
#          [-0.0164],
#          [ 0.1127],
#          [ 0.1570],
#          [ 0.2715],
#          [-0.2805],
#          [-0.0499],
#          [-0.2784],
#          [-0.2608],
#          [ 0.0372]],
#
#         [[ 0.1430],
#          [ 0.1682],
#          [ 0.0613],
#          [ 0.2670],
#          [-0.0924],
#          [-0.0489],
#          [ 0.1772],
#          [-0.0800],
#          [ 0.1784],
#          [-0.0405],
#          [ 0.0608],
#          [-0.2232]],
#
#         [[ 0.0116],
#          [-0.1644],
#          [-0.1132],
#          [-0.1348],
#          [ 0.0662],
#          [-0.2421],
#          [ 0.0237],
#          [-0.2308],
#          [-0.1862],
#          [-0.1969],
#          [-0.2368],
#          [ 0.2543]],
#
#         [[ 0.0843],
#          [ 0.1502],
#          [-0.1073],
#          [-0.0284],
#          [-0.2773],
#          [ 0.0378],
#          [ 0.2447],
#          [ 0.1141],
#          [ 0.2212],
#          [ 0.1187],
#          [ 0.0241],
#          [ 0.2050]],
#
#         [[ 0.0007],
#          [-0.0663],
#          [-0.1481],
#          [ 0.2935],
#          [-0.2670],
#          [ 0.0563],
#          [ 0.1159],
#          [ 0.0121],
#          [-0.1415],
#          [ 0.2365],
#          [-0.0946],
#          [ 0.0019]],
#
#         [[-0.1867],
#          [-0.1015],
#          [-0.2245],
#          [ 0.2802],
#          [ 0.2489],
#          [-0.1995],
#          [ 0.2991],
#          [ 0.0581],
#          [ 0.2031],
#          [ 0.2004],
#          [ 0.1961],
#          [-0.2778]],
#
#         [[ 0.2693],
#          [ 0.2369],
#          [ 0.2075],
#          [ 0.2058],
#          [ 0.1851],
#          [-0.0072],
#          [-0.2706],
#          [-0.1829],
#          [-0.2575],
#          [ 0.2103],
#          [ 0.0895],
#          [-0.0492]],
#
#         [[-0.0654],
#          [-0.2277],
#          [-0.1254],
#          [-0.1766],
#          [ 0.0857],
#          [ 0.1079],
#          [ 0.0420],
#          [-0.2230],
#          [-0.0233],
#          [-0.2514],
#          [ 0.2060],
#          [ 0.2422]],
#
#         [[-0.1901],
#          [ 0.0009],
#          [ 0.1132],
#          [-0.2113],
#          [ 0.0425],
#          [-0.2504],
#          [ 0.1662],
#          [ 0.2526],
#          [ 0.2299],
#          [-0.0579],
#          [ 0.0069],
#          [-0.2455]],
#
#         [[ 0.0585],
#          [-0.1569],
#          [ 0.0970],
#          [ 0.0408],
#          [ 0.1532],
#          [ 0.2647],
#          [ 0.2910],
#          [ 0.0423],
#          [ 0.2760],
#          [ 0.1700],
#          [-0.2039],
#          [ 0.0821]],
#
#         [[ 0.2799],
#          [-0.2763],
#          [ 0.1994],
#          [ 0.0975],
#          [-0.2856],
#          [ 0.2679],
#          [-0.1184],
#          [ 0.0705],
#          [-0.0547],
#          [-0.2047],
#          [-0.0494],
#          [-0.1246]]], device='cuda:0')
# conv1.bias tensor([ 0.0309, -0.2206,  0.0179, -0.1997,  0.2094,  0.1091, -0.2425,  0.1388,
#         -0.1339,  0.1525, -0.0772, -0.1670, -0.0859,  0.1203, -0.2217, -0.1473,
#         -0.3058,  0.0530,  0.0889, -0.2482, -0.0770, -0.0651, -0.1833,  0.0501,
#         -0.1205,  0.1329,  0.0798, -0.1084,  0.1283,  0.2645, -0.1002,  0.0101,
#          0.0695,  0.1911,  0.1340,  0.1734, -0.0506,  0.2210, -0.0418, -0.0534,
#          0.1736, -0.1011, -0.0469, -0.0768, -0.2430,  0.1288, -0.1872,  0.1091,
#          0.1964,  0.1799, -0.0483, -0.0149,  0.1053,  0.2450,  0.2306,  0.1571,
#         -0.2743,  0.0496,  0.1745, -0.3102, -0.1823,  0.0627,  0.2035, -0.2747],
#        device='cuda:0')
# conv2.weight tensor([[[ 0.0371],
#          [ 0.0324],
#          [ 0.0720],
#          ...,
#          [-0.0117],
#          [-0.0777],
#          [-0.0063]],
#
#         [[-0.0649],
#          [-0.0476],
#          [ 0.1815],
#          ...,
#          [ 0.0042],
#          [-0.0258],
#          [-0.0113]],
#
#         [[-0.0424],
#          [-0.0403],
#          [ 0.0364],
#          ...,
#          [-0.1132],
#          [-0.0920],
#          [-0.0521]],
#
#         ...,
#
#         [[-0.0563],
#          [-0.0005],
#          [ 0.1910],
#          ...,
#          [ 0.1185],
#          [ 0.0579],
#          [ 0.0675]],
#
#         [[-0.0404],
#          [-0.1182],
#          [-0.1221],
#          ...,
#          [-0.0570],
#          [-0.0826],
#          [-0.0994]],
#
#         [[-0.0705],
#          [ 0.0858],
#          [ 0.1061],
#          ...,
#          [ 0.0767],
#          [ 0.0595],
#          [-0.0832]]], device='cuda:0')
# conv2.bias tensor([ 0.0243, -0.0804, -0.0231, -0.1055,  0.0248,  0.0281, -0.0261,  0.0816,
#         -0.1236,  0.0705, -0.0433, -0.1291,  0.1133, -0.0962,  0.1165,  0.0086,
#         -0.0373,  0.1026, -0.0816,  0.0972,  0.0649,  0.0930,  0.0208, -0.0005,
#          0.1140, -0.1203, -0.0760,  0.0629, -0.1150, -0.0700, -0.1079,  0.0174],
#        device='cuda:0')
# conv3.weight tensor([[[-0.0847],
#          [ 0.1306],
#          [-0.1377],
#          ...,
#          [-0.0351],
#          [ 0.1591],
#          [-0.0456]],
#
#         [[ 0.0782],
#          [-0.0997],
#          [ 0.1070],
#          ...,
#          [-0.1846],
#          [ 0.0083],
#          [-0.0942]],
#
#         [[-0.0469],
#          [ 0.0601],
#          [ 0.1592],
#          ...,
#          [-0.1211],
#          [-0.0246],
#          [-0.1047]],
#
#         ...,
#
#         [[ 0.1244],
#          [-0.1935],
#          [ 0.0725],
#          ...,
#          [-0.2119],
#          [ 0.0505],
#          [ 0.0069]],
#
#         [[-0.1823],
#          [ 0.1442],
#          [-0.0719],
#          ...,
#          [ 0.0474],
#          [-0.0600],
#          [-0.0814]],
#
#         [[ 0.1582],
#          [-0.1153],
#          [-0.1785],
#          ...,
#          [-0.0384],
#          [ 0.1072],
#          [ 0.1730]]], device='cuda:0')
# conv3.bias tensor([-0.0811, -0.0122,  0.1338,  0.1012, -0.1064, -0.0603,  0.1293,  0.0846,
#         -0.1195, -0.0456,  0.1081,  0.1571,  0.0291, -0.1019,  0.1615,  0.0038,
#         -0.0402, -0.1563, -0.0437,  0.0864, -0.0011, -0.0108,  0.0208,  0.1631,
#          0.0256, -0.0652, -0.0499,  0.0652, -0.0013,  0.0854, -0.1207,  0.0406,
#          0.1132, -0.0071,  0.0189, -0.1632, -0.0095, -0.0155, -0.1409,  0.0216,
#         -0.0588,  0.1261, -0.0049,  0.1111, -0.1024,  0.0891,  0.1063, -0.0191,
#         -0.1972, -0.1254, -0.0116, -0.1437, -0.1485, -0.0076, -0.0908, -0.0571,
#          0.0768, -0.0296,  0.1711, -0.1452, -0.1443,  0.0835,  0.0772,  0.1009,
#         -0.1215, -0.0454,  0.0514, -0.1700, -0.0281,  0.1163,  0.0596,  0.0972,
#          0.0016,  0.1302,  0.1276,  0.0499, -0.0705,  0.0048,  0.0432,  0.1579,
#          0.1343,  0.0430, -0.2040, -0.0131, -0.0233, -0.0535, -0.1566, -0.0405,
#         -0.1289,  0.0306,  0.1811,  0.0427, -0.1480,  0.1738, -0.0175,  0.0759,
#          0.1637, -0.0394,  0.1070, -0.0940, -0.0630,  0.1200, -0.1166,  0.1425,
#         -0.0509,  0.1122,  0.1560, -0.1694, -0.0171, -0.0460, -0.0854,  0.1317,
#         -0.0984, -0.1642,  0.0670, -0.0243,  0.0799, -0.1178,  0.0595, -0.0183,
#         -0.1716,  0.0913, -0.1237, -0.0201, -0.0587,  0.1087, -0.0501, -0.1007],
#        device='cuda:0')
# encoder1.weight_ih_l0 tensor([[ 0.1040,  0.1253,  0.1202,  ..., -0.0517,  0.0171, -0.1152],
#         [ 0.0998, -0.0503,  0.1327,  ..., -0.0012, -0.0570, -0.0016],
#         [ 0.0108, -0.0139,  0.1443,  ..., -0.0740, -0.1221,  0.0124],
#         ...,
#         [-0.0429,  0.1071, -0.0883,  ..., -0.0373, -0.1479, -0.0562],
#         [-0.1119,  0.1095,  0.0476,  ...,  0.0800, -0.0028,  0.0674],
#         [ 0.1388, -0.0788,  0.0410,  ..., -0.0129,  0.0428, -0.0405]],
#        device='cuda:0')
# encoder1.weight_hh_l0 tensor([[-0.0900,  0.0359,  0.0930,  ...,  0.0366,  0.1373,  0.0205],
#         [-0.0673,  0.0952, -0.1157,  ...,  0.0414,  0.1111, -0.0157],
#         [-0.0438,  0.0065, -0.0147,  ...,  0.0721,  0.1009, -0.0993],
#         ...,
#         [ 0.0102, -0.0346,  0.0065,  ...,  0.0570,  0.0051, -0.0705],
#         [-0.0237, -0.0912, -0.0326,  ..., -0.0624, -0.0189,  0.0690],
#         [-0.0030, -0.0868,  0.1183,  ..., -0.0162, -0.0273,  0.0093]],
#        device='cuda:0')
# encoder2.weight_ih_l0 tensor([[-0.0708,  0.1688, -0.1096,  ...,  0.1323,  0.1071, -0.1276],
#         [ 0.0202,  0.0010,  0.0110,  ...,  0.1389, -0.1485, -0.0554],
#         [ 0.0999, -0.0699,  0.0845,  ..., -0.0325,  0.1719,  0.1811],
#         ...,
#         [-0.0898,  0.0391, -0.0039,  ..., -0.1220,  0.1003,  0.1323],
#         [-0.1246, -0.0872, -0.0319,  ..., -0.0975, -0.0760,  0.0189],
#         [ 0.1116, -0.1098, -0.0501,  ...,  0.1174, -0.1135, -0.1390]],
#        device='cuda:0')
# encoder2.weight_hh_l0 tensor([[ 0.1736,  0.0672, -0.1296,  ...,  0.1362,  0.1576, -0.1322],
#         [ 0.0057, -0.1287, -0.1530,  ..., -0.0009,  0.0350, -0.1407],
#         [-0.0059,  0.1170,  0.0962,  ..., -0.1133, -0.0538,  0.0492],
#         ...,
#         [-0.1317,  0.1136, -0.0059,  ..., -0.0314, -0.0333, -0.1456],
#         [ 0.0078, -0.0389,  0.1145,  ...,  0.0357,  0.1711,  0.1594],
#         [-0.1629, -0.0383, -0.1095,  ..., -0.0534,  0.1028, -0.1312]],
#        device='cuda:0')
# encoder3.weight_ih_l0 tensor([[ 0.0458,  0.0577, -0.0997,  ..., -0.0665,  0.0892,  0.0703],
#         [ 0.0811, -0.0328, -0.0184,  ..., -0.0704, -0.0627, -0.0314],
#         [-0.0362,  0.0885, -0.0420,  ...,  0.0878, -0.0059,  0.0900],
#         ...,
#         [ 0.0003, -0.0868, -0.0193,  ...,  0.0300, -0.0154, -0.0480],
#         [ 0.0056,  0.0332,  0.0083,  ...,  0.0274,  0.0560, -0.0381],
#         [ 0.0943, -0.0377, -0.0766,  ..., -0.1129,  0.0118,  0.0697]],
#        device='cuda:0')
# encoder3.weight_hh_l0 tensor([[ 0.0550, -0.0156, -0.0029,  ..., -0.0883, -0.0191, -0.0698],
#         [ 0.0403,  0.0961, -0.0066,  ..., -0.0527,  0.0216, -0.0406],
#         [-0.0120, -0.0804, -0.0737,  ...,  0.0571,  0.0576, -0.0746],
#         ...,
#         [ 0.0193, -0.0221, -0.0457,  ..., -0.0837,  0.0808, -0.0491],
#         [-0.0817, -0.0056,  0.0521,  ..., -0.0176,  0.0534,  0.0883],
#         [-0.0183, -0.0137,  0.0206,  ..., -0.0617,  0.0970, -0.0389]],
#        device='cuda:0')
# decoder1.weight_ih_l0 tensor([[-0.0106, -0.0128,  0.0229,  ..., -0.0799,  0.0755, -0.0549],
#         [ 0.0251, -0.0836,  0.0295,  ..., -0.0039, -0.0445, -0.0270],
#         [-0.0794, -0.0154,  0.0167,  ...,  0.0809,  0.0239, -0.0089],
#         ...,
#         [ 0.0594, -0.0532, -0.0884,  ...,  0.0544,  0.0710,  0.0126],
#         [-0.0237,  0.0608, -0.0362,  ..., -0.0276, -0.0709, -0.0070],
#         [-0.0367, -0.0875, -0.0589,  ...,  0.0137,  0.0332,  0.0887]],
#        device='cuda:0')
# decoder1.weight_hh_l0 tensor([[-1.0942e-02,  2.2037e-02,  3.8784e-02,  ...,  1.0944e-02,
#          -9.7202e-03,  2.9096e-02],
#         [ 1.8507e-02, -2.2190e-02, -4.3920e-02,  ..., -2.2375e-02,
#          -4.0401e-02,  7.5402e-03],
#         [-8.8893e-03,  1.6360e-02, -3.8787e-02,  ...,  6.2129e-03,
#           4.2312e-02,  6.1300e-03],
#         ...,
#         [ 3.8637e-02,  2.6596e-02, -7.1885e-02,  ...,  2.2885e-02,
#           2.9263e-02, -4.7516e-02],
#         [-1.0525e-02,  3.6579e-05,  5.4546e-02,  ...,  6.5927e-02,
#          -2.6552e-02, -1.7926e-02],
#         [-3.6561e-02,  7.1366e-03,  4.0801e-02,  ..., -5.2262e-02,
#          -9.1022e-02, -7.9468e-02]], device='cuda:0')
# decoder2.weight_ih_l0 tensor([[ 0.0475,  0.1256,  0.0502,  ...,  0.1216,  0.1079,  0.1770],
#         [ 0.1198,  0.0875, -0.0550,  ..., -0.0049, -0.0343, -0.0526],
#         [ 0.0381,  0.0006, -0.0050,  ...,  0.1143, -0.0457, -0.1519],
#         ...,
#         [ 0.0696,  0.0378,  0.0058,  ...,  0.0289, -0.1486,  0.0577],
#         [ 0.0311, -0.1501,  0.0643,  ..., -0.0127, -0.0805, -0.1012],
#         [ 0.0224,  0.1575, -0.1555,  ...,  0.0003,  0.1668, -0.0553]],
#        device='cuda:0')
# decoder2.weight_hh_l0 tensor([[-0.1051, -0.1334, -0.0320,  ...,  0.0664, -0.1016,  0.1102],
#         [-0.0844, -0.1584,  0.0759,  ...,  0.1628,  0.0112,  0.0029],
#         [-0.0333, -0.1210,  0.1128,  ...,  0.0754, -0.0354,  0.1334],
#         ...,
#         [ 0.1222,  0.1046,  0.1073,  ..., -0.0878,  0.0450, -0.1412],
#         [-0.0530, -0.0853, -0.1564,  ..., -0.0702, -0.1631,  0.1384],
#         [ 0.1622,  0.0694,  0.1642,  ..., -0.1070,  0.0402,  0.0543]],
#        device='cuda:0')
# decoder3.weight_ih_l0 tensor([[-0.0995, -0.0975, -0.1046,  ...,  0.0395, -0.0146, -0.0067],
#         [ 0.1061,  0.0387, -0.1043,  ...,  0.0640,  0.1108,  0.1061],
#         [ 0.1247, -0.0391,  0.0493,  ..., -0.0784, -0.0151,  0.0939],
#         ...,
#         [-0.0820, -0.0572,  0.0019,  ...,  0.0785,  0.0732, -0.0752],
#         [-0.0745,  0.0269,  0.1281,  ..., -0.0169,  0.0206, -0.0778],
#         [ 0.0955, -0.0330,  0.0739,  ...,  0.0451, -0.0869,  0.1387]],
#        device='cuda:0')
# decoder3.weight_hh_l0 tensor([[ 0.1099,  0.0004,  0.0576,  ..., -0.0587, -0.0794, -0.0889],
#         [-0.0724,  0.0541,  0.0378,  ...,  0.0621,  0.0658,  0.0057],
#         [ 0.0574,  0.0913,  0.0100,  ..., -0.0321, -0.0379, -0.1232],
#         ...,
#         [ 0.1022, -0.1222,  0.0739,  ..., -0.0080, -0.0757, -0.1016],
#         [-0.0401,  0.0773,  0.0433,  ..., -0.0773, -0.1034,  0.0849],
#         [-0.0490,  0.0568,  0.1095,  ...,  0.1238,  0.0577, -0.0847]],
#        device='cuda:0')
# dense.weight tensor([[ 0.0697,  0.0784, -0.0490,  ..., -0.0263,  0.0312, -0.0031]],
#        device='cuda:0')
# dense.bias tensor([0.0657], device='cuda:0')

# %%
best_model = Seq2SeqModel().to(device)
best_model.load_state_dict(torch.load('0919_seq2seq_pytorch.pth'))
best_model.eval()

train_pred_list = []
train_target_list = []

for step, samples in enumerate(ELEC_train):
    inputs = samples[0].to(device)
    targets = samples[1].to(device)
    #print(inputs)
    pred = best_model(inputs)
    #print(pred)    
    train_target_list.extend(targets.detach().cpu().numpy())
    train_pred_list.extend(pred.detach().cpu().numpy())
print(np.shape(train_pred_list))
print(np.shape(train_target_list))
#    
r2 = r2_score(train_target_list, train_pred_list)
print('r2 score', r2)
# Out:
# (2967, 1)
# (2967, 1)
# r2 score 0.5407015339272834

# %%
plt.figure(figsize=(40,10))
plt.plot(train_target_list, color='red', label='real')
plt.plot(train_pred_list, color='blue', label='pred')
plt.legend()
plt.show()

# %%
best_model = Seq2SeqModel().to(device)
best_model.load_state_dict(torch.load('0919_seq2seq_pytorch.pth'))
best_model.eval()

test_pred_list = []
test_output_list = []
for step, samples in enumerate(ELEC_test):
    inputs = samples[0].to(device)
    targets = samples[1].to(device)
    
    pred = best_model(inputs)
    
    test_output_list.extend(targets.detach().cpu().numpy())
    test_pred_list.extend(pred.detach().cpu().numpy())
r2 = r2_score(test_output_list, test_pred_list)
print('r2 score', r2)
# Out:
# r2 score 0.39292759864028604

# %%
plt.figure(figsize=(40,10))
plt.plot(test_output_list, color='red', label='real')
plt.plot(test_pred_list, color='blue', label='pred')
plt.legend()
plt.show()

# %%
# class Seq2SeqModel(nn.Module):
#     def __init__(self):
#         super(Seq2SeqModel, self).__init__()
#         self.decoder2 = nn.LSTM(12, 32, batch_first=True, bias=False)
#         self.decoder3 = nn.LSTM(32, 64, batch_first=True, bias=False)
        
#         self.flatten = nn.Flatten()
#         self.dense = nn.Linear(24*64, 1)
#         self.tanh = nn.Tanh()
#         self.swish = Swish()
        
#     def forward(self, x):
#         x, _ = self.decoder2(x)
#         x = self.tanh(x)
#         x, _ = self.decoder3(x)
#         x = self.tanh(x)
#         x = x.reshape(-1, 24*64)
#         x = self.dense(x)
#         x = self.swish(x)
#         return x

# %%
# model2 = Seq2SeqModel().to(device)

# %%
# from torchinfo import summary

# summary(model2, (1024,24,12))
