# %%
from tqdm.notebook import tqdm
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tqdm
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import time
import tensorflow as tf
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import Sequential, load_model

# %%
dhw_merge2 = pd.read_csv('dhw_merge.csv')

# %%
dhw_merge2['date'] = pd.to_datetime(dhw_merge2.iloc[:,:4])
dhw_len = int(len(dhw_merge2) * 0.7)

# %%
dhw_merge = dhw_merge2.drop(['YEAR', 'date'], axis=1)

# %% [markdown]
# ##  For Scaling

# %%
dhw_X = dhw_merge.drop(['DHW'], axis=1)
dhw_Y = dhw_merge[['DHW']]

scaler_dhw = MinMaxScaler()
scaler_dhw.fit(dhw_X)
scaled_dhw_X = scaler_dhw.transform(dhw_X)

new_dhw_X = pd.DataFrame(scaled_dhw_X, index=dhw_X.index, columns=dhw_X.columns)
new_dhw = pd.concat([new_dhw_X, dhw_Y], axis=1)

# %%
input_dhw = new_dhw.iloc[:-1,]
target_dhw = new_dhw[['DHW']].iloc[1:]

trainX_dhw, testX_dhw, trainY_dhw, testY_dhw = train_test_split(input_dhw,target_dhw,test_size=0.3,shuffle=False,random_state=0)

# %%
def buildDataSet(input, target, seqLength):
    xdata = []
    ydata = []
    for i in range(len(input) - seqLength):
        tx = input.iloc[i:i+seqLength]
        ty = target.iloc[i+seqLength-1]
        xdata.append(tx)
        ydata.append(ty)
    return np.array(xdata), np.array(ydata)

# %%
trainx_dhw, trainy_dhw = buildDataSet(trainX_dhw, trainY_dhw, 24)
testx_dhw, testy_dhw = buildDataSet(testX_dhw, testY_dhw, 24)

# %%
def seq2seq_model(input_shape):
    model_input = tf.keras.layers.Input(shape=input_shape)

    # for feature extracting
    conv1 = tf.keras.layers.Conv1D(64, 1, activation='swish')(model_input)
    pool1 = tf.keras.layers.MaxPool1D(pool_size=2, strides=1, padding='same')(conv1)
    conv2 = tf.keras.layers.Conv1D(32, 1, activation='swish')(pool1)
    pool2 = tf.keras.layers.MaxPool1D(pool_size=2, strides=1, padding='same')(conv2)
    conv3 = tf.keras.layers.Conv1D(128, 1, activation='swish')(pool2)
    pool3 = tf.keras.layers.MaxPool1D(pool_size=2, strides=1, padding='same')(conv3)

    # 인코더 - 디코더 선언
    encoder_lstm1 = tf.keras.layers.LSTM(64, return_sequences=True, activation='tanh')
    encoder_lstm2 = tf.keras.layers.LSTM(32, return_sequences=True, activation='tanh')
    encoder_lstm3 = tf.keras.layers.LSTM(128, return_state=True, return_sequences=True, activation='tanh')

    decoder_lstm1 = tf.keras.layers.LSTM(128, return_sequences=True, activation='tanh')
    decoder_lstm2 = tf.keras.layers.LSTM(32, return_sequences=True, activation='tanh')
    decoder_lstm3 = tf.keras.layers.LSTM(64, return_sequences=True, activation='tanh')

    # 인코더
    encoder_output_lstm1 = encoder_lstm1(pool3)
    encoder_output_lstm2 = encoder_lstm2(encoder_output_lstm1)
    encoder_output_lstm3, state_h, state_c = encoder_lstm3(encoder_output_lstm2)

    #디코더
    decoder_lstm1_output = decoder_lstm1(encoder_output_lstm3, initial_state=[state_h, state_c])
    decoder_lstm2_output = decoder_lstm2(decoder_lstm1_output)
    decoder_lstm3_output = decoder_lstm3(decoder_lstm2_output)

    flatten = tf.keras.layers.Flatten()(decoder_lstm3_output)
    model_output = tf.keras.layers.Dense(1, activation='swish')(flatten)
    
    model = tf.keras.models.Model(model_input, model_output)
    
    return model

# %%
model = seq2seq_model(input_shape=(24, 12))
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 24, 12)]     0           []
#
#  conv1d (Conv1D)                (None, 24, 64)       832         ['input_1[0][0]']
#
#  max_pooling1d (MaxPooling1D)   (None, 24, 64)       0           ['conv1d[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 24, 32)       2080        ['max_pooling1d[0][0]']
#
#  max_pooling1d_1 (MaxPooling1D)  (None, 24, 32)      0           ['conv1d_1[0][0]']
#
#  conv1d_2 (Conv1D)              (None, 24, 128)      4224        ['max_pooling1d_1[0][0]']
#
#  max_pooling1d_2 (MaxPooling1D)  (None, 24, 128)     0           ['conv1d_2[0][0]']
#
#  lstm (LSTM)                    (None, 24, 64)       49408       ['max_pooling1d_2[0][0]']
#
#  lstm_1 (LSTM)                  (None, 24, 32)       12416       ['lstm[0][0]']
#
#  lstm_2 (LSTM)                  [(None, 24, 128),    82432       ['lstm_1[0][0]']
#                                  (None, 128),
#                                  (None, 128)]
#
#  lstm_3 (LSTM)                  (None, 24, 128)      131584      ['lstm_2[0][0]',
#                                                                   'lstm_2[0][1]',
#                                                                   'lstm_2[0][2]']
#
#  lstm_4 (LSTM)                  (None, 24, 32)       20608       ['lstm_3[0][0]']
#
#  lstm_5 (LSTM)                  (None, 24, 64)       24832       ['lstm_4[0][0]']
#
#  flatten (Flatten)              (None, 1536)         0           ['lstm_5[0][0]']
#
#  dense (Dense)                  (None, 1)            1537        ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 329,953
# Trainable params: 329,953
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# 모델 컴파일
earlystopping = EarlyStopping(monitor='loss', patience=50)
checkpoint = ModelCheckpoint(moniter='loss',filepath='dhw_source.h5')
model.compile(loss='mae', optimizer=tf.keras.optimizers.Adamax(learning_rate=3e-4,clipnorm=1.0), metrics=['mae'])
# 모델 요약 정보 출력
hist = model.fit(trainx_dhw, trainy_dhw, epochs=200, batch_size=1024, callbacks=[earlystopping,checkpoint])
# Out:
# Epoch 1/200
# 20/20 [==============================] - 9s 45ms/step - loss: 0.7808 - mae: 0.7808
# Epoch 2/200
# 20/20 [==============================] - 1s 36ms/step - loss: 0.5876 - mae: 0.5876
# Epoch 3/200
# 20/20 [==============================] - 1s 38ms/step - loss: 0.2693 - mae: 0.2693
# Epoch 4/200
# 20/20 [==============================] - 1s 38ms/step - loss: 0.1957 - mae: 0.1957
# Epoch 5/200
# 20/20 [==============================] - 1s 39ms/step - loss: 0.1775 - mae: 0.1775
# Epoch 6/200
# 20/20 [==============================] - 1s 40ms/step - loss: 0.1701 - mae: 0.1701
# Epoch 7/200
# 20/20 [==============================] - 1s 37ms/step - loss: 0.1647 - mae: 0.1647
# Epoch 8/200
# 20/20 [==============================] - 1s 38ms/step - loss: 0.1601 - mae: 0.1601
# Epoch 9/200
# 20/20 [==============================] - 1s 38ms/step - loss: 0.1555 - mae: 0.1555
# Epoch 10/200
# 20/20 [==============================] - 1s 41ms/step - loss: 0.1523 - mae: 0.1523
# Epoch 11/200
# 20/20 [==============================] - 1s 43ms/step - loss: 0.1475 - mae: 0.1475
# Epoch 12/200
# 20/20 [==============================] - 1s 36ms/step - loss: 0.1422 - mae: 0.1422
# Epoch 13/200
# 20/20 [==============================] - 1s 38ms/step - loss: 0.1367 - mae: 0.1367
# Epoch 14/200
# 20/20 [==============================] - 1s 38ms/step - loss: 0.1325 - mae: 0.1325
# Epoch 15/200
# 20/20 [==============================] - 1s 44ms/step - loss: 0.1271 - mae: 0.1271
# Epoch 16/200
# 20/20 [==============================] - 1s 35ms/step - loss: 0.1230 - mae: 0.1230
# Epoch 17/200
# 20/20 [==============================] - 1s 38ms/step - loss: 0.1197 - mae: 0.1197
# Epoch 18/200
# 20/20 [==============================] - 1s 42ms/step - loss: 0.1168 - mae: 0.1168
# Epoch 19/200
# 20/20 [==============================] - 1s 42ms/step - loss: 0.1141 - mae: 0.1141
# Epoch 20/200
# 20/20 [==============================] - 1s 40ms/step - loss: 0.1114 - mae: 0.1114
# Epoch 21/200
# 20/20 [==============================] - 1s 39ms/step - loss: 0.1095 - mae: 0.1095
# Epoch 22/200
# 20/20 [==============================] - 1s 39ms/step - loss: 0.1086 - mae: 0.1086
# Epoch 23/200
# 20/20 [==============================] - 1s 41ms/step - loss: 0.1056 - mae: 0.1056
# Epoch 24/200
# 20/20 [==============================] - 1s 43ms/step - loss: 0.1040 - mae: 0.1040
# Epoch 25/200
# 20/20 [==============================] - 1s 40ms/step - loss: 0.1024 - mae: 0.1024
# Epoch 26/200
# 20/20 [==============================] - 1s 42ms/step - loss: 0.1003 - mae: 0.1003
# Epoch 27/200
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0988 - mae: 0.0988
# Epoch 28/200
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0980 - mae: 0.0980
# Epoch 29/200
# 20/20 [==============================] - 1s 41ms/step - loss: 0.0954 - mae: 0.0954
# Epoch 30/200
# 20/20 [==============================] - 1s 41ms/step - loss: 0.0979 - mae: 0.0979
# Epoch 31/200
# 20/20 [==============================] - 1s 43ms/step - loss: 0.0955 - mae: 0.0955
# Epoch 32/200
# 20/20 [==============================] - 1s 40ms/step - loss: 0.0927 - mae: 0.0927
# Epoch 33/200
# 20/20 [==============================] - 1s 40ms/step - loss: 0.0904 - mae: 0.0904
# Epoch 34/200
# 20/20 [==============================] - 1s 41ms/step - loss: 0.0902 - mae: 0.0902
# Epoch 35/200
# 20/20 [==============================] - 1s 43ms/step - loss: 0.0893 - mae: 0.0893
# Epoch 36/200
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0895 - mae: 0.0895
# Epoch 37/200
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0889 - mae: 0.0889
# Epoch 38/200
# 20/20 [==============================] - 1s 39ms/step - loss: 0.0872 - mae: 0.0872
# Epoch 39/200
# 20/20 [==============================] - 1s 40ms/step - loss: 0.0862 - mae: 0.0862
# Epoch 40/200
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0880 - mae: 0.0880
# Epoch 41/200
# 20/20 [==============================] - 1s 40ms/step - loss: 0.0868 - mae: 0.0868
# Epoch 42/200
# 20/20 [==============================] - 1s 44ms/step - loss: 0.0837 - mae: 0.0837
# Epoch 43/200
# 20/20 [==============================] - 1s 41ms/step - loss: 0.0852 - mae: 0.0852
# Epoch 44/200
# 20/20 [==============================] - 1s 41ms/step - loss: 0.0821 - mae: 0.0821
# Epoch 45/200
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0815 - mae: 0.0815
# Epoch 46/200
# 20/20 [==============================] - 1s 39ms/step - loss: 0.0804 - mae: 0.0804
# Epoch 47/200
# 20/20 [==============================] - 1s 39ms/step - loss: 0.0799 - mae: 0.0799
# Epoch 48/200
# 20/20 [==============================] - 1s 39ms/step - loss: 0.0807 - mae: 0.0807
# Epoch 49/200
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0774 - mae: 0.0774
# Epoch 50/200
# 20/20 [==============================] - 1s 39ms/step - loss: 0.0761 - mae: 0.0761
# Epoch 51/200
# 20/20 [==============================] - 1s 41ms/step - loss: 0.0773 - mae: 0.0773
# Epoch 52/200
# 20/20 [==============================] - 1s 42ms/step - loss: 0.0771 - mae: 0.0771
# Epoch 53/200
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0738 - mae: 0.0738
# Epoch 54/200
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0720 - mae: 0.0720
# Epoch 55/200
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0741 - mae: 0.0741
# Epoch 56/200
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0701 - mae: 0.0701
# Epoch 57/200
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0708 - mae: 0.0708
# Epoch 58/200
# 20/20 [==============================] - 1s 39ms/step - loss: 0.0670 - mae: 0.0670
# Epoch 59/200
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0688 - mae: 0.0688
# Epoch 60/200
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0713 - mae: 0.0713
# Epoch 61/200
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0701 - mae: 0.0701
# Epoch 62/200
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0689 - mae: 0.0689
# Epoch 63/200
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0677 - mae: 0.0677
# Epoch 64/200
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0635 - mae: 0.0635
# Epoch 65/200
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0676 - mae: 0.0676
# Epoch 66/200
# 20/20 [==============================] - 1s 41ms/step - loss: 0.0669 - mae: 0.0669
# Epoch 67/200
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0651 - mae: 0.0651
# Epoch 68/200
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0657 - mae: 0.0657
# Epoch 69/200
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0642 - mae: 0.0642
# Epoch 70/200
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0639 - mae: 0.0639
# Epoch 71/200
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0630 - mae: 0.0630
# Epoch 72/200
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0632 - mae: 0.0632
# Epoch 73/200
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0624 - mae: 0.0624
# Epoch 74/200
# 20/20 [==============================] - 1s 34ms/step - loss: 0.0619 - mae: 0.0619
# Epoch 75/200
# 20/20 [==============================] - 1s 35ms/step - loss: 0.0610 - mae: 0.0610
# Epoch 76/200
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0606 - mae: 0.0606
# Epoch 77/200
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0599 - mae: 0.0599
# Epoch 78/200
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0599 - mae: 0.0599
# Epoch 79/200
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0589 - mae: 0.0589
# Epoch 80/200
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0585 - mae: 0.0585
# Epoch 81/200
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0583 - mae: 0.0583
# Epoch 82/200
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0577 - mae: 0.0577
# Epoch 83/200
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0572 - mae: 0.0572
# Epoch 84/200
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0563 - mae: 0.0563
# Epoch 85/200
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0587 - mae: 0.0587
# Epoch 86/200
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0556 - mae: 0.0556
# Epoch 87/200
# 20/20 [==============================] - 1s 35ms/step - loss: 0.0551 - mae: 0.0551
# Epoch 88/200
# 20/20 [==============================] - 1s 35ms/step - loss: 0.0553 - mae: 0.0553
# Epoch 89/200
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0540 - mae: 0.0540
# Epoch 90/200
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0494 - mae: 0.0494
# Epoch 91/200
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0488 - mae: 0.0488
# Epoch 92/200
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0485 - mae: 0.0485
# Epoch 93/200
# 20/20 [==============================] - 1s 39ms/step - loss: 0.0493 - mae: 0.0493
# Epoch 94/200
# 20/20 [==============================] - 1s 39ms/step - loss: 0.0586 - mae: 0.0586
# Epoch 95/200
# 20/20 [==============================] - 1s 39ms/step - loss: 0.0532 - mae: 0.0532
# Epoch 96/200
# 20/20 [==============================] - 1s 41ms/step - loss: 0.0511 - mae: 0.0511
# Epoch 97/200
# 20/20 [==============================] - 1s 42ms/step - loss: 0.0505 - mae: 0.0505
# Epoch 98/200
# 20/20 [==============================] - 1s 43ms/step - loss: 0.0518 - mae: 0.0518
# Epoch 99/200
# 20/20 [==============================] - 1s 40ms/step - loss: 0.0519 - mae: 0.0519
# Epoch 100/200
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0478 - mae: 0.0478
# Epoch 101/200
# 20/20 [==============================] - 1s 40ms/step - loss: 0.0461 - mae: 0.0461
# Epoch 102/200
# 20/20 [==============================] - 1s 43ms/step - loss: 0.0463 - mae: 0.0463
# Epoch 103/200
# 20/20 [==============================] - 1s 41ms/step - loss: 0.0508 - mae: 0.0508
# Epoch 104/200
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0515 - mae: 0.0515
# Epoch 105/200
# 20/20 [==============================] - 1s 40ms/step - loss: 0.0507 - mae: 0.0507
# Epoch 106/200
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0488 - mae: 0.0488
# Epoch 107/200
# 20/20 [==============================] - 1s 42ms/step - loss: 0.0501 - mae: 0.0501
# Epoch 108/200
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0505 - mae: 0.0505
# Epoch 109/200
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0461 - mae: 0.0461
# Epoch 110/200
# 20/20 [==============================] - 1s 40ms/step - loss: 0.0451 - mae: 0.0451
# Epoch 111/200
# 20/20 [==============================] - 1s 40ms/step - loss: 0.0446 - mae: 0.0446
# Epoch 112/200
# 20/20 [==============================] - 1s 39ms/step - loss: 0.0474 - mae: 0.0474
# Epoch 113/200
# 20/20 [==============================] - 1s 39ms/step - loss: 0.0450 - mae: 0.0450
# Epoch 114/200
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0475 - mae: 0.0475
# Epoch 115/200
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0479 - mae: 0.0479
# Epoch 116/200
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0450 - mae: 0.0450
# Epoch 117/200
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0436 - mae: 0.0436
# Epoch 118/200
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0437 - mae: 0.0437
# Epoch 119/200
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0433 - mae: 0.0433
# Epoch 120/200
# 20/20 [==============================] - 1s 39ms/step - loss: 0.0431 - mae: 0.0431
# Epoch 121/200
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0433 - mae: 0.0433
# Epoch 122/200
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0517 - mae: 0.0517
# Epoch 123/200
# 20/20 [==============================] - 1s 39ms/step - loss: 0.0474 - mae: 0.0474
# Epoch 124/200
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0477 - mae: 0.0477
# Epoch 125/200
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0475 - mae: 0.0475
# Epoch 126/200
# 20/20 [==============================] - 1s 39ms/step - loss: 0.0469 - mae: 0.0469
# Epoch 127/200
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0470 - mae: 0.0470
# Epoch 128/200
# 20/20 [==============================] - 1s 39ms/step - loss: 0.0468 - mae: 0.0468
# Epoch 129/200
# 20/20 [==============================] - 1s 40ms/step - loss: 0.0469 - mae: 0.0469
# Epoch 130/200
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0425 - mae: 0.0425
# Epoch 131/200
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0431 - mae: 0.0431
# Epoch 132/200
# 20/20 [==============================] - 1s 35ms/step - loss: 0.0468 - mae: 0.0468
# Epoch 133/200
# 20/20 [==============================] - 1s 40ms/step - loss: 0.0469 - mae: 0.0469
# Epoch 134/200
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0471 - mae: 0.0471
# Epoch 135/200
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0467 - mae: 0.0467
# Epoch 136/200
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0465 - mae: 0.0465
# Epoch 137/200
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0460 - mae: 0.0460
# Epoch 138/200
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0463 - mae: 0.0463
# Epoch 139/200
# 20/20 [==============================] - 1s 39ms/step - loss: 0.0457 - mae: 0.0457
# Epoch 140/200
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0447 - mae: 0.0447
# Epoch 141/200
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0442 - mae: 0.0442
# Epoch 142/200
# 20/20 [==============================] - 1s 39ms/step - loss: 0.0455 - mae: 0.0455
# Epoch 143/200
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0418 - mae: 0.0418
# Epoch 144/200
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0419 - mae: 0.0419
# Epoch 145/200
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0449 - mae: 0.0449
# Epoch 146/200
# 20/20 [==============================] - 1s 39ms/step - loss: 0.0418 - mae: 0.0418
# Epoch 147/200
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0458 - mae: 0.0458
# Epoch 148/200
# 20/20 [==============================] - 1s 39ms/step - loss: 0.0443 - mae: 0.0443
# Epoch 149/200
# 20/20 [==============================] - 1s 39ms/step - loss: 0.0415 - mae: 0.0415
# Epoch 150/200
# 20/20 [==============================] - 1s 39ms/step - loss: 0.0422 - mae: 0.0422
# Epoch 151/200
# 20/20 [==============================] - 1s 40ms/step - loss: 0.0423 - mae: 0.0423
# Epoch 152/200
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0443 - mae: 0.0443
# Epoch 153/200
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0430 - mae: 0.0430
# Epoch 154/200
# 20/20 [==============================] - 1s 39ms/step - loss: 0.0431 - mae: 0.0431
# Epoch 155/200
# 20/20 [==============================] - 1s 40ms/step - loss: 0.0424 - mae: 0.0424
# Epoch 156/200
# 20/20 [==============================] - 1s 40ms/step - loss: 0.0434 - mae: 0.0434
# Epoch 157/200
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0438 - mae: 0.0438
# Epoch 158/200
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0448 - mae: 0.0448
# Epoch 159/200
# 20/20 [==============================] - 1s 39ms/step - loss: 0.0433 - mae: 0.0433
# Epoch 160/200
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0406 - mae: 0.0406
# Epoch 161/200
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0405 - mae: 0.0405
# Epoch 162/200
# 20/20 [==============================] - 1s 39ms/step - loss: 0.0403 - mae: 0.0403
# Epoch 163/200
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0401 - mae: 0.0401
# Epoch 164/200
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0403 - mae: 0.0403
# Epoch 165/200
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0406 - mae: 0.0406
# Epoch 166/200
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0450 - mae: 0.0450
# Epoch 167/200
# 20/20 [==============================] - 1s 39ms/step - loss: 0.0448 - mae: 0.0448
# Epoch 168/200
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0425 - mae: 0.0425
# Epoch 169/200
# 20/20 [==============================] - 1s 39ms/step - loss: 0.0401 - mae: 0.0401
# Epoch 170/200
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0400 - mae: 0.0400
# Epoch 171/200
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0398 - mae: 0.0398
# Epoch 172/200
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0396 - mae: 0.0396
# Epoch 173/200
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0396 - mae: 0.0396
# Epoch 174/200
# 20/20 [==============================] - 1s 40ms/step - loss: 0.0401 - mae: 0.0401
# Epoch 175/200
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0407 - mae: 0.0407
# Epoch 176/200
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0405 - mae: 0.0405
# Epoch 177/200
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0404 - mae: 0.0404
# Epoch 178/200
# 20/20 [==============================] - 1s 39ms/step - loss: 0.0393 - mae: 0.0393
# Epoch 179/200
# 20/20 [==============================] - 1s 41ms/step - loss: 0.0399 - mae: 0.0399
# Epoch 180/200
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0438 - mae: 0.0438
# Epoch 181/200
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0397 - mae: 0.0397
# Epoch 182/200
# 20/20 [==============================] - 1s 39ms/step - loss: 0.0394 - mae: 0.0394
# Epoch 183/200
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0394 - mae: 0.0394
# Epoch 184/200
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0391 - mae: 0.0391
# Epoch 185/200
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0396 - mae: 0.0396
# Epoch 186/200
# 20/20 [==============================] - 1s 39ms/step - loss: 0.0397 - mae: 0.0397
# Epoch 187/200
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0432 - mae: 0.0432
# Epoch 188/200
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0429 - mae: 0.0429
# Epoch 189/200
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0437 - mae: 0.0437
# Epoch 190/200
# 20/20 [==============================] - 1s 41ms/step - loss: 0.0419 - mae: 0.0419
# Epoch 191/200
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0391 - mae: 0.0391
# Epoch 192/200
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0399 - mae: 0.0399
# Epoch 193/200
# 20/20 [==============================] - 1s 39ms/step - loss: 0.0428 - mae: 0.0428
# Epoch 194/200
# 20/20 [==============================] - 1s 40ms/step - loss: 0.0430 - mae: 0.0430
# Epoch 195/200
# 20/20 [==============================] - 1s 40ms/step - loss: 0.0421 - mae: 0.0421
# Epoch 196/200
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0419 - mae: 0.0419
# Epoch 197/200
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0395 - mae: 0.0395
# Epoch 198/200
# 20/20 [==============================] - 1s 39ms/step - loss: 0.0386 - mae: 0.0386
# Epoch 199/200
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0385 - mae: 0.0385
# Epoch 200/200
# 20/20 [==============================] - 1s 35ms/step - loss: 0.0391 - mae: 0.0391

# %%
#model = load_model('dhw_source.h5')
pred = model.predict(testx_dhw)
pred = np.reshape(pred,(-1,1))

real = np.array(testy_dhw)
# Out:
# 273/273 [==============================] - 4s 8ms/step

# %%
from sklearn.metrics import mean_absolute_error
print('MAE : ', round(mean_absolute_error(real, pred),4)) 

from sklearn.metrics import mean_squared_error
print('MSE : ', round(mean_squared_error(real, pred),4))

from sklearn.metrics import r2_score
print('R2 : ', round(r2_score(real, pred),4))
# Out:
# MAE :  0.0333
# MSE :  0.0068
# R2 :  0.9901

# %%
date = dhw_merge2['date'].iloc[dhw_len:-24]

# %%
plt.figure(figsize=(10,4))
plt.ylabel('DHW consumption',size=10)
plt.plot(date, real, color='red', label='True')
plt.plot(date, pred, color='blue', label='Pred')
plt.rc('font',size=10)
plt.legend()
plt.show()
